# %% [markdown]
# ## Extracting Context Topics and Contexts

# %%
import json
import pandas as pd
import numpy as np
from collections import defaultdict


np.random.seed(42)
# load from parquet file
df = pd.read_parquet('../../data/pquad/test_data.parquet')

# %%
df.paragraphs[0][2]["context"]
# Out:
# 'پاتریشیا کرون، مایکل کوک و بسیاری دیگر از محققان، بر اساس متن و تحقیقات باستان\u200cشناسی، تصور کرده\u200cاند که «مسجدالحرام» در مکه واقع نشده\u200cاست، بلکه در شمال غربی شبه جزیره عربستان واقع شده\u200cاست. دن گیبسون اظهار داشت که اولین مساجد اسلامی و جهت\u200cهای گورستان (قبله) نشان داد پترا، محمد اولین افشاگری\u200cهای خود را در اینجا دریافت کرد و اسلام در اینجا برقرار شد. رابرت برترام سرژانت در ژورنال جامعهٔ شرق\u200cشناسی آمریکا این نظریه را یک جدال سردرگم و غیرمنطقی توصیف کرد که به دلیل درک نادرست پاتریشیا کرون از متون عربی، عدم آشنایی با جامعهٔ عربستان، و سوءتعبیر از نوشته\u200cهای دیگر به نفع نظریهٔ خود پیچیده\u200cتر شده\u200cاست.'

# %%
len(df.paragraphs)
# Out:
# 114

# %%
len(df.paragraphs[3])
# Out:
# 5

# %%
# Extract topics from context to new column, meanwhile, extracting the context themselves into a list
all_context = []

def extract_topics(df):
    global all_context
    for i in range(len(df.paragraphs)):
        for j in range(len(df.paragraphs[i])):
            all_context.append(df.paragraphs[i][j]["context"])
    
extract_topics(df)
    
all_context = list(set(all_context))  # Remove duplicates from contexts
print(f"Total unique contexts: {len(all_context)}")
# Out:
# Total unique contexts: 1059

# %%
## save all_context to a json file
with open('all_context.json', 'w', encoding='utf-8') as f:
    json.dump(all_context, f, ensure_ascii=False, indent=4)

# %% [markdown]
# # Extracting Knowledge Graph Triplets

# %%
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field
from typing import List
import dotenv
import json
import os

# %%
dotenv.load_dotenv()

MODEL_NAME = "gpt-4o-mini"

llm = ChatOpenAI(
    model=MODEL_NAME,
    temperature=0,
    api_key=os.getenv("METIS_API_KEY"),
    base_url="https://api.metisai.ir/openai/v1",
)

# %%
# load all_context from json file
with open('all_context.json', 'r', encoding='utf-8') as f:
    all_context = json.load(f)

# print 3 first contexts
print("First 3 contexts:")
for context in all_context[:3]:
    print(context)
    print("-" * 10)
# Out:
# First 3 contexts:
# ایرانیان از ۱۳۱۶ این دریا را مازندران می‌نامند. نام دریای مازندران و دریای خزر در ۵۰ سال گذشته در رسانه‌های گروهی ایران رایج بوده‌است. در سال ۱۳۶۱ دولت نام دریای مازندران را نام رسمی اعلام کرد.شاهزاده مسعود میرزا ظل‌السلطان ملقب به ظل السلطان که از شاهزادگان قاجار و بزرگترین پسر به سن بلوغ رسیده ناصر الدین شاه بود که در دوران جوانی مدتی حاکم مازندران بود. وی در خاطرات خود آورده‌است: وقتی در بلده در اردوی همایونی بودم، دستورالعملی به جناب بهاء الملک وزیر من و من مرحمت فرمودند که میانکاله را ضبط کرده قلعه ای بسازیم، و در او ساخلو بگذاریم. این میانکاله همان شبه جزیره آبسکون است که شرحش را نوشتیم. یکی از اسامی این دریای مازندران را دریای آبسکون نیز می‌گویند.
# ----------
# پیروزی رونالد ریگان در ابتدای دهه ۱۹۸۰ در حقیقت پیروزی جناح راست حزب جمهوری‌خواه بود که محافظه‌کاری را به شکل عمیق در کشور حاکم کرد. وی با شعار کاهش مالیات‌ها، کاهش هزینه‌های دولت، تقویت بودجه نظامی و کاهش دخالت‌های دولت در امر بخش خصوصی به کاخ سفید وارد شد. به همین دلیل در نخستین دوره ریاست جمهوری ریگان، بزرگ‌ترین کاهش مالیات‌ها در طول تاریخ ایالات متحده و عظیم‌ترین بودجه نظامی در دوران صلح به مرحله اجرا گذاشته شد. در بخش اقتصاد، کاهش هزینه‌های دولت، با افزایش نرخ بیکاری همراه شد و ۴ برابر شدن قیمت نفت، رکود اقتصادی را در ایالات متحده به همراه آورد. اما در عرصه سیاست خارجی، ریگان با در پیش گرفتن یک سیاست خارجی تهاجمی علیه «شیطان سرخ» - اتحاد شوروی _ به بازسازی روحیه ملی پرداخت. وی خصومت و رقابت با مسکو را از طریق طرح جنگ ستارگان به اوج رساند به این امید که ماشین نظامی روس‌ها را از نفس بیندازد. این هدف در زمان جانشین وی یعنی جورج بوش پدر به بار نشست.
# ----------
# محمد غفاری در خانواده‌ای هنرمند و سرشناس در روستای کله در ۴۵ کیلومتری کاشان زاده شد. تحصیلات اولیه‌اش را در مکاتب زادگاهش گذراند. پس از تحصیلات ابتدایی در کاشان، پدرش ابوتراب غفاری که همچون نیاکانش مشغول حرفهٔ نقاشی بود، محمد را همراه برادر بزرگش به تهران فرستاد تا در مدرسه دارالفنون در رشتهٔ نقاشی ادامه تحصیل دهند.
# ----------

# %%
class NamedEntities(BaseModel):
    """A structured list of named entities."""
    named_entities: List[str] = Field(
        ...,
        description="A list of named entities extracted from the provided passage."
    )

class KnowledgeTriple(BaseModel):
    """Represents a single Subject-Predicate-Object relationship."""
    subject: str = Field(..., description="The subject of the relationship.")
    predicate: str = Field(..., description="The predicate or verb phrase describing the relationship.")
    object: str = Field(..., description="The object of the relationship.")

class Triples(BaseModel):
    """A structured list of knowledge triples."""
    triples: List[KnowledgeTriple] = Field(
        ...,
        description="A list of knowledge triples (subject, predicate, object) extracted from the passage."
    )

# %%
ner_system_prompt = """
Instruction:
Your task is to extract named entities from the given paragraph in the user's message.
Respond with a JSON list of entities.

One-Shot Demonstration:
If the user provides the paragraph:
"Radio City is India's first private FM radio station and was started on 3 July 2001. It plays Hindi, English and regional songs. Radio City recently forayed into New Media in May 2008 with the launch of a music portal - PlanetRadiocity.com that offers music related news, videos, songs, and other music-related features."

Your output should be a JSON object with a list of the extracted entities:
{{"named_entities": ["Radio City", "India", "3 July 2001", "Hindi", "English", "May 2008", "PlanetRadiocity.com"]}}
"""

# System Prompt for Open Information Extraction (OpenIE)
# This example is taken from Figure 9 of the HippoRAG paper.
openie_system_prompt = """
Instruction:
Your task is to construct an RDF (Resource Description Framework) graph from the given passages and named entity lists.
Respond with a JSON list of triples, with each triple representing a relationship in the RDF graph.
Pay attention to the following requirements:
- Each triple should contain at least one, but preferably two, of the named entities in the list for each passage.
- Clearly resolve pronouns to their specific names to maintain clarity.

One-Shot Demonstration:
If the user provides the paragraph and entity list:
Paragraph:
"Radio City is India's first private FM radio station and was started on 3 July 2001. It plays Hindi, English and regional songs. Radio City recently forayed into New Media in May 2008 with the launch of a music portal - PlanetRadiocity.com that offers music related news, videos, songs, and other music-related features."
Named Entity List:
["Radio City", "India", "3 July 2001", "Hindi", "English", "May 2008", "PlanetRadiocity.com"]

Your output should be a JSON object containing a list of the extracted triples:
{{"triples": [
    ["Radio City", "located in", "India"],
    ["Radio City", "is", "private FM radio station"],
    ["Radio City", "started on", "3 July 2001"],
    ["Radio City", "plays songs in", "Hindi"],
    ["Radio City", "plays songs in", "English"],
    ["Radio City", "forayed into", "New Media"],
    ["Radio City", "launched", "PlanetRadiocity.com"],
    ["PlanetRadiocity.com", "launched in", "May 2008"],
    ["PlanetRadiocity.com", "is", "music portal"],
    ["PlanetRadiocity.com", "offers", "news"],
    ["PlanetRadiocity.com", "offers", "videos"],
    ["PlanetRadiocity.com", "offers", "songs"]
]}}
"""

# %%
ner_prompt = ChatPromptTemplate.from_messages([
    ("system", ner_system_prompt),
    ("human", "{passage}")
])

openie_prompt = ChatPromptTemplate.from_messages([
    ("system", openie_system_prompt),
    ("human", "Paragraph:\n{passage}\n\nNamed Entity List:\n{entities}")
])

# %%
structured_ner_llm = llm.with_structured_output(NamedEntities)
structured_openie_llm = llm.with_structured_output(Triples)

ner_chain = ner_prompt | structured_ner_llm
openie_chain = openie_prompt | structured_openie_llm

# %%
def extract_knowledge_structured(passage: str) -> (List[str], List[dict]):
    """
    Implements the two-step HippoRAG extraction process using a system/user prompt structure.
    """
    try:
        ner_response = ner_chain.invoke({"passage": passage})
        entities = ner_response.named_entities
        print(f"  -> Extracted Entities: {entities}")
    except Exception as e:
        print(f"  -> Error during structured NER extraction: {e}")
        return [], []

    if not entities:
        print("  -> No entities found, skipping triple extraction.")
        return [], []

    try:
        entities_str = json.dumps(entities, ensure_ascii=False)
        openie_response = openie_chain.invoke({"passage": passage, "entities": entities_str})
        triples = [triple.model_dump() for triple in openie_response.triples]
        print(f"  -> Extracted Triples: {triples}")
        return entities, triples
    except Exception as e:
        print(f"  -> Error during structured OpenIE extraction: {e}")
        return entities, []

# %%
## Test 5 contexts
contexts_to_process = all_context[:5]
knowledge_graph_data = []

print("Starting Knowledge Graph Extraction (HippoRAG Paper Examples)")
for i, context_passage in enumerate(contexts_to_process):
    print(f"\ncontext {i+1}/5:")
    print(f"'{context_passage}'")

    extracted_entities, extracted_triples = extract_knowledge_structured(context_passage)

    if extracted_triples:
        knowledge_graph_data.append({
            "id": i,
            "passage": context_passage,
            "entities": extracted_entities,
            "triples": extracted_triples
        })
    print("-" * 20)
# Out:
# Starting Knowledge Graph Extraction (HippoRAG Paper Examples)
#
# context 1/5:
# 'ایرانیان از ۱۳۱۶ این دریا را مازندران می‌نامند. نام دریای مازندران و دریای خزر در ۵۰ سال گذشته در رسانه‌های گروهی ایران رایج بوده‌است. در سال ۱۳۶۱ دولت نام دریای مازندران را نام رسمی اعلام کرد.شاهزاده مسعود میرزا ظل‌السلطان ملقب به ظل السلطان که از شاهزادگان قاجار و بزرگترین پسر به سن بلوغ رسیده ناصر الدین شاه بود که در دوران جوانی مدتی حاکم مازندران بود. وی در خاطرات خود آورده‌است: وقتی در بلده در اردوی همایونی بودم، دستورالعملی به جناب بهاء الملک وزیر من و من مرحمت فرمودند که میانکاله را ضبط کرده قلعه ای بسازیم، و در او ساخلو بگذاریم. این میانکاله همان شبه جزیره آبسکون است که شرحش را نوشتیم. یکی از اسامی این دریای مازندران را دریای آبسکون نیز می‌گویند.'
#   -> Extracted Entities: ['ایرانیان', '۱۳۱۶', 'دریای مازندران', 'دریای خزر', '۵۰ سال گذشته', 'رسانه\u200cهای گروهی ایران', '۱۳۶۱', 'دولت', 'شاهزاده مسعود میرزا ظل\u200cالسلطان', 'ظل السلطان', 'شاهزادگان قاجار', 'ناصر الدین شاه', 'بلده', 'اردوی همایونی', 'جناب بهاء الملک', 'میانکاله', 'قلعه', 'ساخلو', 'شبه جزیره آبسکون', 'دریای آبسکون']
#   -> Extracted Triples: [{'subject': 'ایرانیان', 'predicate': 'نام این دریا را گذاشته\u200cاند', 'object': 'دریای مازندران'}, {'subject': 'دریای مازندران', 'predicate': 'نام رایج در رسانه\u200cهای گروهی ایران در', 'object': '۵۰ سال گذشته'}, {'subject': 'دولت', 'predicate': 'نام رسمی اعلام کرد', 'object': 'دریای مازندران'}, {'subject': 'دولت', 'predicate': 'نام رسمی اعلام کرد در سال', 'object': '۱۳۶۱'}, {'subject': 'شاهزاده مسعود میرزا ظل\u200cالسلطان', 'predicate': 'لقب دارد', 'object': 'ظل السلطان'}, {'subject': 'شاهزاده مسعود میرزا ظل\u200cالسلطان', 'predicate': 'از', 'object': 'شاهزادگان قاجار'}, {'subject': 'شاهزاده مسعود میرزا ظل\u200cالسلطان', 'predicate': 'پسر به سن بلوغ رسیده', 'object': 'ناصر الدین شاه'}, {'subject': 'شاهزاده مسعود میرزا ظل\u200cالسلطان', 'predicate': 'حاکم مازندران بود در دوران جوانی', 'object': 'true'}, {'subject': 'شاهزاده مسعود میرزا ظل\u200cالسلطان', 'predicate': 'در خاطرات خود گفته', 'object': 'وقتی در بلده در اردوی همایونی بودم، دستورالعملی به جناب بهاء الملک وزیر من و من مرحمت فرمودند که میانکاله را ضبط کرده قلعه ای بسازیم، و در او ساخلو بگذاریم.'}, {'subject': 'میانکاله', 'predicate': 'همان است', 'object': 'شبه جزیره آبسکون'}, {'subject': 'دریای مازندران', 'predicate': 'یکی از اسامی آن است', 'object': 'دریای آبسکون'}]
# --------------------
#
# context 2/5:
# 'پیروزی رونالد ریگان در ابتدای دهه ۱۹۸۰ در حقیقت پیروزی جناح راست حزب جمهوری‌خواه بود که محافظه‌کاری را به شکل عمیق در کشور حاکم کرد. وی با شعار کاهش مالیات‌ها، کاهش هزینه‌های دولت، تقویت بودجه نظامی و کاهش دخالت‌های دولت در امر بخش خصوصی به کاخ سفید وارد شد. به همین دلیل در نخستین دوره ریاست جمهوری ریگان، بزرگ‌ترین کاهش مالیات‌ها در طول تاریخ ایالات متحده و عظیم‌ترین بودجه نظامی در دوران صلح به مرحله اجرا گذاشته شد. در بخش اقتصاد، کاهش هزینه‌های دولت، با افزایش نرخ بیکاری همراه شد و ۴ برابر شدن قیمت نفت، رکود اقتصادی را در ایالات متحده به همراه آورد. اما در عرصه سیاست خارجی، ریگان با در پیش گرفتن یک سیاست خارجی تهاجمی علیه «شیطان سرخ» - اتحاد شوروی _ به بازسازی روحیه ملی پرداخت. وی خصومت و رقابت با مسکو را از طریق طرح جنگ ستارگان به اوج رساند به این امید که ماشین نظامی روس‌ها را از نفس بیندازد. این هدف در زمان جانشین وی یعنی جورج بوش پدر به بار نشست.'
#   -> Extracted Entities: ['رونالد ریگان', 'دهه ۱۹۸۰', 'جناح راست حزب جمهوری\u200cخواه', 'کاخ سفید', 'نخستین دوره ریاست جمهوری ریگان', 'ایالات متحده', '۴ برابر شدن قیمت نفت', 'اتحاد شوروی', 'شیطان سرخ', 'جنگ ستارگان', 'جورج بوش پدر']
#   -> Extracted Triples: [{'subject': 'رونالد ریگان', 'predicate': 'won election in', 'object': 'دهه ۱۹۸۰'}, {'subject': 'رونالد ریگان', 'predicate': 'represented', 'object': 'جناح راست حزب جمهوری\u200cخواه'}, {'subject': 'جناح راست حزب جمهوری\u200cخواه', 'predicate': 'imposed', 'object': 'محافظه\u200cکاری در ایالات متحده'}, {'subject': 'رونالد ریگان', 'predicate': 'entered', 'object': 'کاخ سفید'}, {'subject': 'رونالد ریگان', 'predicate': 'promoted', 'object': 'کاهش مالیات\u200cها'}, {'subject': 'رونالد ریگان', 'predicate': 'promoted', 'object': 'کاهش هزینه\u200cهای دولت'}, {'subject': 'رونالد ریگان', 'predicate': 'promoted', 'object': 'تقویت بودجه نظامی'}, {'subject': 'رونالد ریگان', 'predicate': 'promoted', 'object': 'کاهش دخالت\u200cهای دولت در بخش خصوصی'}, {'subject': 'نخستین دوره ریاست جمهوری ریگان', 'predicate': 'had', 'object': 'بزرگ\u200cترین کاهش مالیات\u200cها در تاریخ ایالات متحده'}, {'subject': 'نخستین دوره ریاست جمهوری ریگان', 'predicate': 'had', 'object': 'عظیم\u200cترین بودجه نظامی در دوران صلح'}, {'subject': 'کاهش هزینه\u200cهای دولت', 'predicate': 'caused', 'object': 'افزایش نرخ بیکاری در ایالات متحده'}, {'subject': '۴ برابر شدن قیمت نفت', 'predicate': 'caused', 'object': 'رکود اقتصادی در ایالات متحده'}, {'subject': 'رونالد ریگان', 'predicate': 'adopted aggressive foreign policy against', 'object': 'شیطان سرخ'}, {'subject': 'شیطان سرخ', 'predicate': 'is', 'object': 'اتحاد شوروی'}, {'subject': 'رونالد ریگان', 'predicate': 'boosted', 'object': 'روحیه ملی در ایالات متحده'}, {'subject': 'رونالد ریگان', 'predicate': 'escalated hostility and competition with', 'object': 'مسکو'}, {'subject': 'رونالد ریگان', 'predicate': 'used', 'object': 'جنگ ستارگان'}, {'subject': 'جنگ ستارگان', 'predicate': 'aimed to', 'object': 'ضعیف کردن ماشین نظامی روس\u200cها'}, {'subject': 'هدف جنگ ستارگان', 'predicate': 'was achieved by', 'object': 'جورج بوش پدر'}]
# --------------------
#
# context 3/5:
# 'محمد غفاری در خانواده‌ای هنرمند و سرشناس در روستای کله در ۴۵ کیلومتری کاشان زاده شد. تحصیلات اولیه‌اش را در مکاتب زادگاهش گذراند. پس از تحصیلات ابتدایی در کاشان، پدرش ابوتراب غفاری که همچون نیاکانش مشغول حرفهٔ نقاشی بود، محمد را همراه برادر بزرگش به تهران فرستاد تا در مدرسه دارالفنون در رشتهٔ نقاشی ادامه تحصیل دهند.'
#   -> Extracted Entities: ['محمد غفاری', 'کله', 'کاشان', 'ابوتراب غفاری', 'تهران', 'مدرسه دارالفنون']
#   -> Extracted Triples: [{'subject': 'محمد غفاری', 'predicate': 'born in', 'object': 'کله'}, {'subject': 'کله', 'predicate': 'located near', 'object': 'کاشان'}, {'subject': 'محمد غفاری', 'predicate': 'born in family of', 'object': 'هنرمند و سرشناس'}, {'subject': 'محمد غفاری', 'predicate': 'completed primary education in', 'object': 'مکاتب زادگاهش'}, {'subject': 'محمد غفاری', 'predicate': 'father is', 'object': 'ابوتراب غفاری'}, {'subject': 'ابوتراب غفاری', 'predicate': 'profession', 'object': 'نقاشی'}, {'subject': 'ابوتراب غفاری', 'predicate': 'sent', 'object': 'محمد غفاری and برادر بزرگش to تهران'}, {'subject': 'محمد غفاری', 'predicate': 'continued education in', 'object': 'مدرسه دارالفنون'}, {'subject': 'محمد غفاری', 'predicate': 'field of study', 'object': 'نقاشی'}]
# --------------------
#
# context 4/5:
# 'منطقه گیلان دارای بارش فراوان است تا جایی که بارش سالانه شاید به ۱۲۰ سانتی‌متر هم برسد. مواد ساختمانی، جز صخره سخت، سریعاً خراب می‌شوند، و ساختمان‌های قدیمی تبدیل به تلی از آوار می‌شوند. درختان و علف‌های هرز بر این آوارها می‌رویند و ساختمان‌های قدیمی را تبدیل به تپه‌هایی پوشیده از گیاهان می‌کنند. بسیاری از این تپه‌ها که به گویش محلی به آن‌ها کول، کوتی، دین و دوین می‌گویند حاشیه ساحل دریا را پر می‌کنند و هر یک پایگاهی می‌شوند که واجد ارزش برای کاوش و پژوهش باستان شناسانه‌است. به هر حال جز چراغ علی تپه در دهانه گوهر رود، که توسط عزت‌الله نگهبان کاویده شد و بیشتر به عنوان تپه مارلیک شناخته می‌شود، هیچ کدامشان تاکنون به‌طور علمی مورد کاوش و مطالعه قرار نگرفته‌اند. ساختمان‌های دارای ارزش تاریخی هم وجود دارند که بیشترشان در طول تاریخشان مکرراً تعمیر و بازسازی شده‌اند. بعضی‌هایشان ضبط واضحی از تاریخشان دارند، ولی بیشترشان فاقد اسناد اولیه قابل اطمینان اند و باید به شواهد غیرمستقیم مانند تاریخهای حک شده بر درهای ورودی، سنگ قبرها، ضریحه‌ها یا تابوتها برای بازسازی بخشی از گذشته یک عمارت داده شده اکتفا کرده به حدس زدن منشأ آن‌ها خطر کرد.'
#   -> Extracted Entities: ['گیلان', '۱۲۰ سانتی\u200cمتر', 'چراغ علی تپه', 'دهانه گوهر رود', 'عزت\u200cالله نگهبان', 'تپه مارلیک']
#   -> Extracted Triples: [{'subject': 'گیلان', 'predicate': 'has annual rainfall of', 'object': '۱۲۰ سانتی\u200cمتر'}, {'subject': 'ساختمان\u200cهای قدیمی', 'predicate': 'turn into', 'object': 'تلی از آوار'}, {'subject': 'درختان و علف\u200cهای هرز', 'predicate': 'grow on', 'object': 'تلی از آوار'}, {'subject': 'تپه\u200cها', 'predicate': 'called locally', 'object': 'کول، کوتی، دین و دوین'}, {'subject': 'تپه\u200cها', 'predicate': 'located at', 'object': 'حاشیه ساحل دریا'}, {'subject': 'تپه\u200cها', 'predicate': 'have value for', 'object': 'کاوش و پژوهش باستان شناسانه'}, {'subject': 'چراغ علی تپه', 'predicate': 'located at', 'object': 'دهانه گوهر رود'}, {'subject': 'چراغ علی تپه', 'predicate': 'excavated by', 'object': 'عزت\u200cالله نگهبان'}, {'subject': 'چراغ علی تپه', 'predicate': 'also known as', 'object': 'تپه مارلیک'}, {'subject': 'تپه مارلیک', 'predicate': 'has not been scientifically excavated', 'object': 'true'}, {'subject': 'ساختمان\u200cهای دارای ارزش تاریخی', 'predicate': 'have been', 'object': 'مکرراً تعمیر و بازسازی شده\u200cاند'}, {'subject': 'بیشتر ساختمان\u200cهای تاریخی', 'predicate': 'lack', 'object': 'اسناد اولیه قابل اطمینان'}, {'subject': 'تاریخ ساختمان\u200cهای تاریخی', 'predicate': 'reconstructed by', 'object': 'شواهد غیرمستقیم مانند تاریخهای حک شده بر درهای ورودی، سنگ قبرها، ضریحه\u200cها یا تابوتها'}]
# --------------------
#
# context 5/5:
# 'فارسی از گذشته‌های دور، به ویژه از دوره یوآن تا آغاز سده بیستم، در چین از نقش مهمی برخوردار بوده‌است. تعامل ایران و چین از دوره ساسانی تداوم داشته‌است و در هنگام ایجاد جاده ابریشم این روابط به اوج رسید و پس از پیدایش اسلام این روابط توسعه پیدا کرد. آثار فارسی فراوانی همانند منهاج الطلب نوشته محمد بن حکیم زینینی در چین نوشته شده‌اند. با ایجاد دودمان مغولی یوآن، بسیاری از مسلمانان آسیای میانه و غربی به چین مهاجرت کردند که ایرانی‌ها و فارسی‌زبان‌ها بخش قابل توجهی از آن‌ها بودند و به این ترتیب در این دوره فارسی به یکی از سه زبان رسمی و زبان اول مسلمانان چین تبدیل شد.'
#   -> Extracted Entities: ['فارسی', 'دوره یوان', 'سده بیستم', 'چین', 'ایران', 'ساسانی', 'جاده ابریشم', 'اسلام', 'منهاج الطلب', 'محمد بن حکیم زینینی', 'دودمان مغولی یوان', 'مسلمانان آسیای میانه', 'ایرانی\u200cها', 'فارسی\u200cزبان\u200cها', 'زبان رسمی', 'مسلمانان چین']
#   -> Extracted Triples: [{'subject': 'فارسی', 'predicate': 'had important role in', 'object': 'چین'}, {'subject': 'تعامل ایران و چین', 'predicate': 'continued from', 'object': 'دوره ساسانی'}, {'subject': 'تعامل ایران و چین', 'predicate': 'reached peak during', 'object': 'ایجاد جاده ابریشم'}, {'subject': 'تعامل ایران و چین', 'predicate': 'developed after', 'object': 'پیدایش اسلام'}, {'subject': 'آثار فارسی', 'predicate': 'include', 'object': 'منهاج الطلب'}, {'subject': 'منهاج الطلب', 'predicate': 'written by', 'object': 'محمد بن حکیم زینینی'}, {'subject': 'منهاج الطلب', 'predicate': 'written in', 'object': 'چین'}, {'subject': 'دودمان مغولی یوان', 'predicate': 'caused migration of', 'object': 'مسلمانان آسیای میانه و غربی به چین'}, {'subject': 'ایرانی\u200cها', 'predicate': 'were part of', 'object': 'مسلمانان آسیای میانه و غربی مهاجر به چین'}, {'subject': 'فارسی\u200cزبان\u200cها', 'predicate': 'were part of', 'object': 'مسلمانان آسیای میانه و غربی مهاجر به چین'}, {'subject': 'فارسی', 'predicate': 'became', 'object': 'یکی از سه زبان رسمی در چین'}, {'subject': 'فارسی', 'predicate': 'became', 'object': 'زبان اول مسلمانان چین'}, {'subject': 'دوره یوان', 'predicate': 'is period of', 'object': 'دودمان مغولی یوان'}, {'subject': 'فارسی', 'predicate': 'had important role from', 'object': 'دوره یوان تا سده بیستم'}]
# --------------------

# %%
# Now do the same for all of the contexts
from tqdm import tqdm

def extract_knowledge_structured(passage: str) -> (List[str], List[dict]):
    """
    Implements the two-step HippoRAG extraction process using a system/user prompt structure.
    """
    try:
        ner_response = ner_chain.invoke({"passage": passage})
        entities = ner_response.named_entities
        # print(f"  -> Extracted Entities: {entities}")
    except Exception as e:
        print(f"  -> Error during structured NER extraction: {e}")
        return [], []

    if not entities:
        print("  -> No entities found, skipping triple extraction.")
        return [], []

    try:
        entities_str = json.dumps(entities, ensure_ascii=False)
        openie_response = openie_chain.invoke({"passage": passage, "entities": entities_str})
        triples = [triple.model_dump() for triple in openie_response.triples]
        # print(f"  -> Extracted Triples: {triples}")
        return entities, triples
    except Exception as e:
        print(f"  -> Error during structured OpenIE extraction: {e}")
        return entities, []
    
    

knowledge_graph_data = []

print("Starting Knowledge Graph Extraction (only 300 context from pquad dataset)")
## we took 300 contexts from pquad dataset, while our test questions only require 32 contexts
# this is only because of the budget limit of the API calls

i = 0
for context_passage in tqdm(all_context[:300]):
    extracted_entities, extracted_triples = extract_knowledge_structured(context_passage)

    if extracted_triples:
        knowledge_graph_data.append({
            "id": i,
            "passage": context_passage,
            "entities": extracted_entities,
            "triples": extracted_triples
        })
        
    i += 1
# Out:
# Starting Knowledge Graph Extraction (only 300 context from pquad dataset)
# 100%|██████████| 300/300 [44:53<00:00,  8.98s/it]

# %%
# save the knowledge graph data to a json file
with open('knowledge_graph_triples_structured.json', 'w', encoding='utf-8') as f:
    json.dump(knowledge_graph_data, f, ensure_ascii=False, indent=4)

# %% [markdown]
# # Check prepared data

# %%
import pandas as pd
import igraph as ig
import json
from collections import defaultdict

# %%
with open('knowledge_graph_triples_structured.json', 'r', encoding='utf-8') as f:
    knowledge_graph_data = json.load(f)
df_kg = pd.DataFrame(knowledge_graph_data).drop(columns=['id'])
df_kg.head()
# Out:
#                                              passage  \
# 0  ایرانیان از ۱۳۱۶ این دریا را مازندران می‌نامند...
# 1  پیروزی رونالد ریگان در ابتدای دهه ۱۹۸۰ در حقیق...
# 2  محمد غفاری در خانواده‌ای هنرمند و سرشناس در رو...
# 3  منطقه گیلان دارای بارش فراوان است تا جایی که ب...
# 4  فارسی از گذشته‌های دور، به ویژه از دوره یوآن ...
#
#                                             entities  \
# 0  [ایرانیان, ۱۳۱۶, دریای مازندران, دریای خزر, ۵۰...
# 1  [رونالد ریگان, دهه ۱۹۸۰, جناح راست حزب جمهوری‌...
# 2  [محمد غفاری, کله, کاشان, ابوتراب غفاری, تهران,...
# 3  [گیلان, ۱۲۰ سانتی‌متر, چراغ علی تپه, دهانه گوه...
# 4  [فارسی, دوره یوان, سده بیستم, چین, ایران, ساسا...
#
#                                              triples
# 0  [{'subject': 'ایرانیان', 'predicate': 'نام این...
# 1  [{'subject': 'رونالد ریگان', 'predicate': 'پیر...
# 2  [{'subject': 'محمد غفاری', 'predicate': 'born ...
# 3  [{'subject': 'گیلان', 'predicate': 'has annual...
# 4  [{'subject': 'فارسی', 'predicate': 'had import...

# %%
all_named_entities = set()
all_triples = []
for entity_list in df_kg['entities']:
    all_named_entities.update(entity_list)
    
for triples in df_kg['triples']:
    for triple in triples:
        all_triples.append((triple['subject'], triple['predicate'], triple['object']))
    
print(f"Total unique named entities: {len(all_named_entities)}")
print(f"Total unique triples: {len(all_triples)}")
# Out:
# Total unique named entities: 3397
# Total unique triples: 4329

# %%
all_named_entities
# Out:
# {'بدیهی گرایی فلسفی',
#  'هسته',
#  'آتئیست',
#  'فیلم',
#  'مک\u200cفارلین',
#  'ALGOL ۶۸',
#  '۱۹۴۲',
#  'تغییر آبی',
#  'آسیایی ۱۹۹۴',
#  'آبشار نیاگارا',
#  '+Google',
#  '۶۳۹ میلیارد دلار',
#  'بعد از جنگ',
#  'دهه ۹۰',
#  'شاخه غربی زبان\u200cهای ایرانی',
#  'تیٔاتر',
#  'زلاتان ابراهیموویچ',
#  'آزمایشگاه\u200cهای بل',
#  '۵۰۰ هزار نفر',
#  'تب',
#  'نفت سفید',
#  'وبگاه\u200cهای شبکه\u200cهای اجتماعی',
#  'لیگ برتر فصل ۸۳–۸۲',
#  'سید روح\u200cالله خمینی',
#  'فایفر',
#  'پیج',
#  'شلوار',
#  'بی\u200cخدایی قوی',
#  '۲۷ کشور اروپایی',
#  'ترکان',
#  'مسیحیان',
#  'مسیحیت',
#  'بلاک پارتی',
#  'آزمایش سکوی پرتاب',
#  'گوسفند وحشی',
#  'قاجار',
#  'ندانم\u200cگرایان',
#  'سناتور هیوبرت هامفری',
#  'کوه قارن',
#  'رابرت برترام سرژانت',
#  '۲۹ سال',
#  'موازی',
#  '۱۲۶٬۴۷۶٬۰۰۰ نفر',
#  'تولید مواد شیمیایی',
#  'شیخ کلینی',
#  'Version Control',
#  '۳۲ تیم',
#  'قباد اول',
#  'فانک',
#  '۲۰۰۰۰ سال پیش',
#  'هیوستون',
#  'آغاجاری',
#  'مراد بخش',
#  'پَرِ مرغ',
#  'اردیبهشت ۱۳۵۹',
#  'اووزان',
#  'اینترنت پروتکل اینترنت',
#  'semi-finals',
#  'ایلین وورنوس',
#  'اشکال\u200cزدایی',
#  'اردوان پنجم',
#  '۱۹۳۱',
#  'وَرزا',
#  'فیلم سرزمین شمالی',
#  'رفع فشار',
#  'شاپور',
#  'آرش برهانی',
#  'چرم طبیعی',
#  'مهر یشت',
#  'لیگ آلمان',
#  'آلومینیوم',
#  'زنان',
#  'جام حذفی ایران',
#  'اردشیر بابکان',
#  'ایرانی\u200cآمریکایی\u200cها',
#  'دهه ۳۰ میلادی',
#  '۳ کارخانه نمک\u200cزدایی',
#  'انرژی',
#  '۶۵۱ میلادی',
#  '۱۹۶۰',
#  'پشته',
#  'مرحله بعدی جنگ',
#  '۱۹۶۲',
#  'دختران',
#  'دریای آبسکون',
#  'هیولای اسپاگتی پرنده',
#  '۵۲۵',
#  'Gelan',
#  '۶۴ تخت بیمارستانی',
#  'جامعه',
#  'Aşıq',
#  '۱۲ ژوئیه ۱۰۰ پیش از میلاد',
#  'خلیفهٔ جدید',
#  'اپیدمیولوژیک',
#  'انقلاب ایران',
#  'بلاش اشکانی',
#  'هورون',
#  'احمد بن محمد بزنطی',
#  'خداوردی',
#  'دژهای قفقاز',
#  'الله',
#  'سی و نهمین ریٔیس\u200cجمهور ایالات متحده آمریکا',
#  '۸ خرداد ۱۳۹۹',
#  'قانون اساسی ژاپن',
#  'دلالان اسلحه اسرائیلی',
#  'ریاست جمهوری',
#  'اکسید',
#  'مایکل مارتین',
#  'تهران',
#  'شهر لاهیجان',
#  'پشتو',
#  'گسکر',
#  'راموس',
#  'گروه',
#  'سه\u200cماهه آخر سال ۲۰۱۰',
#  'تولم',
#  'شورای ترویج موسیقی ملی',
#  '۵۸۵ میلیون فوت مکعب گاز طبیعی',
#  'اسفند ۱۳۵۸',
#  'جام جهانی ۱۹۹۴',
#  'ابومسلم مشهد',
#  'غرق شدن',
#  '۸ ایستگاه تقویت فشار',
#  'دریای میرتو',
#  'موسیقی سبک لاتین',
#  'بابل',
#  'مراکشی',
#  'اصلاح بزرگ',
#  '۱۸ دسامبر ۱۸۶۵',
#  'نسل اول اینترنت',
#  'کاظمین',
#  'لس آنجلس',
#  'اکسیژن مصنوعی',
#  'بهرام سوم',
#  'استاندارد',
#  'تخت جمشید',
#  'Mare Caspium',
#  'سغدی',
#  'Caspian Sea',
#  'دهانی',
#  'انوشیروان',
#  'JVM',
#  'یتیم خانه',
#  'جنبش اخوان المسلمین',
#  'النا ایوانوونا دیاکونووا',
#  'شبکه استانی صدای مرکز گیلان',
#  '۲۰۰',
#  'وزارت بازرگانی و صنعت',
#  'باند موسیقی',
#  'کریسلیگا نوردماین',
#  'راهبان بودائی',
#  'شهریور ۱۳۷۲',
#  'کارخانه\u200cهای فراوری ماهی',
#  'Beta',
#  'المپیک لندن ۲۰۱۲',
#  'استوا',
#  'برنامه\u200cریزی کنفرانس',
#  'James Earl Carter Jr.',
#  'دیگو',
#  'طبری',
#  'اَرْتَه\u200cکْسِرْکْسِسْ',
#  'فِرَقِ اسلامی',
#  'یوهان پاخلبل',
#  '۱۲ کیلومتری جنوب رشت',
#  'اندرو جانسون',
#  'رادیو تالشی',
#  'جف بریجز',
#  '۲۳ ساعت و ۵۶ دقیقه و ۴ ثانیه',
#  'کارخانه\u200cهای روغن',
#  'لاتین گرمی',
#  'تورانی',
#  'راسول',
#  'خلیج سارونیک',
#  'فضاهای نام',
#  'مه ۲۰۱۰',
#  'متفقین',
#  'اکسیژن جامد',
#  'خمام',
#  'Gasoline',
#  'رئال مادرید',
#  'چهاردهمین اصلاحیه قانون اساسی',
#  'استراتوسفر',
#  'Stanislav, 1993',
#  'صفحه اصلی',
#  'استان خراسان',
#  'اشکانیان',
#  'شبه جزیره عربستان',
#  'ابوتراب غفاری',
#  'سال ۱۹۸۰',
#  'مجله پریمیر',
#  '۱۳ ژانویه ۲۰۱۱',
#  'قونیه',
#  'O۲',
#  'جام جهانی فوتبال',
#  'iOS',
#  'نوجوانان',
#  'مجلس یازدهم',
#  '۱۶۵۸م',
#  'دفتر بین\u200cالمللی کتاب برای نسل جوان',
#  'خواهر',
#  'سالوادور دالی ای کاسی',
#  'بهشت',
#  'مسلمانان چین',
#  'دولت فدرال',
#  'صادق خان زند',
#  'ملبورن',
#  'دودمان پهلوی',
#  'ثوابت',
#  'شمشیر',
#  'ذرات گرد و غبار',
#  'بی\u200cخدایی منفی',
#  'بز وحشی',
#  'چارت لاتین بیلبورد',
#  '۱۸ امتیاز',
#  'سیاست فئودالی',
#  'مت دیمون',
#  'صادق خلخالی',
#  'C',
#  'سده هفتم',
#  'مرکز درمانی شهید بهشتی',
#  'کنستانتین بزرگ',
#  'بیستون',
#  'راک',
#  'معمر قذافی',
#  'سید محمدحسین طباطبایی',
#  'ساحل شرقی قاره آسیا',
#  'قالب توابع',
#  '۹ ژوئن ۱۹۸۱',
#  'رابرت ردفورد',
#  '۷۵ کشور',
#  'لات',
#  'اقیانوس منجمد شمالی',
#  'انتخابات پارلمانی ۲۰۱۰',
#  'هلیوپاز',
#  'گوگل ارث',
#  'سلوکیه',
#  'دسامبر ۲۰۰۰',
#  'اهل بیت',
#  '۳ سپتامبر ۲۰۰۱',
#  'دیلمیان',
#  'سال ۱۱۶۳',
#  'لولمان',
#  'اواسط دوران اشکانی',
#  'دومین کشور دنیا',
#  'بی\u200cخدایی سخت',
#  'حکومت موقت سوسیال دموکرات\u200cها',
#  'وانیل',
#  '۱۵۹۲',
#  'بزیرکسلیگا ماین-هسن',
#  'بلشویک\u200cها',
#  '۲۰۰۴',
#  '۱۹۹۸',
#  'اکمل الدین احسان اوغلو',
#  'شوروی',
#  '۸ درصد',
#  'آسیای شرقی',
#  'حسین طاهرزاده',
#  'بختیاری زاده',
#  '日本',
#  'بند ۴۶',
#  'نام تابع',
#  'خاویار',
#  'ایزد پیروزی',
#  '۹۰۰ الی ۱۰۰۰ متر',
#  'بازی\u200cهای ویدئویی',
#  'مثانی',
#  'سمپدوریا',
#  'نیویورک',
#  '۱۹۸۳',
#  '۱۳ میلیون نفر',
#  'میدان نفتی شادگان',
#  'دریای سیاه',
#  'فلیکر',
#  'رپ تور نیویورک',
#  'دیشمه سچمه دیشمه',
#  'واشینگتن، دی.سی.',
#  'اسپورتینگ',
#  'نرم\u200cافزار کاربردی',
#  'فشار اتمسفر',
#  'آلیاژهای منیزیم',
#  '۱۹۷۵',
#  'تراز بافت',
#  'لغت\u200cنامه دهخدا',
#  'شاه شجاع',
#  'ایتالیایی\u200cها',
#  'بابُل',
#  'سرب',
#  'روح\u200cالله خمینی',
#  'پایتخت کانادا اُتاوا',
#  'آهنگ شعف',
#  'رنگ سبز بیدی',
#  'وی مثل وندتا',
#  'سمت چپ قلب',
#  'میر ظهیرالدین',
#  '۳۴٪',
#  'جنگ سرد',
#  'اورانوس',
#  'اسکلت\u200cبندی',
#  'سید مصطفی خمینی',
#  'سازمان ملل متحد',
#  '۶ طبقه',
#  'جناح راست حزب جمهوری\u200cخواه',
#  'اربابان تولیدکننده چای',
#  'خداوند',
#  'کاخ پادشاهی ایران',
#  'جناب بهاء الملک',
#  'لکی',
#  'انگلیسی بریتانیایی',
#  'راوی',
#  'ساختمان جدید',
#  'گوردیانوس',
#  'تئودوسیوس',
#  'لیگ قهرمانان آسیا',
#  'قوی سیاه',
#  'نذیر',
#  'کنستانتین',
#  'دومین کشور پهناور جهان',
#  'مسجدسلیمان',
#  'ایرانی\u200cها',
#  '۱۹۵۳',
#  'چَنگِ رودکی',
#  'اخلاقیات',
#  'لینکلن',
#  'عمان',
#  '۱۹۷۴',
#  '۲۵ متر',
#  '۳۰ نوامبر',
#  'چای سبز',
#  'آب\u200cهای تحت\u200cالارضی',
#  'Grand Old Party',
#  'بارسلونا',
#  'بخشی',
#  'مرحله یک چهارم نهایی',
#  'مشروطیت',
#  'اوگت ۲۰۱۵',
#  'مَآثِرُ الْکُبَراء فی تاریخِ سامَرّاء',
#  '۱۹۲۱',
#  '۱۶ ژوئن سال ۱۹۴۳',
#  '۲۰۱۲',
#  'سامرا',
#  'امپراتوری ژاپن',
#  'ترانهٔ قهرمان',
#  'اتیوپی',
#  'ابن صباغ',
#  'اَشتاد یشت',
#  'تیمجان',
#  '۱۲۲۷ ه\u200d.ق',
#  'پاهای لوله\u200cای',
#  'تعمیر و نگهداری',
#  'خارجی\u200cها',
#  'فصل',
#  'سیب زمینی',
#  'ماده حاجب میکرو حباب پر از گاز',
#  '۳۴ درصدی',
#  'کریکت (بیست۲۰)',
#  'آزمایش اندیشه\u200cها',
#  'گاز آمونیاک',
#  'ثروتمند',
#  'ماهنامه تئوریک حزب توده',
#  'کودکان زیر سه سال',
#  'رنگ سفید',
#  'هونگ\u200cبین',
#  'صراط مستقیم',
#  'سانتو دومینگو',
#  'بیست\u200cوسه سالگی',
#  'بهمش',
#  'رومی\u200cها',
#  'کربن مونوکسید',
#  'بریلیم',
#  'سرود نفت',
#  'امپراتوری عثمانی',
#  'مسابقات نیمه\u200cنهایی',
#  'نوع جی رشته اصلی',
#  'وایمار',
#  '۲۰۰۵ میلادی',
#  'ذَهَبی',
#  'دموکرات',
#  'بشیر باباجان\u200cزاده',
#  'شاهنشاهی اشکانی',
#  'میِ ناب',
#  'فارس',
#  'اپل تی\u200cوی',
#  'فیفا',
#  'شهر بنغازی',
#  'مجراها',
#  'کرد',
#  '۶۳۷۹ کیلومتر',
#  'منطقه خزر',
#  'نزهه القلوب',
#  'فیلم ماگنولیاهای فولادی',
#  'تاتی',
#  '۵ کارخانه نمک\u200cزدایی',
#  '۲۰۰۵',
#  'ایرانشهر',
#  'فیلم ماشین\u200cکار',
#  'قرن بیستم',
#  'کتاب خدمت و خیانت روشنفکران',
#  'سید حسین طباطبایی بروجردی',
#  'بادکش',
#  'لیست اشکالات شناخته شده',
#  'سیستم عامل اندروید',
#  'گریسی',
#  'موقعیت اصلی',
#  'دههٔ ۱۹۹۰',
#  'فرشید مثقالی',
#  'کاسپیس',
#  'سال ۱۹۷۹',
#  'کنسرت مایستر',
#  'بهار دلنشین',
#  'سوئدی',
#  'سه سال',
#  'دیوَیسنَه',
#  'فریزر',
#  'اعضای ثابت تابع',
#  'مقدم آگوستین',
#  'فلسطینیان',
#  'جماعت اخوان المسملین',
#  'کامرون',
#  'شاه سلطان حسین',
#  'شبکه\u200cهای اجتماعی',
#  'Carus',
#  'کاتبان',
#  'جنگ',
#  'شرکت ملی مناطق نفت\u200cخیز جنوب',
#  'آبان',
#  'تگزاس',
#  'یک میلیون دلار آمریکا',
#  'دور نخست',
#  '۱۱ مه ۱۹۰۴',
#  '۶۱۴ هزار بشکه نفت خام',
#  '۲۰۱۸',
#  'رود لارنس',
#  'ترانه فانک',
#  'عیسی رمضانی',
#  'سال ۳۹ پیش از میلاد',
#  'Michigan',
#  'سال ۴۸۵ ه\u200d.ق',
#  'GOP',
#  'کنستانتین اول',
#  '۲۴۱–۲۷۱ م',
#  'VIXX',
#  'سالوادور',
#  'تبیان',
#  'Computics',
#  'اختراع سفالگری',
#  '۱۳۸۵',
#  'سورن\u200cها',
#  '۶ فرسنگ',
#  'تهاجم ژاپن به کره',
#  'بنجامین فرانکلین',
#  'یای نستعلیق',
#  'خلیج پاگاستی',
#  'نیویورک تایمز',
#  'گل\u200cهای صحرایی',
#  'کردهای کرمانج',
#  'شهر نیویورک',
#  'نیروی هوایی اردن',
#  'Caspisches see',
#  'قرعه\u200cکشی',
#  'بازگشته',
#  'برتراند راسل',
#  'سمانه',
#  'کریستیانو رونالدو',
#  'کاسپین',
#  'یلک',
#  'امپراتور',
#  'نوع داده منطقی',
#  'پاپ',
#  '۱۹۰۰ تا ۱۹۵۰',
#  'اَردوی سُور',
#  'قصر دوک وایمار',
#  'بهرام دوم',
#  'یک و نیم میلیارد نفر',
#  'رَشن یسشت',
#  'وَنَند یشت',
#  'بی. یو. جی. مافیا',
#  'قلعه آگره',
#  'کاراکالا',
#  'مدرسه دارالفنون',
#  'سوزلر دیشمه سی',
#  'خانم جردن',
#  '۱ اوت ۱۹۰۳',
#  '۱۹۲۹',
#  'جام ملت\u200cهای آسیا ۱۹۹۶',
#  'بدن\u200cسازی',
#  'آزادی',
#  'فلسفه پدیدارشناسی',
#  'اعتقاد نامه نیقیه',
#  '۶ امتیاز',
#  'یونس بن عبدالرحمن',
#  'athée',
#  'شبه جزیره کره',
#  'کره جنوبی',
#  'محمدرضا یوسفی',
#  'رواقیون',
#  'اسپارت',
#  'مول\u200cهاوزن',
#  'کلسیم',
#  'ناصبیان',
#  'شرکت مهندسی و توسعه نفت ایران',
#  '۲۸٫۹۰۰ متر مربع',
#  'ادبیات ژاپنی',
#  'فلسفه سیاسی بومیان',
#  'دهه ۱۹۵۰',
#  'ساوه',
#  'سن ۷ یا ۸ سالگی',
#  'اوداوارا',
#  'اوایل بهار',
#  'ماکرینوس',
#  'گربه\u200cهای بد',
#  'شهر اسماعیلیه',
#  'باران',
#  'هندی\u200cها',
#  'والی اصفهان',
#  'جاسم حسین',
#  'استان خراسان شمالی',
#  'علی\u200cاکبر شهنازی',
#  'ده استان',
#  'سلیمان',
#  'ناصر الدین شاه',
#  'اسکایپ',
#  'چاه شماره یک',
#  'مخازن ذخیره\u200cسازی',
#  '۱۶۷۵',
#  '۱۲ سال',
#  'زمان استراحت',
#  'یوگسلاوی',
#  '۱۳۸۳',
#  'افغانستان',
#  'چای فوری',
#  'دماغه کواولی',
#  'کواد یکم',
#  'اقیانوس\u200cها',
#  'حیره',
#  'بدون تعهد',
#  '۴ برابر شدن قیمت نفت',
#  'پوستر',
#  'کارگردانان',
#  'گاز نفت مایع',
#  'لنور',
#  'آسیای باختری',
#  'شاهپور اول',
#  'پانصد هزار دینار طلا',
#  'اردورف',
#  'رودها',
#  '۴ دههٔ گذشته',
#  'Voice, Visual, Value in Excelsis',
#  'مرکز شهر تهران',
#  '۴۵ کیلوگرم',
#  'جاوا',
#  'شادی رپها',
#  '۳۷۲ ه\u200d.ق',
#  'دکترین',
#  'مرحله سوم',
#  'یزدگرد اول',
#  'اکسیداسیون چربی',
#  '۱۰ رجب ۱۹۵ ه\u200d.ق',
#  'خلیج دیکیلی',
#  'زبان عربی',
#  'ایرانی',
#  'ریاست جمهوری آمریکا',
#  'Doppler effect',
#  'لاهیجان',
#  'زبان C دارای کلاس',
#  'آئورلیا کوتا',
#  'شمال غرب اوراسیا',
#  '۲۵۶۰۰۰ کیلومتر مربع',
#  'موزه',
#  '۱۲ اکتبر ۱۹۰۱',
#  'ستاره\u200cها',
#  'سکایی',
#  'سونوگرافی تقویت شده با کنتراست',
#  'حکم',
#  'نیروی هوایی شاهنشاهی ایران',
#  'تیشتر',
#  'ابوحمزه',
#  '۱۳',
#  'سنی',
#  '۱۳۹۰',
#  'صحنه',
#  'مارکوس آنتونیوس',
#  'کمیته تهران',
#  'اعداد اکتان',
#  'تونس',
#  'خیابان سی تیر',
#  '۴۲۴ رویداد',
#  'جی۸',
#  'فرهنگ چینی',
#  'آتن',
#  '۱۲۹۰ ه\u200d.ق',
#  'سی ام ژوئیه ۲۰۰۹',
#  'ایلخانان مغول',
#  'سرشماری سال ۲۰۲۰',
#  '۱۳٪',
#  'دولتشاه سمرقند',
#  '۱۸۷۹',
#  'ژنو',
#  'حدیثِ ثَقَلَیْن',
#  'پارس',
#  'پیتر ناور',
#  'دبیرستان',
#  '۶۰ ق. م',
#  'خدایان',
#  'سلطان قلیچ اول',
#  '۱۹۹۷',
#  'جاده ابریشم',
#  'ویکتوریا دانشور',
#  'فینال',
#  'Calvin Gospel',
#  'دی جی',
#  'سفید',
#  'عراق عجم',
#  'جورج بوش (پسر)',
#  'آرگون',
#  'تفرش',
#  'تیم استقلال تهران',
#  'اروپایی',
#  'شورای عالی موسیقی رادیو',
#  'فیلم «محوطه»',
#  'جهاد اسلامی مصر',
#  'Contrapunctus XIV',
#  'زحل',
#  'خراسان',
#  'هند',
#  'مانتین ویو',
#  'رابرت اف. کندی',
#  'داده\u200cشناسی',
#  '۲ ماه',
#  'جنوب شرقی',
#  'فضل بن شاذان',
#  'زاماسپ',
#  'هُرمزد',
#  'رودسر',
#  'فلسفه سیاسی',
#  'حمدالله مستوفی',
#  'ایران-کنترا',
#  'ایران',
#  'ذوب آهن',
#  'Ecclesia Catholica',
#  'شاه تیم ۳ (جاک شخصیت)',
#  'بند ۲۸',
#  'رسانه\u200cها',
#  'ماه یشت',
#  '۱۹۶۹',
#  'بلوچی',
#  'امشاسپندان',
#  'شارون',
#  'بیل',
#  'نخستین جشنواره عاشیقلار دئیشمه سی',
#  'ده میلیون کاربر',
#  'ال\u200cپی\u200cاف',
#  'اگزیستانسیالیسم',
#  'نزهت\u200cالقلوب',
#  'عدالت رومیان',
#  'احزاب نماینده اصول عدالت',
#  'RD Instruments',
#  'حقوق بشر',
#  'وسلی اسنایدر',
#  'مرز مشترک کانادا با ایالات متحده',
#  'وزارت دفاع ایالات متحدهٔ آمریکا',
#  'پالایش',
#  '۴۳۸۰۰۰ کیلومتر مربع',
#  'خرس قهوه\u200cای',
#  'لهجه خرم\u200cآبادی',
#  'کوچصفهان',
#  'سرعت',
#  'گروه داده\u200cشناسی',
#  'انتقال به سرخ',
#  'برنامهٔ گل\u200cها',
#  'سیصد سال قبل از میلاد مسیح',
#  'ناروهیتو',
#  'درفش کاویانی',
#  '۲۰۰۲',
#  'تیم ملی',
#  'شهروندان مهاجر ترک تبار',
#  'جزیره شگفت انگیز',
#  'NISOC',
#  'عدد اکتان سوخت هواپیمای بریتانیایی',
#  'علی پروین',
#  'منبع نور نجومی',
#  'متان',
#  'ستاره دریایی',
#  'رودخانه جراحی',
#  'مدرسهٔ آمریکایی تهران',
#  'هفت خواهران نفتی',
#  'ازبکستان',
#  '۳۰ کیلومتر',
#  'آتیئیسم',
#  'ابن بلخی',
#  'یاقوت حموی',
#  'تقارن شعاعی',
#  'بامداد',
#  'منظومهٔ خورشیدی',
#  'شرکت ملی مناطق نفتخیز جنوب',
#  'امپراتوری روم شرقی',
#  'گویش بوشهری فارسی',
#  'خردسالان',
#  'تورنتو',
#  'اسکار بهترین بازیگر نقش اول مرد',
#  'مزدک',
#  'لس\u200cآنجلس',
#  'لنین',
#  'سرهنگ گاسپار دروویل',
#  'اکسیژن خالص',
#  'شایعات',
#  'اوت ۲۰۱۲',
#  'شَبْلَنْجی',
#  'گیلؤن',
#  'منظومهٔ شمسی',
#  'ادبیات عرب',
#  'گروه جنوب غربی',
#  'قرن ۱۶ میلادی',
#  'یاشار',
#  'آیپدها',
#  'درفش\u200cهای بزرگ و کوچک ایرانیان',
#  'خیرالدّین زِرِکْلی',
#  '۷۷۰۰۰۰ کیلومتر مکعب',
#  'کیان',
#  'لیگ گایٔولینا سادوست',
#  'ژاپنی',
#  'سیزدهمین اصلاحیه قانون اساسی ایالات متحده آمریکا',
#  'فضای میان\u200cستاره\u200cای',
#  'پوسته',
#  'شمال قاره آمریکای شمالی',
#  'سکه\u200cهای بخارایی',
#  'کهکشان\u200cها',
#  'خوانندهٔ جهانی پاپ',
#  'گوگل+',
#  'اسپایک',
#  'N۲',
#  'بابک',
#  'اوسط دهه ۱۹۵۰',
#  'کارگران معدن',
#  'توماس وودرو ویلسون',
#  'Aşık',
#  'تورج دریایی',
#  'آلمیروس',
#  '۲۰۱۹',
#  'متوکل',
#  '۱۹۸۷',
#  'زمان جنگ',
#  'لیگ قهرمانان اروپا',
#  '۱۳۷۷',
#  'فرهاد کاظمی',
#  '۱۹۵۶',
#  'کتابخانه\u200cهای کد پایه',
#  'دفاتر ثبت منطقه\u200cای اینترنت',
#  'سیستم تورنمنت',
#  'ACM',
#  'TCP/IP',
#  'بند ۵۹',
#  'تراولرز کمپانی',
#  'کبک',
#  'قرن چهاردهم میلادی',
#  'زمین',
#  'حاجبِ متوکل',
#  'امید کردستانی',
#  'خواننده رپ',
#  'روسی',
#  'نوبخت اهوازی',
#  '۱۳۸۷',
#  'برهان',
#  'ستاره',
#  'آزمایشگاه',
#  'مراسم چای آنیمیستی',
#  'گندی شاپور',
#  'ارِغنه',
#  'ژوستین یکم',
#  'مای\u200cاسپیس',
#  'عاشیق حسن اسکندری',
#  'گسولین',
#  'شیءگرایی',
#  'لباس سوزن\u200cدوزی شده',
#  'ویلی',
#  'روسیه',
#  '۱۳۴۳',
#  'فب ۵ فریدی',
#  'برده داری',
#  'یونانی',
#  'B3 فسفودی استراز',
#  'تیم\u200cهای تجاری',
#  'اَلْاِنتصار',
#  'محمد بن حکیم زینینی',
#  'هوشنگ مرادی کرمانی',
#  'دزفولی',
#  'بنزین',
#  'افسانه بگر ونس',
#  'لوئیس بونوئل',
#  'بوسنی هرزگوین',
#  'قانون اساسی',
#  'یزید بن عبدالله',
#  'ارجاعات',
#  'وَیو',
#  '۲۱ اردیبهشت سال ۱۳۰۸ خورشیدی',
#  'پرتو اولتراسوند',
#  'مدرسه تحصیلات تکمیلی فاینانس وین',
#  'سنه ۱۳۸۱ میلادی',
#  'ویل اسمیت',
#  'مرداد ۱۲۹۳',
#  'پاراگوئه',
#  'JNI',
#  'نخست\u200cوزیر ژاپن',
#  '۱۲۱ هزار نفر',
#  'سایپا',
#  'لری پیج',
#  'هخامنشی',
#  'پاشازاده',
#  'خلیج\u200cها',
#  'بند ۳۵',
#  'غرب ایران',
#  'کن',
#  'ماسه',
#  'شاهنشاهي اشكاني',
#  'قیام سربداران',
#  '#define max(x, y) ((x)> (y) ? (x) : (y))',
#  'گانگرن گازی',
#  'اذینه پالمیرایی',
#  'ریٔیس هیئت مدیرهٔ توییتر',
#  '۱۹۸۹',
#  'وزارت بهداشت و رفاه',
#  'یعقوب آژند',
#  'سال ۱۳۳۹',
#  'Artaxérxēs',
#  'اسرائیل',
#  'لیگ برتر فوتبال ایران ۸۸-۸۷',
#  'کمپانی ضبط',
#  'نوازنده ویلن',
#  'ژان باپتیست لولی',
#  'لیتوسفر',
#  'سوریه',
#  'مراسم اسکار',
#  'چلیپای راستین',
#  'نیتروژن مایع',
#  'ترکمنستان',
#  'آیت\u200cالله',
#  'انتخابات اولیه درون حزبی',
#  'مرحله بتا',
#  'سیستم حکومتی ژاپن',
#  'قوای حاکم',
#  'مرحله پنجم',
#  'قوچ',
#  'جلال آل احمد',
#  'چای سرد فوری',
#  'قهوه فوری خشک و منجمد',
#  '۱۳۱۴ هجری قمری',
#  'اقیانوس آرام',
#  'شکسته\u200cتعلیق',
#  '۴ کارخانه نمک\u200cزدایی',
#  'طرح صلح ۱۴ ماده\u200cای ویلسون',
#  'روح',
#  '۹٬۹۸۴٬۰۰۰ کیلومتر مربع',
#  'امیرحسین صادقی',
#  'شیکوکو',
#  '۲۹۳',
#  'سدیم',
#  'بهرام یشت',
#  'وین',
#  'قورباغه',
#  '۱۹۵۱',
#  'آتئیسم',
#  '۲۱۸ میلادی',
#  'رقص ورزشی',
#  'ابن ارومه',
#  'جورج بوش پدر',
#  'مشتریان',
#  'بیسموت',
#  'جایزه گلدن گلوب بهترین بازیگر زن فیلم درام',
#  'هسته یونیکس',
#  'گراند میکسر دی اس تی',
#  '۲ روز در دره',
#  'گلدن گلوب',
#  'فوتبال دستی',
#  'کارخانه\u200cهای برنجکوبی',
#  'دریاچه وینیپگ',
#  'قانون',
#  'هیده\u200cیوشی',
#  'ادسا',
#  'جام در جام اروپا',
#  'ساخلو',
#  'شرکت استاندارد اویل کالیفرنیا',
#  'استان مازندران',
#  'شورای امنیت سازمان ملل',
#  'شبه جانوران',
#  'نیتروژن',
#  '۲۰۰۰',
#  'اکسیژن',
#  'دوزخ',
#  'هیرو',
#  'نفت\u200cهای صادراتی',
#  'سدنا ۹۰۳۷۷',
#  'اعراب',
#  'اروگوئه',
#  'ژنرال کنسول ایران',
#  'جایزه اسکار',
#  '۱۹۵ ه\u200d.ق',
#  '۱۳۰۰',
#  '۱۰ ژوئن ۱۹۸۲',
#  'دهه ۱۹۳۰ میلادی',
#  'بتمن آغاز می\u200cکند',
#  '۲۵ بیلیون بار دانلود',
#  'ویرایش ۲٫۰',
#  'شاهان کوشانی',
#  '۱۷۵ میلیون دلار',
#  '۱۹۱۰',
#  'هیئت وزیران',
#  'پهلوی',
#  'خطوط طیفی',
#  'دعبل خزائی',
#  'لری بالاگریوه ای',
#  'آهن',
#  'ناصرالدین\u200cشاه قاجار',
#  'ابن سِکّیت',
#  'پترول',
#  'قلعه نویی',
#  '۱۳۱۶',
#  'ریچارد نیکسون',
#  'قرن\u200cهای چهارم و هفتم',
#  'هادی',
#  'شرکت نفت مناطق مرکزی ایران',
#  'انجمن\u200cهای اسلامی',
#  'امپراتوری ساسانی',
#  'کیکرز آفن\u200cباخ',
#  'استفاده جهانی بتا',
#  '۲۰۱۶',
#  'هنری مانچینی',
#  'اهوازی',
#  'آینتراخت فرانکفورت',
#  'نپتون',
#  'نمودار آهنگ\u200cهای پاپ برتر',
#  'بورنموث',
#  'مرغ',
#  '۳۵ میلیون یورو',
#  'استرالیا',
#  'آمبولانس',
#  'عربها',
#  'بیرق\u200cهای ما',
#  'هفت عضو شورا',
#  'پاناتیناکوس یونان',
#  'امپراتوری آلمان',
#  'آی\u200cپد',
#  'لا اله الا الله',
#  '۳۶۵ روز و ۶ ساعت',
#  'خلیج استریمونی',
#  'تتش\u200cبن آلب ارسلان',
#  '۱۵۵۸',
#  'منابع رومی',
#  'نمک\u200cزدایی',
#  'نویسندگان',
#  '۱۳۸۸',
#  'Turologist',
#  'بلژیک',
#  'علی بن مهزیار اهوازی',
#  'کنفدراسیونی ایرکوییزها',
#  'پارینه\u200cسنگی پسین',
#  '۲۰۰۸',
#  'رشته کوه البرز',
#  'شبه جزیره آبشوران',
#  'آچوب باغلَمه (açub bağleme)',
#  '۱۸۶۵',
#  'رحیم',
#  'برنامهٔ «یادی از هنرمندان»',
#  'مُنشیان',
#  'آتریاد',
#  'رود بهمن\u200cشیر',
#  'اَرْتَخْشیر',
#  'الجزایر',
#  'لیبرال',
#  'ایالات متحده',
#  'ارمنستان ایران',
#  'تنزیل',
#  'دیسکو',
#  'شرکت ملی مناطق نفت\u200cخیزِ جنوب',
#  'بیگ سور',
#  'جلد ۱',
#  '۱۹۵۰',
#  'سوسیال دموکرات\u200cهای تندرو بلشویک',
#  'دوره یوان',
#  'طباطبایی',
#  'رادیو',
#  'ذکر',
#  'خلیفه',
#  'جیمز ارل کارتر جونیور',
#  'شوشان\u200cدخت',
#  'خیابان ناصرخسرو',
#  'عظیم',
#  'میانکاله',
#  '۷ امتیاز',
#  'آتیکا',
#  'ارکستر انجمن موسیقی ملی',
#  'رود سپیدرود',
#  'تعلیق',
#  'جام اتحادیه',
#  'مکتب خانه\u200cها',
#  'مس کرمان',
#  'سالوادور فلیپه ژاسینتو دالی دومنک',
#  'رالف حراری',
#  'رابرت دنیرو',
#  'مکه',
#  'رسانه\u200cهای گروهی ایران',
#  'اوستایی',
#  ...}
