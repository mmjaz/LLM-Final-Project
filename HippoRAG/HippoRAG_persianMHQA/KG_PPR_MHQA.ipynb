# %%
import json
from sentence_transformers import SentenceTransformer, util
import torch
import numpy as np
from tqdm import tqdm
import pandas as pd

# %%
with open("knowledge_graph_triples_structured.json", 'r', encoding='utf-8') as f:
    knowledge_data = json.load(f)

df_kg = pd.DataFrame(knowledge_data)
df_kg
# Out:
#       id                                            passage  \
# 0      0  آفریقای جنوبی با نام رسمی جمهوری آفریقای جنوبی...
# 1      1  مانجاری فاندیس مدل و هنرپیشه اهل هند است.\nمان...
# 2      2  لوک اسکای‌واکر شخصیتی تخیلی و قهرمان داستان در...
# 3      3  مارشال‌های آمریکایی فیلمی محصول سال ۱۹۹۸ آمریک...
# 4      4  کیران دسای (Kiran Desai) (زاده ۳ سپتامبر ۱۹۷۱)...
# ..   ...                                                ...
# 465  465  تهدید سه‌گانه (به انگلیسی: Triple Threat) نام ...
# 466  466  تریپل اکس (به انگلیسی: XXX) فیلمی است محصول سا...
# 467  467  جیمز جوزف براون جونیور خواننده، ترانه‌سرا و نو...
# 468  468  آدامانتیوس کورائیس یک پژوهشگر یونانی بود که به...
# 469  469  توبی فلندرسون  یک شخصیت تخیلی در مجموعه تلویزی...
#
#                                               entities  \
# 0    [آفریقای جنوبی, جمهوری آفریقای جنوبی, جنوب آفر...
# 1    [مانجاری فاندیس, هند, ۲۰۰۸, سریال اگه بدونی یا...
# 2    [لوک اسکای‌واکر, جرج لوکاس, مارک همیل, جنگ ستا...
# 3    [مارشال‌های آمریکایی, ۱۹۹۸, آمریکا, استوارت بر...
# 4    [کیران دسای, Kiran Desai, ۳ سپتامبر ۱۹۷۱, هند,...
# ..                                                 ...
# 465  [تهدید سه‌گانه, Triple Threat, جسی وی. جانسون,...
# 466  [تریپل اکس, XXX, ۲۰۰۲, راب کوهن, مایکل روف, ری...
# 467  [جیمز جوزف براون جونیور, آمریکا, موسیقی فانک, ...
# 468  [آدامانتیوس کورائیس, یونان, جنگ استقلال یونان,...
# 469  [توبی فلندرسون, مجموعه تلویزیونی کمدی آمریکایی...
#
#                                                triples
# 0    [{'subject': 'آفریقای جنوبی', 'predicate': 'ha...
# 1    [{'subject': 'مانجاری فاندیس', 'predicate': 'i...
# 2    [{'subject': 'لوک اسکای‌واکر', 'predicate': 'i...
# 3    [{'subject': 'مارشال‌های آمریکایی', 'predicate...
# 4    [{'subject': 'کیران دسای', 'predicate': 'is', ...
# ..                                                 ...
# 465  [{'subject': 'تهدید سه‌گانه', 'predicate': 'En...
# 466  [{'subject': 'تریپل اکس', 'predicate': 'Englis...
# 467  [{'subject': 'جیمز جوزف براون جونیور', 'predic...
# 468  [{'subject': 'آدامانتیوس کورائیس', 'predicate'...
# 469  [{'subject': 'توبی فلندرسون', 'predicate': 'is...
#
# [470 rows x 4 columns]

# %%
all_nodes = set()
relation_edges = []

for item in knowledge_data:
    for triple in item['triples']:
        subject = triple['subject'].strip()
        obj = triple['object'].strip()
        
        if subject: all_nodes.add(subject)
        if obj: all_nodes.add(obj)

        relation_edges.append({
            "source": subject,
            "target": obj,
            "type": "relation",
            "label": triple['predicate']
        })

# %%
len(relation_edges), len(all_nodes)
# Out:
# (5694, 4644)

# %%
# Collect All Unique Nodes and Relation Edges
nodes_list = sorted(list(all_nodes))
node_to_id = {node: i for i, node in enumerate(nodes_list)}

node_to_id
# Out:
# {'1 ending': 0,
#  '1 representative': 1,
#  '1 to 4 teams': 2,
#  '1,925': 3,
#  '1000': 4,
#  '130 million dollars': 5,
#  '1949': 6,
#  '20 to 30 domestic and international flights': 7,
#  '2015': 8,
#  '23 ژوئیه 1967': 9,
#  '271': 10,
#  '3D': 11,
#  '3D film': 12,
#  '4200 متر': 13,
#  '45 متر': 14,
#  '5.0 اینچی': 15,
#  'AFC Champions League': 16,
#  'Adewale Akinnuoye-Agbaje': 17,
#  'Alice in den Städten': 18,
#  'Alien': 19,
#  'Alien film series': 20,
#  'America': 21,
#  'American computer-animated fantasy musical film': 22,
#  'American crime heist film': 23,
#  'American film': 24,
#  'American media company': 25,
#  'American music publishing company': 26,
#  'American producer': 27,
#  'American road thriller film': 28,
#  'American science fiction TV series': 29,
#  'Anne Frank Huis': 30,
#  'Apache': 31,
#  'Arthrose': 32,
#  'Bill Kendrick': 33,
#  "Bridget Jones's Diary": 34,
#  'British musician': 35,
#  'Bruce Willis': 36,
#  'Burnt': 37,
#  'By-product': 38,
#  'Call of Duty': 39,
#  'Celestia': 40,
#  'Celestیا': 41,
#  'Chase Tower': 42,
#  'Chris Laurel': 43,
#  'Color TV-Game': 44,
#  'Coneheads': 45,
#  'Cop Car': 46,
#  'Cul-de-sac': 47,
#  'D.B. Sweeney': 48,
#  'Dame Emma Thompson': 49,
#  'Dan Bilzerian': 50,
#  'Daniel Roebuck': 51,
#  'Doom': 52,
#  'Doom 4': 53,
#  'English actor': 54,
#  'Epic Records': 55,
#  'Eurovision Song Contest 2018': 56,
#  'Eve': 57,
#  'Extraction': 58,
#  'Frank Sheeran': 59,
#  'Frozen II': 60,
#  'Gina Carano': 61,
#  'Golden Globe Award': 62,
#  'Hell in a Cell': 63,
#  'Hell or High Water': 64,
#  'Henry Holiday': 65,
#  'Hg': 66,
#  'IPS-LCD': 67,
#  'Iko Uwais': 68,
#  'Inuit': 69,
#  'Invincible': 70,
#  'Japanese craftsman': 71,
#  'Japanese video game company': 72,
#  'Jewish diarist during جنگ جهانی دوم': 73,
#  'Justice League': 74,
#  'Justice League superhero team': 75,
#  'KHK': 76,
#  'Kellan Lutz': 77,
#  "Leone d'Oro": 78,
#  'Life': 79,
#  'Lifetime Achievement Award': 80,
#  'Love Sensuality Devotion: The Greatest Hits': 81,
#  'MGM': 82,
#  'Malick Sidibé': 83,
#  'Marisa Tomei': 84,
#  'Metro-Goldwyn-Mayer': 85,
#  'Modern Times': 86,
#  'Muslim': 87,
#  'NSAID': 88,
#  'Nabemono': 89,
#  'Naked Lunch': 90,
#  'Naproxen/esomeprazole': 91,
#  'Nazi persecution': 92,
#  'Nicholas M. Loeb': 93,
#  'Nightmare Alley': 94,
#  'Objectives': 95,
#  'Oenothera biennis': 96,
#  'Once Upon a Time in Mexico': 97,
#  'Open World': 98,
#  'OpenGL': 99,
#  'Osteoarthritis': 100,
#  'PSP': 101,
#  'Passeriformes': 102,
#  'Pay-Per-View event': 103,
#  'PlayStation Portable': 104,
#  'Poisson process': 105,
#  'Professional Wrestling': 106,
#  'Prometheus': 107,
#  'Promising Young Woman': 108,
#  'Rock Flour': 109,
#  'Scuderia Ferrari': 110,
#  'Selección de fútbol de España': 111,
#  'Shqiptarët': 112,
#  'Sir Charles Spencer Chaplin Jr.': 113,
#  'Sir Michael Caine': 114,
#  'Steven C. Miller': 115,
#  'Summer Altice': 116,
#  'SuperTux': 117,
#  'Tekumo kabushikigaisha': 118,
#  'The Burning Secret': 119,
#  'The Hunting of the Snark': 120,
#  'The Ides of March': 121,
#  'The Killing': 122,
#  'The Last Witch Hunter': 123,
#  'The Lost City of Z': 124,
#  'The Man Booker Prize': 125,
#  'The X-Files': 126,
#  'Thomas Stanley Holland': 127,
#  'Tower Green': 128,
#  'Triple Threat': 129,
#  'Une femme est une femme': 130,
#  'Vala': 131,
#  'Vimovo': 132,
#  'Vlach': 133,
#  'World Wrestling Entertainment, Inc': 134,
#  'XXX': 135,
#  'Yoshitoshi ABe': 136,
#  'You Rock My World': 137,
#  'Zanclean': 138,
#  'Zosui': 139,
#  'a group of criminals who rob the betting money of پیست اسب دوانی': 140,
#  'a liable contracting party': 141,
#  'a secret room in خانه آنه فرانک': 142,
#  'a very common disease': 143,
#  'a wealthy patron': 144,
#  'abandoned police car': 145,
#  'acid reducer': 146,
#  'action, adventure, first-person shooter, open world': 147,
#  'actor': 148,
#  'after ۱۹۹۰': 149,
#  'all English-language works': 150,
#  'all geographical regions': 151,
#  'all positions': 152,
#  'all works written in زبان انگلیسی': 153,
#  'all سَنگ\u200cها': 154,
#  'allows detailed and accurate designs': 155,
#  'ambitious man': 156,
#  'amount of money': 157,
#  'an actress': 158,
#  'an injured third party': 159,
#  'another film based on فار کرای': 160,
#  'another film in production': 161,
#  'any specific party': 162,
#  'arcade games': 163,
#  'balancing forgiveness and revenge': 164,
#  'best domestic and foreign film and television productions': 165,
#  'best film': 166,
#  'best film award': 167,
#  'best new English-language novel': 168,
#  'black and white photos of popular culture in باماکو in دهه ۱۹۶۰': 169,
#  'black comedy thriller': 170,
#  'book sales': 171,
#  'buildings': 172,
#  'burrow in the ground': 173,
#  'cash payment': 174,
#  'casting and pre-production of پنج عصر': 175,
#  'caught by her past': 176,
#  'character': 177,
#  'chemical, physical, pharmacological properties, antimicrobial spectrum, and mechanism of action': 178,
#  'collaborations of David Bowie, Tony Visconti, and Brian Eno': 179,
#  'collapse of ستارهها': 180,
#  'color in گرم منفی': 181,
#  'comedy drama': 182,
#  'compound and lobed leaves': 183,
#  'computer games in ۱۹۶۰s': 184,
#  'continuous-time process': 185,
#  'corrupt psychiatrist': 186,
#  'corrupt sheriff': 187,
#  'corruption and organized crime in labor unions': 188,
#  'country ranking': 189,
#  'discrete-time process': 190,
#  'diversity': 191,
#  'division of آلمان': 192,
#  'does not have similar quality': 193,
#  'eleventh studio album of David Bowie': 194,
#  'employment and financial crisis during رکود بزرگ': 195,
#  'execution at برج سبز': 196,
#  'families of graphical operating systems': 197,
#  'family farm in تگزاس': 198,
#  'few minor similarities with سیستم سرگرمی نینتندو game': 199,
#  'film': 200,
#  'film and television production and distribution': 201,
#  'film based on فار کرای': 202,
#  'filmmakers': 203,
#  'films': 204,
#  'first NBA championship': 205,
#  'first pop studio album of David Bowie': 206,
#  'first-person shooter': 207,
#  'first-person shooter video game': 208,
#  'five-year initial plan': 209,
#  'fossil reproduction not observable': 210,
#  'four approved gospels in عهد جدید': 211,
#  'fourth king of دودمان قاجار': 212,
#  'fourth most populous country in آفریقای زیرصحرا': 213,
#  'free and open-source text editor': 214,
#  'freedom in choosing how and when to complete objectives': 215,
#  'from ۲۰۱۴': 216,
#  'future worlds': 217,
#  'gives mission to followers to preach to all people': 218,
#  'global fame': 219,
#  'granite plaque at تایبرن': 220,
#  'grass and moss': 221,
#  'great figures of cinema and television in آمریکا': 222,
#  'handmade hanafuda cards': 223,
#  'her work with هانا بیکر is finished and wants new experience': 224,
#  'hidden blade and firearms': 225,
#  'hiding in خانه آنه فرانک and related life events of آنه فرانک': 226,
#  'high rating compared to other series': 227,
#  'his brother': 228,
#  'hole caused by broken branches in tree trunk': 229,
#  'home computer games': 230,
#  'host country of مسابقه آواز یوروویژن ۲۰۱۸': 231,
#  'impermeable cell wall compared to باکتری\u200cهای گرم مثبت': 232,
#  'in production': 233,
#  'in ۲۰۲۲': 234,
#  'increase damage counters and knock opponent off stage instead of killing': 235,
#  'indemnity': 236,
#  'independent': 237,
#  'industrial or edible': 238,
#  'ingredients in one group of چیراشی\u200cزوشی': 239,
#  'ingredients in the other group of چیراشی\u200cزوشی': 240,
#  'insects': 241,
#  'inter-event times in فرایند پواسون': 242,
#  'interaction between میدان مغناطیسی and جریان الکتریکی': 243,
#  'large mass of decayed plants and soil': 244,
#  'largest group of organisms where individuals can produce fertile offspring': 245,
#  'last absolute monarchy in ایران': 246,
#  'length of time or spatial distance': 247,
#  'lifetime achievement award': 248,
#  'lifetime artistic activity of cinema and television figures in آمریکا': 249,
#  'lifetime artistic activity of cinema and television great figures in آمریکا': 250,
#  "love and gaining woman's affection": 251,
#  'main character': 252,
#  'man lost in desert': 253,
#  'man lost in desert to home': 254,
#  'many cinema awards': 255,
#  'many countries': 256,
#  'many travelers and tourists': 257,
#  'marine commando': 258,
#  'martial arts and action': 259,
#  'martial arts instructor': 260,
#  'martial arts master': 261,
#  'materials': 262,
#  'media and entertainment company': 263,
#  'migration trends and natural disasters': 264,
#  'minority': 265,
#  'mixed inside گوهان سرکه\u200cزده': 266,
#  'mobile games': 267,
#  'modern Europe': 268,
#  'modern Europe for leisure': 269,
#  'modern blockbuster films': 270,
#  'more than ۲۰ languages': 271,
#  'mostly raw': 272,
#  'mud dome with entrance tunnel': 273,
#  'multinational game developer': 274,
#  'music arranger and vocal coach in شب یلدا': 275,
#  'music director of بوستو': 276,
#  'musician': 277,
#  'names of famous executed individuals': 278,
#  'nearly 50 years': 279,
#  'nesting hole in tree trunks as آشیانه': 280,
#  'no specific infection symptoms or کاهش دمای بدن': 281,
#  'nobles': 282,
#  'not all پرنده': 283,
#  'number of teams in لیگ قهرمانان آسیا': 284,
#  'on top of trees': 285,
#  'one group of چیراشی\u200cزوشی': 286,
#  'one of the best actresses of her generation': 287,
#  'one of the best series in آمریکا': 288,
#  'one of the most important competitions for filmmakers': 289,
#  'one of the most important literary awards in the world': 290,
#  'one of the most popular films in بالیوود in ۲۰۱۳': 291,
#  'one of the most popular films of بالیوود in ۲۰۱۳': 292,
#  'ongoing': 293,
#  'only اسلیم model produced limitedly': 294,
#  'open world design': 295,
#  'oral tablet pain reliever': 296,
#  'other business ventures': 297,
#  'other cities in ایران': 298,
#  'other developers': 299,
#  'other group of چیراشی\u200cزوشی': 300,
#  'other prisoners': 301,
#  'other similar software': 302,
#  'other گرگ خاکستری': 303,
#  'outer space': 304,
#  'oxidation of زیرلایه\u200cهای سیلیسیم': 305,
#  'oxidizing material': 306,
#  'penalty shootout': 307,
#  'period of lasting peace in افغانستان': 308,
#  'photographer': 309,
#  'platform made of saliva': 310,
#  'playing cautious women in historical dramas and literary adaptations': 311,
#  'press': 312,
#  'product of ۱۹۸۶': 313,
#  'product of ۲۰۰۵': 314,
#  'production advisor in شب یلدا': 315,
#  'programming and dynamic website design': 316,
#  'proton pump inhibitor': 317,
#  'read and write': 318,
#  'real estate': 319,
#  'reconstruction': 320,
#  'recording sessions': 321,
#  'records of آلمان غربی and آلمان شرقی': 322,
#  'released': 323,
#  'repairs': 324,
#  'replacement': 325,
#  'resistance to آنتی\u200cبیوتیک\u200cها': 326,
#  'science fiction': 327,
#  'science fiction and drama': 328,
#  'science fiction film': 329,
#  'seas': 330,
#  'season 1 of سیزده دلیل برای اینکه adaptation': 331,
#  'season 2 of سیزده دلیل برای اینکه adaptation': 332,
#  'second world war': 333,
#  'services to سپاه پاسداران': 334,
#  'set-point in مغز': 335,
#  'seven فرمول یک world championships': 336,
#  'short': 337,
#  'similar software': 338,
#  'simple hole in soil': 339,
#  'skyscraper': 340,
#  'small fruits': 341,
#  'small spacecraft to galaxy in 3D': 342,
#  'small, spherical, red, toxic fruit': 343,
#  'some prisoners': 344,
#  'species count': 345,
#  'species fully described': 346,
#  'species known': 347,
#  'species visible to naked eye': 348,
#  'specific film or television program': 349,
#  'stealth': 350,
#  'struggle of ولگرد کوچولو in modern industrial world': 351,
#  'stuntman': 352,
#  'survival information': 353,
#  'suspense': 354,
#  'teenage psychopath': 355,
#  'their own people': 356,
#  'thick fur': 357,
#  'third feature film of گدار': 358,
#  'third part of گرند ماستی': 359,
#  'third part of گرند ماستی series': 360,
#  'third place in جام باشگاه\u200cهای جهان ۲۰۰۷': 361,
#  'three synoptic gospels': 362,
#  'thriller': 363,
#  'thriller and action genre': 364,
#  'to protect خانه آنه فرانک from demolition': 365,
#  'top individuals with humanitarian achievements': 366,
#  'tree trunks': 367,
#  'true': 368,
#  'tuber (shallow root) containing starch': 369,
#  'two and a half stars out of four': 370,
#  'two brothers': 371,
#  'two brothers planning a bank heist': 372,
#  'two main groups': 373,
#  'two mischievous boys': 374,
#  'two weeks': 375,
#  'unit': 376,
#  'unstable young woman': 377,
#  'urban areas': 378,
#  'very resistant to corrosion': 379,
#  'video game series': 380,
#  'was a student': 381,
#  'was cancelled': 382,
#  'was poor innkeeper': 383,
#  'was praised by critics': 384,
#  'white or purple flowers': 385,
#  'winning جایزهٔ ادبی من بوکر': 386,
#  'world': 387,
#  'write his memoirs': 388,
#  'writers from کشورهای مشترک\u200cالمنافع, انگلیسی\u200cها, and ایرلندی\u200cها': 389,
#  "young man causing Earth's cooling by chemical reactions": 390,
#  'καινός': 391,
#  'μείων': 392,
#  'Монгол': 393,
#  'آئودی کیو۸': 394,
#  'آئورورا': 395,
#  'آئین بابی': 396,
#  'آب': 397,
#  'آبله\u200cمیمون': 398,
#  'آبنبات': 399,
#  'آبی روشن': 400,
#  'آبین سور': 401,
#  'آب\u200cگوشت ژاپنی': 402,
#  'آتا': 403,
#  'آتش فشان': 404,
#  'آثار ویلیام سوارد باروز دوم': 405,
#  'آخرین جدای': 406,
#  'آخرین شکارچی جادوگر': 407,
#  'آخرین پادشاه افغانستان': 408,
#  'آخرین کتاب': 409,
#  'آداب و رسوم یهودیان': 410,
#  'آدام سندلر': 411,
#  'آدام سندلر and درو بریمور': 412,
#  'آدام شنکمن': 413,
#  'آدامانتیوس کورائیس': 414,
#  'آدواله آکینویه آگباجه': 415,
#  'آذرین, رسوبی, دگرگونی': 416,
#  'آر وی': 417,
#  'آرامش سیاسی و اقتصادی توکوگاوا': 418,
#  'آرایه\u200cشناسی': 419,
#  'آرایه\u200cشناسی لینه\u200cای': 420,
#  'آرایه\u200cها': 421,
#  'آرتروز': 422,
#  'آرتی شاو': 423,
#  'آرتی شاو: زمان چیزی است که به\u200cدست آورده\u200cای': 424,
#  'آرتی\u200cسی': 425,
#  'آردسنگ': 426,
#  'آردویک': 427,
#  'آرسی\u200cای رکوردز': 428,
#  'آرومن\u200cها': 429,
#  'آرژانتین': 430,
#  'آرکید نینجا گایدن': 431,
#  'آزاد شدند': 432,
#  'آزاده صمدی': 433,
#  'آزار و اذیت نازی\u200cها': 434,
#  'آزای ناگاماسا': 435,
#  'آزمایش': 436,
#  'آزمایش جانوران': 437,
#  'آزمایش موفقیت\u200cآمیز جنگ\u200cافزارهای هسته\u200cای خود را به\u200cطور عمومی': 438,
#  'آزمایشگاه فیزیک دانشکده علوم دانشسرای عالی': 439,
#  'آسترازنکا': 440,
#  'آسرانی': 441,
#  'آسمان': 442,
#  'آسمان اکتبر': 443,
#  'آسمان\u200cخراش': 444,
#  'آسیا': 445,
#  'آشپزی ژاپنی': 446,
#  'آشیانه': 447,
#  'آشیانهٔ استادانه': 448,
#  'آشیانهٔ فنجانی': 449,
#  'آفتاب شیودسانی': 450,
#  'آفرودیت توانا': 451,
#  'آفریقای جنوب صحرا': 452,
#  'آفریقای جنوبی': 453,
#  'آفریقای سیاه': 454,
#  'آفریقای شمالی': 455,
#  'آفونسو پنجم': 456,
#  'آقا شکور ناصح پور': 457,
#  'آقای اکو': 458,
#  'آقای تقلب': 459,
#  'آل ثانی': 460,
#  'آلایش': 461,
#  'آلبانی': 462,
#  'آلبانیای قفقاز': 463,
#  'آلبانیایی\u200cها': 464,
#  'آلبوم تریلر': 465,
#  'آلبوم\u200cهای موسیقی': 466,
#  'آلفردو دی استفانو': 467,
#  'آلمان': 468,
#  'آلمان شرقی': 469,
#  'آلمان غربی': 470,
#  'آلمان غربی and آلمان شرقی': 471,
#  'آلمان غربی و آلمان شرقی': 472,
#  'آلمانی': 473,
#  'آلن جنکینس': 474,
#  'آلن گینزبرگ': 475,
#  'آلومینوسیلیکاتی': 476,
#  'آلکان\u200cها': 477,
#  'آلیس در شهرها': 478,
#  'آلیشا ویکندر': 479,
#  'آمار': 480,
#  'آماس مفصلی\u200cاستخوانی': 481,
#  'آمریکا': 482,
#  'آمریکای جنوبی': 483,
#  'آمریکای شمالی': 484,
#  'آمریکای شمالی and اروپا': 485,
#  'آمریکای لاتین': 486,
#  'آمریکایی': 487,
#  'آمریکایی و انگلیسی': 488,
#  'آموزاندن، ورزیدن و تحقیق دانش و مسائل علمی': 489,
#  'آموزه\u200cهای سامورایی': 490,
#  'آن بولین': 491,
#  'آن هانی': 492,
#  'آن ورشک': 493,
#  'آنا': 494,
#  'آناتومی گری': 495,
#  'آنتون وبرن': 496,
#  'آنتونی مکی': 497,
#  'آنتونی پلنا': 498,
#  'آنتونیو باندراس': 499,
#  'آنتی\u200cبیوتیک': 500,
#  'آنتی\u200cبیوتیک types': 501,
#  'آنتی\u200cبیوتیک\u200cها': 502,
#  'آنجلا کینزی': 503,
#  'آنجلس تایمز': 504,
#  'آندرداگ': 505,
#  'آنر': 506,
#  'آنزیمها': 507,
#  'آنه فرانک': 508,
#  'آنه فرانک and family': 509,
#  'آنه فرانک و خانواده\u200cاش': 510,
#  "آنه فرانک's diaries": 511,
#  'آنیه': 512,
#  'آهن': 513,
#  'آهن in space': 514,
#  'آهنگساز': 515,
#  'آهنگساز ایتالیایی': 516,
#  'آهنگ\u200cساز': 517,
#  'آوانگارد تجربیات سریالی لین': 518,
#  'آوریل ۲۰۰۹': 519,
#  'آوریل ۲۰۱۵': 520,
#  'آپاچی': 521,
#  'آپاچی تامکت': 522,
#  'آپاچی سابورژن': 523,
#  'آپاچی ماون': 524,
#  'آپاچی\u200cها': 525,
#  'آپچی انت': 526,
#  'آژانس قراردادی': 527,
#  'آکادمی': 528,
#  'آکادمی علوم و هنرهای تصاویر متحرک': 529,
#  'آگوست دوم': 530,
#  'آیدا': 531,
#  'آیفون اس\u200cای': 532,
#  'آیفون اکس\u200cآر': 533,
#  'آیفون ۱۱': 534,
#  'آیفون ۱۱ پرو': 535,
#  'آیفون ۶اس': 536,
#  'آینه\u200cها': 537,
#  'آیوسا': 538,
#  'آیین بابی': 539,
#  'آی\u200cاواس ۱۳': 540,
#  'آی\u200cاواس ۱۴٫۵': 541,
#  'آی\u200cدی تک ۶': 542,
#  'آی\u200cدی سافتور': 543,
#  'آی\u200cمکس': 544,
#  'آی\u200cپد ایر ۲': 545,
#  'آی\u200cپد مینی ۴': 546,
#  'آی\u200cپد نسل پنجم': 547,
#  'آی\u200cپد پرو': 548,
#  'آی\u200cپداواس ۱۴٫۵': 549,
#  'آی\u200cیوسی\u200cان': 550,
#  'آی\u200cیوسی\u200cان study': 551,
#  'ئی\u200cاِی': 552,
#  'ابر قهرمانی فیلم': 553,
#  'ابرشرکت فاکس': 554,
#  'ابرقدرت اروپایی': 555,
#  'ابرنواختر': 556,
#  'ابله': 557,
#  'ابوالسلاطین': 558,
#  'ابوذر': 559,
#  'ابونعیم عبدالله بن احمد شافعی اشعری': 560,
#  'ابونعیم عبدالله بن احمد شافعی اشعری as one of the best references of Islamic hadith sciences': 561,
#  'اتاق\u200cهای مخفی خانه آنه فرانک': 562,
#  'اتان': 563,
#  'اتحاد جماهیر شوروی سوسیالیستی': 564,
#  'اتحادیه بین\u200cالمللی برادری تیمسترز': 565,
#  'اتحادیه فوتبال آلمان': 566,
#  'اتحادیه فوتبال بلغارستان': 567,
#  'اتحادیه فوتبال سوئیس': 568,
#  'اتحادیه ملی بسکتبال آمریکا': 569,
#  'اتحادیه کارگران آمریکا': 570,
#  'اتحادیهٔ ملی بسکتبال': 571,
#  'اتریش': 572,
#  'اتومبیل\u200cدزدی بزرگ': 573,
#  'اثر دانت بر ایتالیایی': 574,
#  'اثر شایسته تقدیر': 575,
#  'اثر مارتین لوتر بر آلمانی': 576,
#  'اثر مشهور جان رالز': 577,
#  'اثر پروانه\u200cای': 578,
#  'اثر پروانه\u200cای (butterfly effect) in chaos theory': 579,
#  'اثر پروانه\u200cای ۲': 580,
#  'اثر پروانه\u200cای ۳': 581,
#  'اجرا': 582,
#  'احتمال': 583,
#  'احمد سمیعی گیلانی': 584,
#  'اخبار ۲۰:۳۰': 585,
#  'اختربینی': 586,
#  'اخترشناس سوئیسی': 587,
#  'اختلاف ثابت و پیاپی بین اعضا': 588,
#  'اخلاق': 589,
#  'اد هریس': 590,
#  'اد هلمز': 591,
#  'اداره': 592,
#  'اداری-تجاری': 593,
#  'ادبیات ایتالیا': 594,
#  'ادبیات یونانی نوین': 595,
#  'ادرار کردن با درد همراه با عفونت کلیه': 596,
#  'ادریس البا': 597,
#  'ادل اینل': 598,
#  'ادوارد آرنولد': 599,
#  'ادوین کتمول': 600,
#  'ادگار وارز': 601,
#  'ادی کو': 602,
#  'ادی گریفن': 603,
#  'ارباب خود ناگای ناگاهیرو را کشت': 604,
#  'ارتباطات': 605,
#  'ارتش ایالات متحده': 606,
#  'ارتشی سابق آمریکایی': 607,
#  'ارث': 608,
#  'اردبیل': 609,
#  'اردشیر اردلان': 610,
#  'اردو': 611,
#  'ارنست جونز': 612,
#  'ارنست میلر هِمینگوی': 613,
#  'ارنست همینگوی': 614,
#  'ارنِست میلر هِمینگوی': 615,
#  'ارومیه': 616,
#  'اروپا': 617,
#  'اروپای جنوب شرقی': 618,
#  'اروپای شرقی': 619,
#  'اروپای مرکزی': 620,
#  'ارگ': 621,
#  'اریک اریکسون': 622,
#  'اریک برس and جیمکی گروبر': 623,
#  'اریک دی آربلوف': 624,
#  'اریکسون': 625,
#  'از نفس افتاده': 626,
#  'ازرا میلر': 627,
#  'اس.اف.دبلیو': 628,
#  'اساسینز کرید': 629,
#  'اساسینز کرید ۳': 630,
#  'اساسینز کرید ۴: پرچم سیاه': 631,
#  'اساسینز کرید: سرکش': 632,
#  'اساسینز کرید: وحدت': 633,
#  'استاد برجسته دانشگاه نجوم دانشگاه ژنو': 634,
#  'استاد نظریه و نقد ادبی': 635,
#  'استادان برجسته': 636,
#  'استادتمام نظریه و نقد ادبی': 637,
#  'استادتمامِ نظریه و نقد ادبی': 638,
#  'استان اصفهان': 639,
#  'استان خراسان جنوبی': 640,
#  'استان خراسان شمالی': 641,
#  'استان خوزستان': 642,
#  'استان مازندران': 643,
#  'استخوان شتر': 644,
#  'استرالیا': 645,
#  'استفان زویگ': 646,
#  'استفانی فولسوم': 647,
#  'استفنی مک\u200cمن لوک': 648,
#  'استن کارلایل': 649,
#  'استنلی کوبریک': 650,
#  'استوارت برد': 651,
#  'استودیو انیمیشن والت دیزنی': 652,
#  'استودیو بل': 653,
#  'استودیو توسعه دهنده': 654,
#  'استودیو قرن بیستم': 655,
#  'استودیو مترو گلدوین مایر': 656,
#  'استودیوهای انیمیشن پیکسار': 657,
#  'استودیوهای توسعه دهنده دیگر': 658,
#  'استودیوی فیلمسازی آمریکایی': 659,
#  'استودیوی هانزا': 660,
#  'استورم رید': 661,
#  'استیو بارون': 662,
#  'استیو جابز': 663,
#  'استیو کرل': 664,
#  'استیو کلاوز': 665,
#  'استیون جیلنهال': 666,
#  'استیون سی میلر': 667,
#  'استیون مرچنت': 668,
#  'استیون نایت': 669,
#  'اسرائیل': 670,
#  'اسرائیل حدود ۷۵ تا ۴۰۰ کلاهک هسته\u200cای دارد': 671,
#  'اسلام': 672,
#  'اسلاو': 673,
#  'اسلاوهای جنوبی': 674,
#  'اسلج\u200cهمر گیمز': 675,
#  'اسلحهٔ گرم': 676,
#  'اسلیم': 677,
#  'اسم این برنامه': 678,
#  'اسماعیل چشم آذر': 679,
#  'اسپانیا': 680,
#  'اسپانیای نو': 681,
#  'اسپرم به مهبل یا گردن رحم زن': 682,
#  'اسپرماتوزوآی بالغ': 683,
#  'اسپوندیلیت آنکیلوزان': 684,
#  'اسکات ادکینز': 685,
#  'اسکات هافمن': 686,
#  'اسکار': 687,
#  'اسکار بهترین بازیگر نقش مکمل مرد': 688,
#  'اسکار بهترین فیلم مستند': 689,
#  'اسکار نونز': 690,
#  'اسکرانتون': 691,
#  'اسکندربیک ترکمان': 692,
#  'اسکودریا فراری': 693,
#  'اسکیموهای سیبری': 694,
#  'اسکیموهای کانادا': 695,
#  'اسید گاما-لینولنیک': 696,
#  'اس\u200cامپرازول': 697,
#  'اس\u200cبی\u200cتی': 698,
#  'اس\u200cکیوال': 699,
#  'اس\u200cیووی ب\u200cام\u200cو سری ۷': 700,
#  'اشتون کوچر and ایمی اسمارت': 701,
#  'اشوک تاکریا': 702,
#  'اشکانیان': 703,
#  'اشکوب زیرین': 704,
#  'اصطلاح بنتونیت': 705,
#  'اصطلاح سامورایی': 706,
#  'اصغر فرهادی': 707,
#  'اصفهان': 708,
#  'اصلان': 709,
#  'اصولگرایان': 710,
#  'اضطراب اختگی': 711,
#  'اضطراب و دلهره و حس تعلیق': 712,
#  'اعتراض\u200cها برای دادخواهی و افشای جنایت\u200cهای حکومت اسلامی': 713,
#  'اعضای دائم شورای امنیت سازمان ملل': 714,
#  'اعضای راسته گنجشک\u200cسانان': 715,
#  'اعضای سازمان ملل متحد': 716,
#  'اعطای نشان افتخار به کشته\u200cشدگان جنگ ویتنام': 717,
#  'افراد محکوم': 718,
#  'افراد پیر و جوان با سیستم ایمنی ضعیف': 719,
#  'افرادی که به نوشتن می\u200cپردازند': 720,
#  'افرادی که نقش مهمی در سینما داشته\u200cاند': 721,
#  'افزایش ترشح اسید معده': 722,
#  'افزایش میزان تنفس': 723,
#  'افسران روس': 724,
#  'افسون\u200cزده (۲۰۰۷)': 725,
#  'افسون\u200cنزده': 726,
#  'افعی مینو': 727,
#  'افغانستان': 728,
#  'اقوام انتس': 729,
#  'اقوام اولیهٔ کانادا': 730,
#  'اقوام ایرانی تبار': 731,
#  'اقیانوس آرام': 732,
#  'اقیانوس اطلس': 733,
#  'اقیانوس منجمد شمالی': 734,
#  'اقیانوس هند': 735,
#  'ال سگوندو': 736,
#  'الانان': 737,
#  'الحَمْد لله': 738,
#  'السا': 739,
#  'المپیک ریو': 740,
#  'المپیک لندن': 741,
#  'المپیک ۲۰۱۶ ریو دوژانیرو': 742,
#  'المپیک ۲۰۲۰ توکیو': 743,
#  'الن دی\u200cجنرس': 744,
#  'الن ریپلی': 745,
#  'الن کامینگ': 746,
#  'الهام چرخنده': 747,
#  'الکتروموتور': 748,
#  'الکترونیک آرتز': 749,
#  'الکس': 750,
#  'الکس مورفی': 751,
#  'الکساندر مک\u200cکوئین': 752,
#  'الکلیسم in مردم انتس': 753,
#  'الیجاه وود': 754,
#  'الیزابت اول': 755,
#  'الیسون بری': 756,
#  'الیور استون': 757,
#  'اما تامسون': 758,
#  'اما تامپسون': 759,
#  'امام': 760,
#  'امام معصوم': 761,
#  'امبت دیویتس': 762,
#  'امت والش': 763,
#  'امرالد فنل': 764,
#  'امروزه': 765,
#  'امپراتور ریگن': 766,
#  'امپراتور هیگاشی\u200cیاما': 767,
#  'امپراتور ژاپن': 768,
#  'امپراتوری اسپانیا': 769,
#  'امپراتوری اول فرانسه': 770,
#  'امپراتوری بریتانیا': 771,
#  'امپراتوری درانی': 772,
#  'امپراتوری روسیه': 773,
#  'امپراتوری ضربه متقابل': 774,
#  'امپراتوری ضربه متقابل می\u200cزند': 775,
#  'امپراتوری مغول': 776,
#  'امپراتوری پرتغال': 777,
#  'امپراتوری گورکانی': 778,
#  'امپراتوری گورکانی هند': 779,
#  'امیر قطر': 780,
#  'امیرکبیر': 781,
#  'ام\u200cجی\u200cام': 782,
#  'ام\u200cسی\u200cام': 783,
#  'انتاریو': 784,
#  'انتشارات حکایت قلم نوین': 785,
#  'انتشارات نگاه امروز': 786,
#  'انتشارات نیلوفر': 787,
#  'انتقال داده از سایتهای اینترنتی': 788,
#  'انتونیو دان ولی in ایتالیا': 789,
#  'انتونیو دی نولی': 790,
#  'انتونیوتو اسودیمیر in ایتالیا': 791,
#  'انجمن فیزیک ایران': 792,
#  'انجمن منتقدان فیلم لس آنجلس': 793,
#  'انجیل متی': 794,
#  'انجیل مرقس': 795,
#  'انجیل مرقس هنگام نگارش اثر خود': 796,
#  'اندرو استنتون': 797,
#  'اندروید مارشمالو': 798,
#  'اندروید نسخه 4.4.2': 799,
#  'اندلس': 800,
#  'اندونزی': 801,
#  'اندی باکلی': 802,
#  'انرژی': 803,
#  'انرژی الکتریکی to انرژی مکانیکی': 804,
#  'انرژی مکانیکی to انرژی الکتریکی': 805,
#  'انریکه ایگلسیاس': 806,
#  'انزجار': 807,
#  'انسان': 808,
#  'انسان جاه\u200cطلب': 809,
#  'انسان سالم و بالغ': 810,
#  'انسان سرد، مستبد و بی\u200cاحساس': 811,
#  'انسان\u200cها': 812,
#  'انستیتو بین\u200cالمللی پژوهش\u200cهای صلح استکهلم': 813,
#  'انسینو': 814,
#  'انعطاف\u200cپذیر': 815,
#  'انقراض هولوسین': 816,
#  'انقلاب': 817,
#  'انگ لی': 818,
#  'انگلستان': 819,
#  'انگلیسی': 820,
#  'انگلیسی\u200cها': 821,
#  'انیمه': 822,
#  'انیگما': 823,
#  'ان\u200cبی\u200cسی': 824,
#  'اهداف': 825,
#  'اهواز': 826,
#  'اوئدا یاسویوکی': 827,
#  'اوا مندس': 828,
#  'اوتو فنیچل': 829,
#  'اودا نوبوناگا': 830,
#  'اودن': 831,
#  'اودون': 832,
#  'اودیسه باختر': 833,
#  'اودیسه به سمت غرب': 834,
#  'اوراوا رد دایمندز': 835,
#  'اوراوا ردز': 836,
#  'اورشلیم': 837,
#  'اوزی': 838,
#  'اوسمیوم': 839,
#  'اولین بفتای خود': 840,
#  'اولین دایمیوی قلمروی کاگا': 841,
#  'اولین فیلم بیگانه': 842,
#  'اولین نقش ایمی لیسل اسمارت': 843,
#  'اولیگوسن': 844,
#  'اوم پوری': 845,
#  'اوما تورمن': 846,
#  'اوماتسو نو کاتا': 847,
#  'اووه بل': 848,
#  'اوپن\u200cجی\u200cال': 849,
#  'اوژی\u200cیا': 850,
#  'اوکراین': 851,
#  'اُستئوآرتریت': 852,
#  'اُواری گریخت': 853,
#  'اِسپِرم': 854,
#  'اپرا': 855,
#  'اپرا وینفری': 856,
#  'اپرای فضایی': 857,
#  'اپرای مردمی صوفیه': 858,
#  'اپل': 859,
#  'اپل پارک': 860,
#  'اپچی': 861,
#  'اپیزود اول و دوم of ۱۳ دلیل برای اینکه': 862,
#  'اپیک رکوردز': 863,
#  'اچ\u200cتی\u200cام\u200cال': 864,
#  'اکبر عبدی آقاباقر': 865,
#  'اکتبر': 866,
#  'اکتبر ۲۰۱۰': 867,
#  'اکتیبر ۲۰۰۳': 868,
#  'اکتیویژن': 869,
#  'اکسایش حرارتی': 870,
#  'اکسایش زیرلایه\u200cهای سیلیسیم': 871,
#  'اکسیداسیون در هوا مرطوب': 872,
#  'اکسیداسیون در هوای مرطوب': 873,
#  'اکسیدها': 874,
#  'اکس\u200cام\u200cال': 875,
#  'اکس\u200cاچ\u200cتی\u200cام\u200cال': 876,
#  'اکس\u200cباکس': 877,
#  'اکس\u200cباکس وان': 878,
#  'اکس\u200cباکس ۳۶۰': 879,
#  'اکشن سینمای هنگ کنگ': 880,
#  'اکورو اس\u200cسی\u200cام': 881,
#  'اگر سنگ از آسمان ببارد': 882,
#  'ایالات متحده': 883,
#  'ایالات متحده آمریکا': 884,
#  'ایالات متحده و روسیه': 885,
#  'ایالت اورگن': 886,
#  'ایالت ایندیانا': 887,
#  'ایالت ماساچوست': 888,
#  'ایالت هند': 889,
#  'ایالت کلرادو': 890,
#  'ایالت\u200cهای جنوب غربی آمریکا': 891,
#  'ایان مک\u200cدیارمید': 892,
#  'ایان هارت': 893,
#  'ایان هولم': 894,
#  'ایتالیا': 895,
#  'ایتالیایی': 896,
#  'ایترو': 897,
#  'ایدا': 898,
#  'ایدینا منزل': 899,
#  'ایدیوکراسی': 900,
#  'ایدیوکراسی in ۲۰۰۶': 901,
#  'ایران': 902,
#  'ایران and روسیه تزاری': 903,
#  'ایران ایر': 904,
#  'ایران ایرتور': 905,
#  'ایرانشهر': 906,
#  'ایرانی': 907,
#  'ایرانی\u200cتبار': 908,
#  'ایرتون سنا': 909,
#  'ایرتگ': 910,
#  'ایرج صغیری': 911,
#  'ایرلندی\u200cها': 912,
#  'ایرن ژاکوب': 913,
#  'ایروان': 914,
#  'ایریدیم': 915,
#  'ایس کمبت ۷: آسمان\u200cهای ناشناخته': 916,
#  'ایسترورومن\u200cها': 917,
#  'ایمی آدامز': 918,
#  'ایمی لیسل اسمارت': 919,
#  'اینترنت': 920,
#  'اینداستریال لایت اند مجیک': 921,
#  'ایندرا کومار': 922,
#  'ایندیانا جونز': 923,
#  'اینفینیتی وارد': 924,
#  'اینوئیت': 925,
#  'اینورترها': 926,
#  'این\u200cاسلیو': 927,
#  'ایو': 928,
#  'ایوا دوورنی': 929,
#  'ایوان ریچل وود': 930,
#  'ایوان مک\u200cگرگور': 931,
#  'ایوان پنجم': 932,
#  'ایوت نیکول براون': 933,
#  'ایکس باکس ۳۶۰': 934,
#  'ایکس\u200cباکس': 935,
#  'ایکس\u200cباکس ۳۶۰': 936,
#  'ایکو اویس': 937,
#  'ایگور استراوینسکی': 938,
#  'ایگی پاپ': 939,
#  'ای۳': 940,
#  'ای۳ ۲۰۰۴': 941,
#  'بئاتریس': 942,
#  'با استعداد': 943,
#  'با توکی یوری\u200cآکی جنگید': 944,
#  'بابر': 945,
#  'باتری\u200cها': 946,
#  'بادمجان': 947,
#  'باز مدرسم دیر شد': 948,
#  'بازخورد منفی در پیش\u200cنمایش آزمایشی': 949,
#  'بازگشت به معصومیت': 950,
#  'بازگشت جدای': 951,
#  'بازی آرکید': 952,
#  'بازی آرکید برادران ماریو': 953,
#  'بازی اکشن': 954,
#  'بازی دوبعدی آزاد و متن\u200cباز در سبک سکوبازی': 955,
#  'بازی مرحله یک چهارم نهایی جام جهانی ۱۹۵۴': 956,
#  'بازی ویدئویی': 957,
#  'بازی ویدئویی به سبک پارتی': 958,
#  'بازی ویدئویی بیتم آپ از زاویه دید پهلو': 959,
#  'بازی ویدئویی در سبک اکشن و ماجراجویی': 960,
#  'بازی ویدئویی در سبک اکشن-ماجراجویی': 961,
#  'بازی ویدئویی در سبک تاریخی اکشن ماجراجویی': 962,
#  'بازی ویدئویی در سبک تاریخی اکشن-ماجراجویی': 963,
#  'بازی ویدئویی در سبک ترس و بقا': 964,
#  'بازی ویدئویی علمی-تخیلی در سبک تیراندازی اول شخص': 965,
#  'بازیک': 966,
#  'بازیکن': 967,
#  'بازیکن to move freely in دنیای مجازی': 968,
#  'بازیکن هاکی': 969,
#  'بازیکنان کرایسیس ۲': 970,
#  'بازیگر': 971,
#  'بازیگر آمریکایی': 972,
#  'بازیگر انگلیسی': 973,
#  'بازیگر انگلیسی سینما و تئاتر': 974,
#  'بازیگر ایرانی': 975,
#  'بازیگر ایرلندی': 976,
#  'بازیگر بریتانیایی': 977,
#  'بازیگر سریالهای تلویزیونی': 978,
#  'بازیگر سینما': 979,
#  'بازیگر سینما و تلویزیون': 980,
#  'بازیگر سینما و تلویزیون و مانکن پیشین آمریکایی': 981,
#  'بازیگر و فیلم\u200cنامه\u200cنویس بریتانیایی': 982,
#  'بازیگر کمیک': 983,
#  'بازیگران و موسیقی\u200cدانان': 984,
#  'بازی\u200cهای دارای ساختار و داستان خطی': 985,
#  'بازی\u200cهای مبارزه ای سنتی': 986,
#  'بازی\u200cهای گرسنگی: زاغ مقلد – بخش ۲': 987,
#  'باشگاه توقینیه فویلارد': 988,
#  'باشگاه فوتبال حرفه\u200cای': 989,
#  'باشگاه فوتبال رئال مادرید': 990,
#  'باشگاه فوتبال راسینگ سانتاندر': 991,
#  'باشگاه فوتبال منچستر سیتی': 992,
#  'باشگاه فوتبال پرسپولیس': 993,
#  'بال\u200cلاکی ژاپنی': 994,
#  'بامیان': 995,
#  'باند فوق سریع': 996,
#  'باندای نامکو گیمز': 997,
#  'بانک': 998,
#  'بانک چیس': 999,
#  ...}

# %%
node_to_id["Alien"]
# Out:
# 19

# %%
nodes_list[19]
# Out:
# 'Alien'

# %% [markdown]
# # Extracting Node Similarity and filtering

# %%
## mps or cpu
device = "mps" if torch.backends.mps.is_available() else "cpu"
print(f"device: {device}")
encode_model = SentenceTransformer('sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2')
# Out:
# device: cpu

# %%
node_embeddings = encode_model.encode(
    nodes_list, 
    show_progress_bar=True,
    convert_to_tensor=True
)
# Out:
# Batches:   0%|          | 0/146 [00:00<?, ?it/s]

# %%
# Find Similar Nodes and Create Synonymy Edges 

similar_pairs = util.paraphrase_mining_embeddings(
    node_embeddings,
    top_k=2, 
)

SIMILARITY_THRESHOLD = 0.96

synonymy_edges = []
for score, i, j in similar_pairs:
    if score > SIMILARITY_THRESHOLD:
        node1 = nodes_list[i]
        node2 = nodes_list[j]
        synonymy_edges.append({
            "source": node1,
            "target": node2,
            "type": "synonymy",
            "score": score
        })

# %%
final_graph = {
    "nodes": [{"id": i, "label": node} for i, node in enumerate(nodes_list)],
    "edges": relation_edges + synonymy_edges
}

# %%
with open("hippocampal_index.json", 'w', encoding='utf-8') as f:
    json.dump(final_graph, f, ensure_ascii=False, indent=4)

# %% [markdown]
# # PPR

# %%
import json
from sentence_transformers import SentenceTransformer, util
import torch
import numpy as np
import igraph as ig
from tqdm import tqdm
from langchain_openai import ChatOpenAI
from langchain.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field
from typing import List
import dotenv
import os

dotenv.load_dotenv()


GRAPH_INDEX_PATH = "hippocampal_index.json"
SOURCE_TRIPLES_PATH = "knowledge_graph_triples_structured.json"
ORIGINAL_CONTEXT_PATH = "all_context.json"
ENCODER_MODEL_NAME = 'paraphrase-multilingual-MiniLM-L12-v2'
MODEL_NAME = "gpt-4o-mini"
PPR_DAMPING_FACTOR = 0.5 # The lesser the value, the more the algorithm focuses on the local structure of the graph.

# %%
class QueryEntities(BaseModel):
    """A structured list of named entities extracted from a user's query."""
    named_entities: List[str] = Field(
        ...,
        description="A list of named entities that are important for solving the user's question."
    )


class HippoRAGRetriever:
    def __init__(self):
        print("Initializing HippoRAGRetriever...")
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        
        # 1. Load all necessary data files
        self._load_data()

        # 2. Initialize models
        self.encoder_model = SentenceTransformer(ENCODER_MODEL_NAME, device=self.device)
        self.llm = ChatOpenAI(
            model=MODEL_NAME, temperature=0, api_key=os.getenv("METIS_API_KEY"), base_url="https://api.metisai.ir/openai/v1"
        )
        
        # 3. Pre-compute necessary mappings and structures
        self._build_graph()
        self._compute_node_specificity()
        self._create_passage_to_node_mapping()

        # 4. Pre-encode all graph nodes for fast query-time similarity search
        print("Pre-encoding all graph nodes for retrieval...")
        self.node_labels = [node['label'] for node in self.graph_data['nodes']]
        self.node_embeddings = self.encoder_model.encode(
            self.node_labels, show_progress_bar=True, convert_to_tensor=True
        )
        print("Initialization complete.")

    def _load_data(self):
        """Loads the graph, source triples, and original passages."""
        print("Loading graph index and source data...")
        try:
            with open(GRAPH_INDEX_PATH, 'r', encoding='utf-8') as f:
                self.graph_data = json.load(f)
            with open(SOURCE_TRIPLES_PATH, 'r', encoding='utf-8') as f:
                self.source_triples = json.load(f)
            with open(ORIGINAL_CONTEXT_PATH, 'r', encoding='utf-8') as f:
                self.passages = json.load(f) 
        except FileNotFoundError as e:
            print(f"Error: Could not find a required data file: {e.filename}")
            print("Please ensure all data files from the previous steps are present.")
            exit()

    def _build_graph(self):
        """Builds a weighted igraph.Graph object from the loaded JSON data."""
        print("Building weighted igraph object...")
        self.g = ig.Graph(directed=False)
        self.g.add_vertices(len(self.graph_data['nodes']))
        
        self.node_label_to_id = {node['label']: node['id'] for node in self.graph_data['nodes']}
        
        edges = []
        weights = []
        for edge_data in self.graph_data['edges']:
            source_id = self.node_label_to_id.get(edge_data['source'])
            target_id = self.node_label_to_id.get(edge_data['target'])
            
            if source_id is not None and target_id is not None:
                edges.append((source_id, target_id))
                # Assign weights: similarity score for synonymy, 1.0 for relations
                if edge_data['type'] == 'synonymy':
                    weights.append(edge_data.get('score', 0.8))
                else: 
                    weights.append(1.0)
        
        self.g.add_edges(edges)
        # Assign the weights to the 'weight' edge attribute
        self.g.es['weight'] = weights  
        print(f"Graph built with {self.g.vcount()} vertices and {self.g.ecount()} edges.")

    def _compute_node_specificity(self):
        """
        Calculates node specificity for each node in the graph.
        Specificity s_i = 1 / |P_i|, where P_i is the set of passages containing node i.
        """
        print("Computing node specificity...")
        node_passage_counts = {node_id: 0 for node_id in range(len(self.node_label_to_id))}
        passage_nodes = {} 
        for item in self.source_triples:
            passage_id = item['id']
            nodes_in_passage = set(item.get('entities', []))
            for triple in item.get('triples', []):
                nodes_in_passage.add(triple['subject'])
                nodes_in_passage.add(triple['object'])
            
            for node_label in nodes_in_passage:
                node_id = self.node_label_to_id.get(node_label)
                if node_id is not None:
                    if passage_id not in passage_nodes.get(node_id, set()):
                        node_passage_counts[node_id] += 1
                        if node_id not in passage_nodes:
                            passage_nodes[node_id] = set()
                        passage_nodes[node_id].add(passage_id)

        self.node_specificity = {}
        for node_id, count in node_passage_counts.items():
            if count > 0:
                self.node_specificity[node_id] = 1.0 / count
            else:
                self.node_specificity[node_id] = 0 

    def _create_passage_to_node_mapping(self):
        """Creates a mapping from passage index to the list of node IDs it contains."""
        self.passage_to_nodes = {i: [] for i in range(len(self.passages))}
        for item in self.source_triples:
            passage_idx = item['id']
            nodes_in_passage = set(item.get('entities', []))
            for triple in item.get('triples', []):
                nodes_in_passage.add(triple['subject'])
                nodes_in_passage.add(triple['object'])
            
            node_ids_in_passage = {self.node_label_to_id.get(label) for label in nodes_in_passage}
            self.passage_to_nodes[passage_idx] = [nid for nid in node_ids_in_passage if nid is not None]


    def _extract_query_entities(self, query: str) -> List[str]:
        """Uses an LLM to extract named entities from the user query."""
        system_prompt = """
        Instruction:
        Your task is to extract named entities from the given paragraph in the user's message.
        Respond with a JSON list of entities.

        One-Shot Demonstration:
        If the user provides the paragraph:
        "Radio City is India's first private FM radio station and was started on 3 July 2001. It plays Hindi, English and regional songs. Radio City recently forayed into New Media in May 2008 with the launch of a music portal - PlanetRadiocity.com that offers music related news, videos, songs, and other music-related features."

        Your output should be a JSON object with a list of the extracted entities:
        {{"named_entities": ["Radio City", "India", "3 July 2001", "Hindi", "English", "May 2008", "PlanetRadiocity.com"]}}
        """
        prompt = ChatPromptTemplate.from_messages([
            ("system", system_prompt),
            ("human", "Question: {query}")
        ])
        chain = prompt | self.llm.with_structured_output(QueryEntities)
        try:
            response = chain.invoke({"query": query})
            return response.named_entities
        except Exception as e:
            print(f"Error extracting query entities: {e}")
            return []
            
    def _find_query_nodes(self, query_entities: List[str]) -> List[int]:
        """Finds the most similar graph nodes for the extracted query entities."""
        if not query_entities:
            return []
        
        global VERBOSE
        
        query_embeddings = self.encoder_model.encode(query_entities, convert_to_tensor=True)
        # Compute cosine similarity between query embeddings and all node embeddings
        cos_scores = util.cos_sim(query_embeddings, self.node_embeddings)
        
        top_matches_indices = torch.argmax(cos_scores, dim=1)
        
        # --- DEBUGGING ADDITION ---
        matched_node_ids = []
        for i, entity in enumerate(query_entities):
            node_id = top_matches_indices[i].item()
            score = cos_scores[i][node_id].item()
            node_label = self.node_labels[node_id]
            if VERBOSE:
                print(f"  - Query Entity: '{entity}' -> Matched Node: '{node_label}' (ID: {node_id}) | Score: {score:.4f}")
            matched_node_ids.append(node_id)
        
        return list(set(matched_node_ids))

    def retrieve(self, query: str, top_k: int = 5) -> List[dict]:
        """
        Performs the full online retrieval process for a given query.
        """
        global VERBOSE
        
        # 1. Neocortex: Extract entities from query
        query_entities = self._extract_query_entities(query)
        if not query_entities:
            print("Could not extract entities from query. Aborting retrieval.")
            return []
        if VERBOSE:
            print(f"Step 1: Extracted query entities -> {query_entities}")

        # 2. Parahippocampal Regions: Find corresponding nodes in the graph
        query_node_ids = self._find_query_nodes(query_entities)
        if not query_node_ids:
            print("Could not find matching nodes in the graph. Aborting retrieval.")
            return []
        query_node_labels = [self.node_labels[i] for i in query_node_ids]
        if VERBOSE:
            print(f"Step 2: Found corresponding query nodes -> {query_node_labels}")

        # 3. Hippocampus: Perform pattern completion with PPR
        personalization_vector = np.zeros(self.g.vcount())
        total_specificity = 0
        for node_id in query_node_ids:
            specificity = self.node_specificity.get(node_id, 0)
            personalization_vector[node_id] = specificity
            total_specificity += specificity
        
        # Normalize the vector so it sums to 1
        if total_specificity > 0:
            personalization_vector /= total_specificity
            
        ppr_scores = self.g.personalized_pagerank(
            vertices=None,
            directed=False,
            damping=PPR_DAMPING_FACTOR,
            reset=personalization_vector.tolist(),
            weights=self.g.es['weight'] 
        )

        # --- DEBUGGING ADDITION ---
        
        if VERBOSE:
            print("\n--- DEBUG: Top 10 Nodes after PageRank ---")
            # Get the indices of the top 10 scores
            top_node_indices = np.argsort(ppr_scores)[-10:][::-1]
            for node_id in top_node_indices:
                print(f"  - Node: '{self.node_labels[node_id]}' (ID: {node_id}) | PPR Score: {ppr_scores[node_id]:.6f}")
        
        # 4. Aggregate node scores to get passage scores
        passage_scores = {i: 0.0 for i in range(len(self.passages))}
        for passage_idx, node_ids in self.passage_to_nodes.items():
            score = sum(ppr_scores[node_id] for node_id in node_ids)
            passage_scores[passage_idx] = score
            
        # Sort and return top_k results
        sorted_passages = sorted(passage_scores.items(), key=lambda item: item[1], reverse=True)
        
        results = []
        for passage_idx, score in sorted_passages[:top_k]:
            results.append({
                "passage_index": passage_idx,
                "passage_text": self.source_triples[passage_idx]["passage"],
                "score": score
            })
        return results

# %%
retriever = HippoRAGRetriever()
# Out:
# Initializing HippoRAGRetriever...
# Loading graph index and source data...
# Building weighted igraph object...
# Graph built with 4644 vertices and 5980 edges.
# Computing node specificity...
# Pre-encoding all graph nodes for retrieval...
# Batches:   0%|          | 0/146 [00:00<?, ?it/s]
# Initialization complete.

# %%
example_query = "آیا کاترین لانگفورد نقش هانا بیکر را در فصل سوم سریال ۱۳ دلیل برای اینکه بازی کرده است ؟"
VERBOSE = True
top_passages = retriever.retrieve(query=example_query, top_k=15)

print("\n--- Top 5 Retrieved Passages ---")
if top_passages:
    for i, result in enumerate(top_passages):
        print(f"{i+1}. [Score: {result['score']:.6f}] Passage (Index {result['passage_index']}):")
        print(f"   '{result['passage_text'][:200]}...'")
        print("-" * 20)
else:
    print("No passages were retrieved.")
# Out:
# Step 1: Extracted query entities -> ['کاترین لانگفورد', 'هانا بیکر', 'فصل سوم', 'سریال ۱۳ دلیل برای اینکه']
#   - Query Entity: 'کاترین لانگفورد' -> Matched Node: 'کاترین لانگفورد' (ID: 3926) | Score: 1.0000
#   - Query Entity: 'هانا بیکر' -> Matched Node: 'هانا بیکر' (ID: 3499) | Score: 1.0000
#   - Query Entity: 'فصل سوم' -> Matched Node: 'فصل سوم' (ID: 2681) | Score: 1.0000
#   - Query Entity: 'سریال ۱۳ دلیل برای اینکه' -> Matched Node: '۱۳ دلیل برای اینکه' (ID: 4278) | Score: 0.8479
# Step 2: Found corresponding query nodes -> ['فصل سوم', 'هانا بیکر', '۱۳ دلیل برای اینکه', 'کاترین لانگفورد']
#
# --- DEBUG: Top 10 Nodes after PageRank ---
#   - Node: 'فصل سوم' (ID: 2681) | PPR Score: 0.226735
#   - Node: '۱۳ دلیل برای اینکه' (ID: 4278) | PPR Score: 0.219418
#   - Node: 'کاترین لانگفورد' (ID: 3926) | PPR Score: 0.121785
#   - Node: 'هانا بیکر' (ID: 3499) | PPR Score: 0.091013
#   - Node: 'نت‌فلیکس' (ID: 3341) | PPR Score: 0.026780
#   - Node: 'جی اشر' (ID: 1525) | PPR Score: 0.015935
#   - Node: 'توماس مک‌کارتی' (ID: 1300) | PPR Score: 0.013931
#   - Node: 'برایان یورکی' (ID: 1030) | PPR Score: 0.013333
#   - Node: 'سیزده دلیل برای اینکه' (ID: 2308) | PPR Score: 0.012820
#   - Node: 'سیزده دلیل برای اینکه adaptation' (ID: 2309) | PPR Score: 0.012199
#
# --- Top 5 Retrieved Passages ---
# 1. [Score: 0.441110] Passage (Index 71):
#    '۱۳ دلیل برای اینکه (انگلیسی: Reasons Why 13) یک سریال اینترنتی آمریکایی در ژانر درام نوجوانان و معمایی است.
# فیلم‌نامه این سریال توسط برایان یورکی بر اساس رمانی به همین نام نوشته جی اشر که در سال ۲۰۰۷ ...'
# --------------------
# 2. [Score: 0.341167] Passage (Index 335):
#    'فصل سوم مجموعه کمدی موقعیت اداره در ۲۱ سپتامبر ۲۰۰۶ در ایالات متحده از ان‌بی‌سی پخش شد و در ۱۷ مه ۲۰۰۷ به پایان رسید.
# این فصل در مجموع ۲۵ ساعت و نیم زمان داشت که به ۱۶ قسمت نیم ساعته، ۵ قسمت ۴۰ دقیقه ...'
# --------------------
# 3. [Score: 0.320178] Passage (Index 77):
#    'هانا بیکر (به انگلیسی: Hannah Baker) یک شخصیت خیالی داستانی است که توسط نویسنده آمریکایی جی اشر خلق شده‌است.
# اولین حضور این شخصیت در رمان سیزده دلیل برای اینکه نوشته جی اشر می‌باشد که در سال ۲۰۰۷ منتش...'
# --------------------
# 4. [Score: 0.315828] Passage (Index 79):
#    'هانا بیکر یک شخصیت خیالی داستانی است که توسط نویسنده آمریکایی جی اشر خلق شده‌است.
# اولین حضور این شخصیت در رمان سیزده دلیل برای اینکه نوشته جی اشر می‌باشد که در سال ۲۰۰۷ منتشر شد.
# در اقتباس سریالی این ...'
# --------------------
# 5. [Score: 0.010611] Passage (Index 300):
#    'پلی‌استیشن ۴ یک کنسول بازی ویدئویی خانگی از نسل هشتم است که از سوی شرکت سونی اینتراکتیو انترتینمنت عرضه شده‌است.
# این کنسول نخستین بار در ۲۰ فوریه سال ۲۰۱۳ در یک کنفرانس اختصاصی از سوی سونی که در شهر ن...'
# --------------------
# 6. [Score: 0.010418] Passage (Index 67):
#    'پلی‌استیشن ۳ سومین کنسول خانگی شرکت سونی کامپیوتر انترتینمنت از سری پلی‌استیشن است که در ادامه موفقیت‌های پلی‌استیشن ۲ به بازار عرضه شد.
# این کنسول از هفتمین نسل کنسول‌های بازی ویدئویی است و در ۱۱ نوام...'
# --------------------
# 7. [Score: 0.008596] Passage (Index 459):
#    'حیات (انگلیسی: Life) یک فیلم علمی–تخیلی مهیج (هیجان انگیز) و دلهره آور آمریکایی به کارگردانی دنیل اسپینوزا و نویسندگی رت ریس و پال ورنیک است که در سال ۲۰۱۷ منتشر شد.
# از بازیگران آن می‌توان به جیک جیلن...'
# --------------------
# 8. [Score: 0.007764] Passage (Index 331):
#    'دیوید والاس یک شخصیت تخیلی در مجموعه تلویزیونی کمدی اداره است که توسط اندی باکلی به تصویر کشیده‌است.
# والاس در فصل دوم به عنوان مدیر ارشد مالی جدید داندر میفلین معرفی می‌شود.
# والاس به نام دیوید فاستر و...'
# --------------------
# 9. [Score: 0.007734] Passage (Index 469):
#    'توبی فلندرسون  یک شخصیت تخیلی در مجموعه تلویزیونی کمدی آمریکایی اداره است.
# او توسط پل لیبرشتاین که نویسنده، کارگردان، تهیه‌کننده و شورانرمجموعه نیز بود، به تصویر کشیده شده‌است.
# وی نماینده منابع انسانی...'
# --------------------
# 10. [Score: 0.006936] Passage (Index 125):
#    'افسون‌نزده فیلم پویانمایی آمریکایی در ژانر کمدی رمانتیک فانتزی و موزیکال به نویسندگی و کارگردانی آدام شنکمن است که در سال ۲۰۲۲ اکران خواهد شد.
# این فیلم دنبالهٔ افسون‌زده (۲۰۰۷) است و در آن ایمی آدامز،...'
# --------------------
# 11. [Score: 0.006686] Passage (Index 51):
#    'توبی فلندرسون یک شخصیت تخیلی در مجموعه تلویزیونی کمدی آمریکایی اداره است.
# او توسط پل لیبرشتاین که نویسنده، کارگردان، تهیه‌کننده و شورانرمجموعه نیز بود، به تصویر کشیده شده‌است.
# وی نماینده منابع انسانی ...'
# --------------------
# 12. [Score: 0.006150] Passage (Index 262):
#    'اوراوا رد دایمندز (در ژاپنی: 浦和レッドダイヤモンズ به معنای: الماس‌های قرمز اوراوا) به صورت محاوره اوراوا ردز، نام یکی از تیم‌های حرفه‌ای فوتبال جی لیگ (لیگ برتر) در کشور ژاپن است که در سال ۱۹۵۰ میلادی تأسیس شد...'
# --------------------
# 13. [Score: 0.005773] Passage (Index 398):
#    'اگر سنگ از آسمان ببارد  (به انگلیسی: Hell or High Water) یک فیلم جنایی سرقتی آمریکایی به کارگردانی دیوید مکنزی و نویسندگی تیلور شریدن است.
# از بازیگران این فیلم می‌توان به کریس پاین، بن فاستر، جف بریجز...'
# --------------------
# 14. [Score: 0.005759] Passage (Index 10):
#    'اگر سنگ از آسمان ببارد یک فیلم جنایی سرقتی آمریکایی به کارگردانی دیوید مکنزی و نویسندگی تیلور شریدن است.
# از بازیگران این فیلم می‌توان به کریس پاین، بن فاستر، جف بریجز و گیل بیرمنگام اشاره کرد.
# داستان ...'
# --------------------
# 15. [Score: 0.005684] Passage (Index 247):
#    'جوایز گلدن گلوب (انگلیسی: Golden Globe Award) مجموعه جوایزی است که هرساله در ایالات متحده توسط ۹۳ عضو انجمن مطبوعات خارجی هالیوود به بهترین تولیدات سینمایی و تلویزیونی، هم داخلی و هم خارجی اهدا می‌گرد...'
# --------------------

# %%
example_query = "کدام یک از بازیگران فیلم اثر پروانه‌ای در فیلم آینه‌ها نیز ایفای نقش کرده است ؟"
VERBOSE = False
top_passages = retriever.retrieve(query=example_query, top_k=25)

print("\n--- Top 5 Retrieved Passages ---")
if top_passages:
    for i, result in enumerate(top_passages):
        print(f"{i+1}. [Score: {result['score']:.6f}] Passage (Index {result['passage_index']}):")
        print(f"   '{result['passage_text'][:]}...'")
        print("-" * 20)
else:
    print("No passages were retrieved.")
# Out:
# --- Top 5 Retrieved Passages ---
# 1. [Score: 0.872532] Passage (Index 285):
#    'ایمی لیسل اسمارت بازیگر سینما و تلویزیون و مانکن پیشین آمریکایی است.
# او حرف مدلینگ را در کشور ایتالیا شروع کرد و سپس وارد مدرسه بازیگری شد.
# اولین نقش او در فیلم کمپ‌فایر تیلز به کارگردانی مارتین کونرت بود و از آن زمان به بعد در فیلم‌های متعددی همچون سفر جاده‌ای، اثر پروانه‌ای و آینه‌ها ایفای نقش کرده‌است....'
# --------------------
# 2. [Score: 0.317362] Passage (Index 383):
#    'اثر پروانه‌ای فیلمی تریلر روان‌شناختی به نویسندگی و کارگردانی اریک برس و جیمکی گروبر و با بازیگری اشتون کوچر و ایمی اسمارت ، محصول سال ۲۰۰۴ آمریکا است.
# داستان فیلم از اثر پروانه‌ای مطرح شده در نظریه آشوب استفاده می‌کند.
# نسخه دوم این فیلم هم با نام اثر پروانه‌ای ۲ در سال ۲۰۰۶ ساخته شده‌است و نسخه سوم این فیلم هم با نام اثر پروانه‌ای ۳ سه سال بعد ساخته شد....'
# --------------------
# 3. [Score: 0.029795] Passage (Index 414):
#    'پل جرج کلبنیکوف یا پاول یوریویج خلبنیکوف (زادهٔ ۳ ژوئن ۱۹۶۳ - درگذشته ۹ ژوئیه ۲۰۰۴) یک روزنامه‌نگار آمریکایی روسی‌تبار بود.
# وی برای ده سال برای مجله فوربز کار کرد و در هنگام مرگش در سال ۲۰۰۴ ویراستار ویرایش روسی مجله بود.
# قتل کلبنیکوف در سال ۲۰۰۴ ضربه بزرگی به روزنامه‌نگاری تحقیقی در روسیه به‌شمار می‌رود.
# سه شهروند چچنی به اتهام قتل وی دستگیر ولی بعداً آزاد شدند....'
# --------------------
# 4. [Score: 0.027961] Passage (Index 132):
#    'زنی پشت پنجره یک فیلم تریلر روان‌شناختی به کارگردانی جو رایت محصول سال ۲۰۲۱ آمریکا است که فیلم‌نامه آن توسط تریسی لتس بر اساس رمانی به همین نام نوشته شده‌است.
# ایمی آدامز، جولیان مور، وایت راسل ، آنتونی مکی و گری اولدمن ستارگان فیلم هستند.
# فیلم ابتدا قرار بود در تاریخ ۴ اکتبر ۲۰۱۹ منتشر شود.
# اما به دنبال بازخورد منفی  در پیش‌نمایش آزمایشی  و پس از دنیاگیری ۲۰–۲۰۱۹ کروناویروس ، اکران فیلم برای مدتی به تعویق افتاد....'
# --------------------
# 5. [Score: 0.023157] Passage (Index 188):
#    'جوزپه فورتونینو فرانچسکو وردی آهنگساز ایتالیایی بود.
# در دهکده‌ای کوچک در ایتالیا زاده شد.
# پدرش مسافرخانه‌چی فقیری بود که خواندن و نوشتن نمی‌دانست.
# وردی جوان در ده سالگی برای تحصیل موسیقی و رفتن به مدرسه رهسپار شهر بوستو در نزدیکی زادگاهش شد.
# نه سال تمام هر یکشنبه برای آنکه کفش‌هایش خراب نشود آنها را بغل می‌زد و حدود پنج کیلومتر پابرهنه راه می‌رفت تا در کلیسای دهکده‌اش ارگ بنوازد.
# یک حامی ثروتمند، وردی را به خانه خود برد و بعدها تأمین مخارج تحصیل موسیقی او را در میلان بر عهده گرفت.
# وردی پس از پایان ۲۲ سالگی به شهر بوستو بازگشت و سرپرست موسیقی آنجا شد.
# به این ترتیب پس از اطمینان از درآمدی ثابت توانست با دختر حامی خویش، بانوی جوانی که از کودکی او را می‌شناخت و دلبسته‌اش بود، ازدواج کند....'
# --------------------
# 6. [Score: 0.023123] Passage (Index 158):
#    'جوزپه فورتونینو فرانچسکو وردی آهنگساز ایتالیایی بود.
# او در دهکده‌ای کوچک در ایتالیا زاده شد.
# پدرش مسافرخانه‌چی فقیری بود که خواندن و نوشتن نمی‌دانست.
# وردی جوان در ده سالگی برای تحصیل موسیقی و رفتن به مدرسه رهسپار شهر بوستو در نزدیکی زادگاهش شد.
# نه سال تمام هر یکشنبه برای آنکه کفش‌هایش خراب نشود آنها را بغل می‌زد و حدود پنج کیلومتر پابرهنه راه می‌رفت تا در کلیسای دهکده‌اش ارگ بنوازد.
# یک حامی ثروتمند، وردی را به خانه خود برد و بعدها تأمین مخارج تحصیل موسیقی او را در میلان بر عهده گرفت.
# وردی پس از پایان ۲۲ سالگی به شهر بوستو بازگشت و سرپرست موسیقی آنجا شد.
# به این ترتیب پس از اطمینان از درآمدی ثابت توانست با دختر حامی خویش، بانوی جوانی که از کودکی او را می‌شناخت و دلبسته‌اش بود، ازدواج کند....'
# --------------------
# 7. [Score: 0.021922] Passage (Index 169):
#    'تیم ملی فوتبال بلغارستان یک تیم فوتبال بین‌المللی است که به نمایندگی از کشور بلغارستان به میدان می‌رود.
# این تیم زیر نظر اتحادیه فوتبال بلغارستان فعالیت می‌کند.
# زمین خانگی این تیم ورزشگاه ملی وسل لفسکی واقع در شهر صوفیه است.
# بهترین عملکرد این تیم در جام جهانی در جام جهانی ۱۹۹۴ بود که آن‌ها توانستند تیم آلمان را شکست داده و به نیمه‌نهایی راه پیدا کنند، در آنجا به ایتالیا شکست خوردند و در نهایت مقام چهارم را در این جام بدست آوردند....'
# --------------------
# 8. [Score: 0.021829] Passage (Index 252):
#    'آلبانیایی‌ها (به آلبانیایی: Shqiptarët) یکی از گروه‌های نژادی شبه جزیره بالکان هستند که بیشترشان در آلبانی و کوزوو زندگی می‌کنند.
# آن‌ها به زبان آلبانیایی سخن می‌گویند.
# بیشتر آن‌ها در کوزوو و آلبانی هستند و بقیه نیز در ایتالیا، مقدونیه، مونتنگرو و یونان مستقر هستند.
# بیشینه آن‌ها مسلمانند....'
# --------------------
# 9. [Score: 0.021697] Passage (Index 373):
#    'دانته آلیگیری شاعر اهل ایتالیا بوده‌است.
# وی در سیاست زادگاه خود عاملی مؤثر بود، همچنین دانته به عنوان یکی از پیروان مکتب آلبرت کبیر شناخته می شود.
# نوشته‌های دانته بر ادبیات ایتالیا و سراسر اروپا برای همیشه تاثیر گذاشت....'
# --------------------
# 10. [Score: 0.019146] Passage (Index 89):
#    'انتونیو دی نولی نجیب‌زاده و ناوبر قرن پانزدهم میلادی اهل جنوا بود  که به عنوان نخستین حاکم، اولین مستعمره برونمرزی اروپا در آفریقای زیرصحرایی خدمت کرد.
# او برخی از بخش‌های دماغه سبز را به نمایندگی از هنری دریانورد اکتشاف نموده و از سوی شاه آفونسوی پنجم پرتغال به عنوان نخستین حاکم دماغه سبز گماشته شد.
# در بیشتر کتاب‌های تاریخ و جغرافیا، از جمله رویدادنامه‌ها یا دانشنامه‌های باستانی و همچنین در اطلاعات رسمی به‌دست آمده از حکومت دماغه سبز، از وی به‌نام انتونیو دی نولی یاد شده‌است.
# در ایتالیا او به‌نام انتونیو دان ولی (به یادداشت ۲۱ در ذیل مراجعه نمایید) یا بعضا به‌نام انتونیوتو اسودیمیر شناخته می‌شود....'
# --------------------
# 11. [Score: 0.018289] Passage (Index 4):
#    'کیران دسای (Kiran Desai) (زاده ۳ سپتامبر ۱۹۷۱) نویسنده زن هندی است.
# او در هند، انگلستان و آمریکا تحصیل کرده‌است.
# دسای با رمان میراث پوچ در سال ۲۰۰۶ جایزه بوکر را برد....'
# --------------------
# 12. [Score: 0.018287] Passage (Index 5):
#    'کیران دسای نویسنده زن اهل هند است.
# او در هند، انگلستان و آمریکا تحصیل کرده‌است.
# دسای با رمان میراث پوچ در سال ۲۰۰۶ جایزه بوکر را برد....'
# --------------------
# 13. [Score: 0.017389] Passage (Index 185):
#    'جیکوب بنجامین «جیک» جیلنهال (زادهٔ ۱۹ دسامبر ۱۹۸۰ در لس‌آنجلس)، یک هنرپیشهٔ آمریکایی است.
# پسر کارگردان، استیون جیلنهال و نمایشنامه‌نویس، ناومی فومر، بازیگری را از سن ده سالگی شروع کرد.
# او از زمانی که اولین نقش اصلی‌اش در سال ۱۹۹۹ در فیلمی به نام آسمان اکتبر بازی کرد، در نقش‌های متفاوتی ظاهر شده.
# در سال ۲۰۰۱ در فیلم دانی دارکو نقش یک نوجوان روان‌پریش را بازی کرد.
# در سال ۲۰۰۴ در فیلم پرفروش روز پس از فردا در نقش جوانی ظاهر شد که با فعل و انفعالات شیمیایی موجب سردی کرهٔ زمین شد و در نقش یک تکاور در فیلم جارهید ساخت ۲۰۰۵ بازی کرد.
# در همان سال برای بازی در نقش جک تویست در فیلم کوهستان بروکبک نامزد دریافت جایزهٔ اسکار بهترین بازیگر نقش مکمل مرد از آکادمی علوم و هنرهای تصاویر متحرک شد.
# همچنین در سال ۲۰۱۰ در فیلم شاهزاده ایران شن های زمان شخصیت اصلی را بر عهده داشت....'
# --------------------
# 14. [Score: 0.017236] Passage (Index 317):
#    'جیکوب بنجامین «جیک» جیلنهال (زادهٔ ۱۹ دسامبر ۱۹۸۰ در لس‌آنجلس)، یک هنرپیشه آمریکایی است.
# پسر کارگردان، استیون جیلنهال و نمایشنامه‌نویس، ناومی فومر، بازیگری را از سن ده سالگی شروع کرد.
# او از زمانی که اولین نقش اصلی‌اش در سال ۱۹۹۹ در فیلمی به نام آسمان اکتبر بازی کرد، در نقش‌های متفاوتی ظاهر شده.
# در سال ۲۰۰۱ در فیلم دانی دارکو نقش یک نوجوان روان‌پریش را بازی کرد.
# در سال ۲۰۰۴ در فیلم پرفروش روز پس از فردا در نقش جوانی ظاهر شد که با فعل و انفعالات شیمیایی موجب سردی کرهٔ زمین شد و در نقش یک تکاور در فیلم جارهید ساخت ۲۰۰۵ بازی کرد.
# در همان سال برای بازی در نقش جک تویست در فیلم کوهستان بروکبک نامزد دریافت جایزهٔ اسکار بهترین بازیگر نقش مکمل مرد از آکادمی علوم و هنرهای تصاویر متحرک شد.
# همچنین در سال ۲۰۱۰ در فیلم شاهزاده ایران شن های زمان شخصیت اصلی را بر عهده داشت....'
# --------------------
# 15. [Score: 0.017097] Passage (Index 431):
#    'گَل گَدوت-ورسانو    (به عبری: גל גדות؛ زادهٔ ۳۰ آوریل ۱۹۸۵) بازیگر و مُدل اسرائیلی است.
# وی در سال ۲۰۰۴ به عنوان نماینده کشور اسرائیل در مسابقهٔ دوشیزه جهان شرکت کرد.
# بیشتر شهرت او به دلیل بازی در نقش پرنسس دایانا/ زن شگفت‌انگیز در دنیای سینمایی دی‌سی است....'
# --------------------
# 16. [Score: 0.017092] Passage (Index 274):
#    'گَل گَدوت-ورسانو    (به عبری: גל גדות؛ زادهٔ ۳۰ آوریل ۱۹۸۵) بازیگر و مدل اسرائیلی است.
# وی در سال ۲۰۰۴ به عنوان نماینده کشور اسرائیل در مسابقهٔ دوشیزه جهان شرکت کرد.
# بیشتر شهرت او به دلیل بازی در نقش پرنسس دایانا در دنیای سینمایی دی‌سی است....'
# --------------------
# 17. [Score: 0.017047] Passage (Index 120):
#    'ونسا مارانو (به انگلیسی: Vanessa marano) بازیگر سریالهای تلویزیونی ، زاده ۳۱ اکتبر ۱۹۹۲ میلادی ، در شهر لس آنجلس، آمریکا به دنیا آمد.
# وی در سریال آناتومی گری (مجموعه تلویزیونی) به ایفای نقش پرداخت که این سریال برنده جایزه گلدن گلوب برای بهترین سریال درام شد.
# همچنین در سریالهای درمانگاه خصوصی، سی اس آی ، دنیای مالکوم و فیلم نجات زویی ، دافنه و ولما ، زندگی مخفی چوبک ها و لیمو لیمای عزیز هم حضور داشت .
# ونسا مارانو در مجموعه تلویزیونی درام دکستر محصول سالهای ۲۰۰۶ تا ۲۰۱۳ میلادی ایفای نقش داشت که این سریال برنده دو جایزه امی در سال ۲۰۱۰ میلادی داشت....'
# --------------------
# 18. [Score: 0.016730] Passage (Index 33):
#    'مایا رودولف کمدین و هنرپیشه اهل ایالات متحده آمریکا یهودی‌تبار است.
# وی از سال ۱۹۹۶ میلادی تاکنون مشغول فعالیت بوده‌است.
# در سال ۲۰۰۰، رودولف عضوی از بازیگران پخش زنده شنبه شب شد و به عنوان بازیگر نقش مکمل در فیلم‌های ۵۰ قرار اول (۲۰۰۴)، همراهان خانه‌ای در علف‌زار (۲۰۰۶) و ایدیوکراسی (۲۰۰۶) ظاهر شد....'
# --------------------
# 19. [Score: 0.015744] Passage (Index 437):
#    '۵۰ تا قرار اول فیلمی است کمدی رمانتیک محصول سال ۲۰۰۴ به کارگردانی پیتر سگال.
# در این فیلم بازیگرانی همچون آدام سندلر، درو بریمور، راب اشنایدر، شان آستین، لوئیسیا استراس، بلیک کلارک، میسی پایل و دن اکروید ایفای نقش کرده‌اند.
# این فیلم دومین همکاری مشترک درو بریمور و آدام ساندلر می‌باشد.
# در ایران فیلم چپ دست به تقلید از این فیلم ساخته شد....'
# --------------------
# 20. [Score: 0.015593] Passage (Index 119):
#    'خاطرات بریجت جونز (به انگلیسی: Bridget Jones's Diary) فیلمی محصول سال ۲۰۰۱ انگلستان به کارگردانی شارون مگوایر است.
# در این فیلم بازیگرانی همچون رنی زلوگر، هیو گرانت، کالین فرث، جیم برودبنت، امبت دیویتس و جما جونز، سلیا ایمری، جیمز فوکنر، شرلی هندرسون، جیمز کالیس، لیزا باربوسکیا، دالی ولز و دونالد داگلاس ایفای نقش کرده‌اند.
# دنباله‌های این فیلم در سال ۲۰۰۴ با نام بریجت جونز: نکته باریک و سال ۲۰۱۶ با نام بچه بریجت جونز ساخته شده است....'
# --------------------
# 21. [Score: 0.015023] Passage (Index 255):
#    'پاتریشیا رونی مارا (انگلیسی: Patricia Rooney Mara؛ زادهٔ ۱۷ آوریل ۱۹۸۵) بازیگر آمریکایی است.
# او یکی از اعضای خانواده‌های رونی و مارا است و فعالیت حرفه‌ای خود را از سال ۲۰۰۵ با بازی در تلویزیون و فیلم‌های مستقل مانند نقش اصلی فیلم تنر هال (۲۰۰۹) آغاز کرده‌است.
# او در سال ۲۰۱۰ برای بازی در نقش مکمل درام زندگی‌نامه‌ای شبکهٔ اجتماعی ساختهٔ دیوید فینچر در میان مردم شناخته شد....'
# --------------------
# 22. [Score: 0.014977] Passage (Index 176):
#    'پرواز بر فراز آشیانه فاخته رمانی‌ است که کن کیسی، نویسنده آمریکایی، به سال ۱۹۶۲ نگاشته‌است.
# رمان در بیمارستانی روانی در ایالت اورگن آمریکا می‌گذرد و حاوی نگاهیست به ساختارهای قدرت در سازمان‌ها.
# همچنین رمان به نقد مکتب روان‌شناسی رفتارگرایی می‌پردازد و اصول انسانی را می‌ستاید.
# نویسنده داستان مدتی را به عنوان کارمند بیمارستان روانی در منلو پارک کالیفرنیا سپری کرده بود و نسبت به بیماران روانی احساس همدردی می‌کرد.
# این رمان ابتدا در سال ۱۹۶۳ به صورت نمایشنامه درآمد، اما برداشت بسیار مشهورتر آن، فیلم دیوانه از قفس پرید است که در سال ۱۹۷۵ با کارگردانی میلوش فورمن و بازی جک نیکلسون بر اساس این داستان ساخته شده‌است.
# این فیلم برنده ۵ جایزه اسکار شد....'
# --------------------
# 23. [Score: 0.014907] Passage (Index 13):
#    'پرومتئوس (به انگلیسی: Prometheus) فیلمی علمی-تخیلی به کارگردانی ریدلی اسکات و نویسندگی جون اسپایتس و دیمون لیندلوف است که محصول ژوئن ۲۰۱۲ در آمریکا و تعدادی کشورهای دیگر اکران شد.
# این فیلم با ۱۳۰ میلیون دلار بودجه تولید  و با بازیگرانی چون نومی راپاس، شارلیز ترون و ادریس البا نقش آفرینی کردند.
# طبق گفته اسکات، داستان فیلم می‌تواند به نوعی قصهٔ اولیه یا ماقبل سری فیلم‌های بیگانه تلقی گردد هرچند داستانی کاملاً مستقل دارد.
# فیلمبرداری فیلم از مارس ۲۰۱۱ آغاز شد و فیلم به صورت ۳ بعدی اکران شد....'
# --------------------
# 24. [Score: 0.014907] Passage (Index 456):
#    'پرومتئوس (به انگلیسی: Prometheus) فیلمی علمی-تخیلی به کارگردانی ریدلی اسکات و نویسندگی جون اسپایتس و دیمون لیندلوف است که در ژوئن ۲۰۱۲ در آمریکا و تعدادی کشورهای دیگر اکران شد.
# این فیلم با ۱۳۰ میلیون دلار بودجه تولید  و با بازیگرانی چون نومی راپاس، شارلیز ترون و ادریس البا نقش آفرینی کردند.
# طبق گفته اسکات، داستان فیلم می‌تواند به نوعی قصهٔ اولیه یا ماقبل سری فیلم‌های بیگانه تلقی گردد هرچند داستانی کاملاً مستقل دارد.
# فیلمبرداری فیلم از مارس ۲۰۱۱ آغاز شد و فیلم به صورت ۳ بعدی اکران شد....'
# --------------------
# 25. [Score: 0.014906] Passage (Index 103):
#    'جرج لوکاس جونیور کارگردان، تهیه‌کننده، فیلم‌نامه‌نویس و کارآفرین آمریکایی است.
# او بیشتر برای خلق فرنچایزهای جنگ ستارگان و ایندیانا جونز و تأسیس کمپانی‌های لوکاس‌فیلم، لوکاس‌فیلم گیمز و اینداستریال لایت اند مجیک شناخته شده‌است.
# او تا سال ۲۰۱۲ رئیس کمپانی لوکاس‌فیلم بود و در نهایت این کمپانی را به شرکت والت دیزنی فروخت.
# لوکاس یکی از موفق‌ترین فیلم‌سازان تجاری در تاریخ است و نامزد دریافت چهار جایزهٔ اسکار شده‌است.
# فیلم‌های او با توجه به تورم در میان ۱۰۰ فیلم پرفروش گیشهٔ آمریکای شمالی قرار گرفته‌اند.
# لوکاس یکی از مهم‌ترین چهره‌های جنبش هالیوود نو در قرن بیستم و از پیشگامان بلاکباستر مدرن محسوب می‌شود....'
# --------------------

# %% [markdown]
# # RAG pipeline

# %%
class StructuredAnswer(BaseModel):
    final_answer: str = Field(
        description="The final, concise answer to the user's question."
    )

# %%
class QuestionAnsweringSystem:
    def __init__(self, retriever: HippoRAGRetriever):
        self.retriever = retriever
        self.llm = ChatOpenAI(
             model="gpt-4o-mini", temperature=0, api_key=os.getenv("METIS_API_KEY"), base_url="https://api.metisai.ir/openai/v1"
        )
        self.qa_prompt = self._create_qa_prompt()

    def _create_qa_prompt(self):
        answer_types_guidance = [
            "اسامی عام", 
            "شخص", 
            "بلی/خیر", 
            "تاریخ", 
            "رویداد", 
            "مکان", 
            "اسامی خاص دیگر", 
            "شماره", 
            "کار هنری", 
            "گروه یا سازمان", 
            "صفت"
        ]
        
        system_prompt = f"""
        You are an expert Question Answering assistant. Your task is to answer the user's question based *only* on the provided context.
        First, think step-by-step.
        Then, provide a clear and very concise final answer. The answer should be a direct value, like one of the following types: {answer_types_guidance}.

        --- ONE-SHOT EXAMPLE ---
        CONTEXT:
        Passage 1: The Eiffel Tower is a wrought-iron lattice tower on the Champ de Mars in Paris, France. It is named after the engineer Gustave Eiffel, whose company designed and built the tower.
        Passage 2: The construction of the Eiffel Tower began in January 1887 and was completed on 31 March 1889.

        QUESTION:
        When was the Eiffel Tower finished?

        YOUR STRUCTURED OUTPUT:
        {{{{
            "final_answer": "31 March 1889"
        }}}}
        --- END OF EXAMPLE ---
        """

        return ChatPromptTemplate.from_messages([
            ("system", system_prompt),
            ("human", "CONTEXT:\n{context}\n\nQUESTION:\n{question}\n\nYOUR STRUCTURED OUTPUT:")
        ])

    def answer_question(self, query: str, top_k_retrieval: int = 5) -> str:
        # Retrieve relevant passages using HippoRAG
        retrieved_passages = self.retriever.retrieve(query, top_k=top_k_retrieval)
        
        if not retrieved_passages:
            print("No relevant context found. Cannot generate an answer.")
            return "Could not find any relevant information to answer the question."

        context_string = ""
        for i, doc in enumerate(retrieved_passages):
            context_string += f"Passage {i+1} (Score: {doc['score']:.4f}):\n{doc['passage_text']}\n\n"
        
        # Generate the final answer using the LLM with structured output
        structured_chain = self.qa_prompt | self.llm.with_structured_output(StructuredAnswer)
        
        try:
            response = structured_chain.invoke({
                "context": context_string.strip(),
                "question": query
            })
            return response.final_answer
        except Exception as e:
            print(f"Failed to generate structured answer: {e}")
            return "Failed to generate a structured answer from the context."

# %%
qa_system = QuestionAnsweringSystem(retriever=retriever)

# %%
VERBOSE = False
example_query = "آیا کاترین لانگفورد نقش دختر بچه نوجوانی که هانا بیکر نام داشت را در سریال ۱۳ دلیل برای اینکه بازی کرده است ؟"
final_answer = qa_system.answer_question(example_query, top_k_retrieval=5)

print(final_answer)
# Out:
# بلی

# %%
example_query = "کدام یک از بازیگران فیلم اثر پروانه‌ای در فیلم آینه‌ها نیز ایفای نقش کرده است ؟"
final_answer = qa_system.answer_question(example_query, top_k_retrieval=5)

print(final_answer)
# Out:
# ایمی اسمارت

# %%
with open('../../data/test_data.json', 'r', encoding='utf-8') as f:
    test_dataset = json.load(f)

df_test = pd.DataFrame(test_dataset)
df_test.head()
# Out:
#      id       type     answer_type  \
# 0     3  مقایسه‌ای         بلی/خیر
# 1  2255         پل             شخص
# 2     8         پل  اسامی خاص دیگر
# 3     9         پل  اسامی خاص دیگر
# 4    10         پل         بلی/خیر
#
#                                             question              answer  \
# 0  آیا کاترین لانگفورد نقش دختر بچه نوجوانی که ها...                 بله
# 1  کدام یک از بازیگران فیلم اثر پروانه‌ای در فیلم...         ایمی اسمارت
# 2  کدام بازی ویدیویی شرکتی ژاپنی منبع الهام طراحی...  برادران سوپر ماریو
# 3  یکی از بازی های معروف شرکتی که اولین کنسول باز...  برادران سوپر ماریو
# 4  آیا جایزه ای که سیدیبه در سال 2007 آن را دریاف...                 بله
#
#                                     supporting_facts  \
# 0    [[۱۳ دلیل برای اینکه , [3]], [هانا بیکر , [4]]]
# 1  [[اثر پروانه‌ای (فیلم) , [0]], [ایمی اسمارت , ...
# 2                [[سوپرتاکس , [2]], [نینتندو , [0]]]
# 3                [[سوپرتاکس , [2]], [نینتندو , [3]]]
# 4        [[مالک سیدیبه , [3]], [شیر طلایی , [0, 3]]]
#
#                                              context
# 0  [[۱۳ دلیل برای اینکه , [۱۳ دلیل برای اینکه (ان...
# 1  [[اثر پروانه‌ای (فیلم) , [اثر پروانه‌ای فیلمی ...
# 2  [[سوپرتاکس , [سوپرتاکس (به انگلیسی: SuperTux) ...
# 3  [[سوپرتاکس , [سوپرتاکس (به انگلیسی: SuperTux) ...
# 4  [[مالک سیدیبه , [مالک سیدیبه (انگلیسی: Malick ...

# %%
results_no_reasoning = []
for i in tqdm(range(len(df_test))):
    row = df_test.iloc[i]
    question = row['question']
    answer = row['answer']
    model_answer = qa_system.answer_question(question, top_k_retrieval=10)
    results_no_reasoning.append({'question': question, 'answer': answer, 'model_answer': model_answer})
    

with open('results_no_reasoning.json', 'w', encoding='utf-8') as f:
    json.dump(results_no_reasoning, f, ensure_ascii=False, indent=4)
# Out:
# 100%|██████████| 152/152 [05:46<00:00,  2.28s/it]

# %% [markdown]
# # Evaluateate the results using LLM judge

# %%
import os
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage, SystemMessage
from langchain_core.prompts import ChatPromptTemplate
from pydantic import BaseModel, Field
from typing import List, Dict, Any
import json
import re
from tqdm import tqdm

# %%
with open('results_no_reasoning.json', 'r', encoding='utf-8') as f:
    results = json.load(f)

# %%
results
# Out:
# [{'question': 'آیا کاترین لانگفورد نقش دختر بچه نوجوانی که هانا بیکر نام داشت را در سریال ۱۳ دلیل برای اینکه بازی کرده است ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'کدام یک از بازیگران فیلم اثر پروانه\u200cای در فیلم آینه\u200cها نیز ایفای نقش کرده است ؟',
#   'answer': 'ایمی اسمارت',
#   'model_answer': 'ایمی اسمارت'},
#  {'question': 'کدام بازی ویدیویی شرکتی ژاپنی منبع الهام طراحی بازی سوپرتاکس بوده است ؟',
#   'answer': 'برادران سوپر ماریو',
#   'model_answer': 'برادران سوپر ماریو'},
#  {'question': 'یکی از بازی های معروف شرکتی که اولین کنسول بازی ویدیویی خود را در سال ۱۹۹۷ توزیع کرد ؟',
#   'answer': 'برادران سوپر ماریو',
#   'model_answer': 'بلی/خیر'},
#  {'question': 'آیا جایزه ای که سیدیبه در سال 2007 آن را دریافت کرد برای افرادی است که نقش مهمی در سینما داشته\u200cاند ؟',
#   'answer': 'بله',
#   'model_answer': 'خیر'},
#  {'question': 'آیا محمدرضا ترکی در نشریه نامه فرهنگستان نقش تصمیم گیرنده پذیرش یا رد مقالات را بر عهده داشت ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'آیا شرکت سازنده دورنیر دو ۲۱۷ هواگردهای نظامی و غیرنظامی بسیاری را طراحی و تولید نموده است  ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'کدام یک از زبان هایی که کلمه حمد در آن استفاده می شود در جنوب آسیا گفتگو می شود ؟',
#   'answer': 'زبان اردو',
#   'model_answer': 'اردو'},
#  {'question': 'آیا شرکتی که بازی این\u200cاسلیو: اودیسه به سمت غرب  توسط آن منتشر شده یک شرکت چند ملیتی می باشد ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'شرکتی که بازی این\u200cاسلیو: اودیسه به سمت غرب  توسط آن منتشر شده است در کدام کشور قرار دارد ؟',
#   'answer': 'ژاپن',
#   'model_answer': 'فرانسه'},
#  {'question': 'برنامه تلویزیونی زابیواکا برای چندمین دوره ی جام جهانی پخش شد ؟',
#   'answer': 'بیست و یکمین',
#   'model_answer': 'جام جهانی ۲۰۱۸'},
#  {'question': 'کدام ویژه برنامه در بیست و یکمین دوره جام جهانی فوتبال از تلویزیون اینترنتی آیو اسپرت پخش شد ؟',
#   'answer': 'زابیواکا',
#   'model_answer': 'زابیواکا'},
#  {'question': 'جام جهانی که برنامه تلویزیونی زابیواکا ویژه آن پخش شد با قهرمانی کدام تیم پایان یافت ؟',
#   'answer': 'فرانسه',
#   'model_answer': 'تیم ملی فوتبال فرانسه'},
#  {'question': 'کدام ویژه برنامه در اولین دوره جام جهانی فوتبال در اروپای شرقی از تلویزیون اینترنتی آیو اسپرت پخش شد ؟',
#   'answer': 'زابیواکا',
#   'model_answer': 'زابیواکا'},
#  {'question': 'داده های ماهواره ای که نخستین\u200c بار نقشه\u200cبردار موضوعی بر روی آن نصب شد در چه سالی فعالیتش پایان یافت ؟',
#   'answer': 'سال ۱۹۹۳',
#   'model_answer': '۲۰۰۰'},
#  {'question': 'آیا ویژه برنامه بیست و یکمین دوره ی جام جهانی فوتبال توسط مجید یاسر و علی انصاریان اجرا شد ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'آیا فرانسه در جام جهانی ای که ویژه برنامه زابیواکا از تلویزیون اینترنتی آیو اسپرت پخش می\u200cشد قهرمان جهان شد ؟',
#   'answer': 'بله',
#   'model_answer': 'خیر'},
#  {'question': 'آیا نویسنده\u200cی هری پاتر و تالار اسرار چند داستان جنایی نوشته است ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'آیا مجموعه فانتزی هری پاتر و ترانه بیلی جین از پرفروش ترین آثار می باشند ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'کدام بازیگر آمریکایی که در فیلم نیمه ماه مارس ایفای نقش کرده نامزد دریافت یک جایزهٔ فیلم بفتا و یک جایزهٔ گلدن گلوب بوده\u200cاست ؟',
#   'answer': 'مریسا تومی',
#   'model_answer': 'مریسا تومِی'},
#  {'question': 'استودیویی که فیلم کایوت در برابر اکمی در آینده به وسیله آن توزیع خواهد شد متعلق به کدام رسانه است ؟',
#   'answer': 'رسانه وارنر',
#   'model_answer': 'رسانه وارنر'},
#  {'question': 'کدام تیم ژاپنی سابقه ۲ قهرمانی در رقابت سالانهٔ فوتبال باشگاهی قاره\u200cای که توسط کنفدراسیون فوتبال آسیا اداره می\u200cشود را دارد ؟',
#   'answer': 'اوراوا رد دایمندز',
#   'model_answer': 'اوراوا رد دایمندز'},
#  {'question': 'نام رسمی لیگی که تیم اوراوا رد دایمندز سابقه قهرمانی در فصل\u200cهای ۲۰۰۷ و ۲۰۱۷ را در آن دارد چیست ؟',
#   'answer': 'لیگ قهرمانان ای\u200cاف\u200cسی',
#   'model_answer': 'لیگ قهرمانان آسیا'},
#  {'question': 'سرمربی فعلی تیم ملی فوتبالی که فرانسیسکو خنتو در دورانی ۱۴ ساله از سال ۱۹۵۵ تا ۱۹۶۹ عضو آن بوده چه کسی است ؟',
#   'answer': 'لوییس انریکه',
#   'model_answer': 'لوییس انریکه'},
#  {'question': 'کدام بازیگر فیلم حیات در سال ۲۰۱۰ در فیلم شاهزاده ایران شن های زمان شخصیت اصلی را بر عهده داشت است ؟',
#   'answer': 'جیک جیلنهال',
#   'model_answer': 'جیک جیلنهال'},
#  {'question': 'یکی از بازیگران فیلم حیات که بازیگری را در ده سالگی شروع کرد، در سال ۲۰۰۴ چه فیلمی بازی کرده است ؟',
#   'answer': 'روز پس از فردا',
#   'model_answer': 'روز پس از فردا'},
#  {'question': 'نام یکی از بازیگران فیلم حیات که در فیلمی در سال 2005 در نقش یک تکاور بازی می کرد چیست ؟',
#   'answer': 'جیک جیلنهال',
#   'model_answer': 'جیک جیلنهال'},
#  {'question': 'دفتر اصلی شرکت چینی که تلفن هوشمند هواوی آنر ۴سی را تحت برند آنر عرضه کرده در کدام شهر است ؟',
#   'answer': 'شنژن',
#   'model_answer': 'پکن'},
#  {'question': 'آیا فیلیپ تورتون در شهر تاریخی ای که مرکز نورماندی بود متولد شده است ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'سابقه ی یک سوغات اصفهان که از صنایع دستی محسوب میشود حدود چند سال است ؟',
#   'answer': 'پنج هزار سال',
#   'model_answer': 'حدود پنج هزار سال'},
#  {'question': ' محصولی که چهارمین محصول کشاورزی کشت شده در جهان بوده و در آن نیکوتین وجود دارد چه نام دارد ؟',
#   'answer': 'سیب زمینی',
#   'model_answer': 'سیب\u200cزمینی'},
#  {'question': 'شرکت عرضه کننده بازی های فال اوت و الدر اسکورولز که بازی رستاخیز را هم عرضه کرده است چه نام دارد ؟',
#   'answer': 'بتزدا',
#   'model_answer': 'بتزدا'},
#  {'question': 'شرکت زیر مجموعه ماکروسافت که بازی رستاخیز را برای ویندوز، اکس باکس و پلی استیشن عرضه کرده است چه نام دارد ؟',
#   'answer': 'بتزدا',
#   'model_answer': 'بتزدا'},
#  {'question': 'آیا ماکروسافت شرکت منتشر کننده بازی رستاخیز را در سال ۲۰۲۰ خریداری کرده است ؟',
#   'answer': 'بله',
#   'model_answer': 'خیر'},
#  {'question': 'در جنگی که آنه فرانک در آن کشته شد حدود چند نفر کشته شدند ؟',
#   'answer': '۷۰ تا ۸۵ میلیون',
#   'model_answer': 'حدود ۷۰ تا ۸۵ میلیون'},
#  {'question': 'چند کشور جهان در جنگی که آنه فرانک در آن کشته شد درگیر شدند ؟',
#   'answer': '30 کشور',
#   'model_answer': 'بیش از ۳۰ کشور'},
#  {'question': 'عنصر اصلی ماده ای که پودر سنگ از آن بر اثر نیروی سایش یخچال ها بر کف یخچال به وجود می\u200cآید چیست ؟',
#   'answer': 'سلیس',
#   'model_answer': 'سنگ'},
#  {'question': 'کدام یک از فیلم هایی که موسیقی آن در استودیو بل ضبط شده است در روزهای دوشنبه پخش می شد ؟',
#   'answer': 'سربداران',
#   'model_answer': 'سربداران'},
#  {'question': 'نوسینده کدام یک از فیلم هایی که در استودیو  بل ضبط شده است کیهان رهگذار بوده است ؟',
#   'answer': 'بله',
#   'model_answer': 'سربداران'},
#  {'question': 'پادشاه افغانی که سد سرده در زمان آن ساخته شد به مدت چند سال بر افغانستان حمک فرمایی کرد ؟',
#   'answer': 'چهل سال',
#   'model_answer': 'چهل سال'},
#  {'question': 'آیا پادشاه افغانی که سد سرده در زمان آن ساخته شد توانست دوره\u200cای از صلح پایدار را در افغانستان برقرار کند ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'در جشنواره ای که نخستین نمایش فیلم اگر سنگ از آسمان ببارد در آن انجام شد چه کسی رئیس هیئت داوران بود ؟',
#   'answer': 'جرج میلر',
#   'model_answer': 'اسامی عام'},
#  {'question': 'در جشنواره ای که نخستین نمایش فیلم اگر سنگ از آسمان ببارد در آن انجام شد شهاب حسینی جایزه بهترین بازیگر نقش اول مرد را دریافت کرد ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'بازیگر نقش اصلی فیلم تنر هال در کدام فیلم به همراه کیت بلانشت نقش آفرینی کرده است ؟',
#   'answer': 'کوچه کابوس',
#   'model_answer': 'کوچهٔ کابوس'},
#  {'question': 'کدام بازیگر فیلم تریپل اکس موسیقی\u200cدان اهل ایالات متحده آمریما است ؟',
#   'answer': 'ایو',
#   'model_answer': 'ایو'},
#  {'question': 'آیا کارگردان دو فیلم استخراج و ماشین پلیس جان واتس می باشد ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'کارگردان فیلم استخراج از چه سالی مشغول به فعالیت است ؟',
#   'answer': '2005',
#   'model_answer': 'بیش از ۳۰ سال'},
#  {'question': 'آیا ایو و استیون سی میلر هر دو آمریکایی هستند ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'کارگردان دو فیلم پرومتئوس و مجموعه فیلم بیگانه چه کسی می باشد ؟',
#   'answer': 'ریدلی اسکات',
#   'model_answer': 'ریدلی اسکات'},
#  {'question': 'آیا قورباغه ها و مارمولک\u200cها هر دو از راسته بی\u200cدمان هستند ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'کدام زبان برنامه نویسی که توسط بلوفیش پشتیبانی می شود از لحاظ نحو شبیه به سی\u200cشارپ است ؟',
#   'answer': 'والا',
#   'model_answer': 'والا'},
#  {'question': 'در کدام کتاب از سردبیر مجله کارنامه از حسین پاینده به عنوان منتقدی که به پیش برد نقد ادبی یاری رسانده یاد شده است ؟',
#   'answer': 'باغ در باغ',
#   'model_answer': 'باغ در باغ'},
#  {'question': 'آیا نویسنده کتاب باغ در باغ از تأثیرگذارترین داستان\u200cنویسان معاصر زبان فارسی بوده است ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'مجله ای که پل جرج کلبنیکوف به مدت ده سال برای آن کار می کرد توسط چه کسی تاسیس شد ؟',
#   'answer': 'بیسی فوربز',
#   'model_answer': 'بیسی فوربز'},
#  {'question': 'از بین نگاناسان\u200cها و مردم انتس جمعیت کدام کمتر است ؟',
#   'answer': 'انتس',
#   'model_answer': 'مردم انتس'},
#  {'question': 'آیا شغل اصلی نگاناسان\u200cها و مردم انتس دامپروری در گله\u200cهای گوزن شمالی می\u200cباشد ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'آیا نگاناسان\u200cها و مردم انتس هر دو به زبان نگاناسانی تکلم می کنند ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'آیا نگاناسان\u200cها و مردم انتس هر دو نزدیک به مدار قطب شمال به\u200cسر می\u200cبرند ؟',
#   'answer': 'خیر',
#   'model_answer': 'بلی'},
#  {'question': 'کدام یک از بازیگران فیلم آخرین شکارچی جادوگر برنده اسکار و گلدن گلوب شده است ؟',
#   'answer': 'مایکل کین',
#   'model_answer': 'بلی'},
#  {'question': 'آیا شرکت تکمو در همان سالی که بازی نینجا گایدن اولین بار در آمریکای شمالی عرضه شد تاسیس گردید ؟',
#   'answer': 'خیر',
#   'model_answer': 'بلی'},
#  {'question': 'تصویرگر مجموعه شکار جانور شگفت\u200cانگیز از اعضای کدام گروه نقاشان بود ؟',
#   'answer': 'پیشارافائلی',
#   'model_answer': 'هنری هالیدی'},
#  {'question': ' کدام یک از نشانه های آبله\u200cمیمون باعث می شود بسیاری از میکروب ها توانایی رشد نداشته باشند ؟',
#   'answer': 'تب',
#   'model_answer': 'تب'},
#  {'question': 'آیا موسس سورا ال\u200cتی\u200cدی مجموعه بازی برادران سوپر اسمش را منتشر کرده است  ؟',
#   'answer': 'خیر',
#   'model_answer': 'بلی'},
#  {'question': 'شرکت منتشر کننده آهنگ بیلی جین در چه سالی بنیان\u200cگذاشته شد ؟',
#   'answer': 'سال 1953',
#   'model_answer': '۱۹۵۳'},
#  {'question': 'کسی که شخصیت های مجموعه تجربیات سریالی لین را طراحی کرده عمدتا در کدام حوزه کار می کند ؟',
#   'answer': 'انیمه و مانگا',
#   'model_answer': 'انیمه و مانگا'},
#  {'question': 'کدام یک از مردمانی که از تکنیک تیراندازی با کمان استفاده می کردند قومی از نژاد زرد هستند ؟',
#   'answer': 'مغول\u200cها',
#   'model_answer': 'مغول'},
#  {'question': 'کدام یک از فلزات نجیب به معنی زنده می باشد ؟',
#   'answer': 'جیوه',
#   'model_answer': 'جیوه'},
#  {'question': 'آیا نقره زنده به عنوان فلزات نجیب شناخته می شود ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'کنسول بازی که ایس کمبت ۷: آسمان\u200cهای ناشناخته در ژانویه 2019 برای آن منتشر شد توسط کدام شرکت معرفی شده است ؟',
#   'answer': 'مایکروسافت',
#   'model_answer': 'سونی'},
#  {'question': 'آیا شرکت نینتندو زودتر از شرکت تکمو تاسیس شد ؟',
#   'answer': 'خیر',
#   'model_answer': 'بلی'},
#  {'question': 'آیا جایزه ادبی من بوکر و جوایز گلدن گلوب هر دو به بهترین تولیدات سینمایی و تلویزیونی، هم داخلی و هم خارجی اهدا می\u200cگردد ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'آیا نخستین جوایز گلدن گلوب زودتر از جایزه شیر طلایی اهدا گردید ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'آیا نینجا گایدن و ندای وظیفه هر دو توسط یک شرکت منتشر شده اند ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'آیا شرکت منتشر کننده نینجا گایدن بازی ندای وظیفه را منتشر کرده است ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'آیا کسی که بازی سوپرتاکس را توسعه داده بازی ندای وظیفه را منتشر کرده است ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'آیا بازی ندای وظیفه و بازی ایس کمبت ۷: آسمان\u200cهای هر دو توسط یک فرد منتشر شده اند ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'آیا کارگردان فیلم آلیس در شهرها نوسینده فیلم پرومتئوس بوده است ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'آیا فیلم آلیس در شهرها و فیلم پرومتئوس محصول یک سال می باشند ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'آیا فیلمبرداری فیلم آلیس در شهرها توسط  نویسندگان فیلم پرومتئوس انجام شده است ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'آیا فیلم آلیس در شهرها و فیلم نیمه ماه مارس درام می باشند ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'آیا فیلم آلیس در شهرها و فیلم نیمه ماه مارس توسط ویم وندرس کارگردانی شده اند ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'خانواده سلطنتی شیخ خلیفه بن حمد بن خلیفه آل ثانی از چه سالی بر کشور قطر حکمرانی می\u200cکنند ؟',
#   'answer': 'سال 1850',
#   'model_answer': 'از سال ۱۸۵۰'},
#  {'question': 'آیا از خانواده سلطنتی شیخ خلیفه بن حمد بن خلیفه آل ثانی تاکنون 9 نفر به\u200cعنوان امیر قطر منصوب شده\u200cاند ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'کدام یک از فیلم هایی که حفیصه حرزی در آن نقش داشته نخستین بار در بخش رقابتی جشنواره فیلم کن ۲۰۱۱ اکران شد ؟',
#   'answer': 'خانه بردباری',
#   'model_answer': 'خانهٔ بردباری'},
#  {'question': 'کدام یک از فیلم هایی که حفیصه حرزی در آن نقش داشته در سبک درام است ؟',
#   'answer': 'خانه بردباری',
#   'model_answer': 'خانه بردباری'},
#  {'question': 'کدام یک از فیلم هایی که حفیصه حرزی در آن نقش داشته در سال ۲۰۱۱ منتشر شد ؟',
#   'answer': 'خانه بردباری',
#   'model_answer': 'خانه بردباری'},
#  {'question': 'کارگردان کدام یک از فیلم هایی که حفیصه حرزی در آن نقش داشته برتران بونلو بوده است ؟',
#   'answer': 'خانه بردباری',
#   'model_answer': 'خانه بردباری'},
#  {'question': 'فردی که شخصیت تخیلی لوک اسکای\u200cواکر توسط او پدید آمده است تا چه سالی رئیس کمپانی لوکاس فیلم بود ؟',
#   'answer': '2012 سال',
#   'model_answer': '۲۰۱۲'},
#  {'question': 'فردی که شخصیت تخیلی لوک اسکای\u200cواکر توسط او پدید آمده است کمپانی لوکاس فیلم را به کدام شرکت فروخت ؟',
#   'answer': 'شرکت والت دیزنی',
#   'model_answer': 'شرکت والت دیزنی'},
#  {'question': 'آیا فردی که شخصیت تخیلی لوک اسکای\u200cواکر توسط او پدید آمده است از مهم\u200cترین چهره\u200cهای جنبش هالیوود نو بود ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'کدام یک از خطرناکترین انواع بیماری\u200cهایی که توسط برخی انواع پشه منتقل می\u200cشوند از فیلاریا منشا می\u200c گیرد ؟',
#   'answer': 'فیلاریازیس',
#   'model_answer': 'فیلاریازیس'},
#  {'question': 'کدام یک از رهبران سیاسی روسیه و متحدانش در ده سالگی به حکومت رسید ؟',
#   'answer': 'پطر کبیر',
#   'model_answer': 'پتر یکم'},
#  {'question': 'آیا روزنامه ای که جاستین چنگ برای آن می\u200cنویسد دومین روزنامه بزرگ مناطق شهری در ایالات متحده می\u200cباشد ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'کدام یک از روزنامه هایی که جاستین چنگ برای آن می\u200cنویسد در قسمت غربی ایالات متحده آمریکا توزیع می\u200cشود ؟',
#   'answer': 'لس آنجلس تایمز',
#   'model_answer': 'لس آنجلس تایمز'},
#  {'question': 'لقب نویسنده رمان خورشید همچنان می\u200cدمد چه بود ؟',
#   'answer': 'پدر ادبیات مدرن',
#   'model_answer': 'ارنست همینگوی'},
#  {'question': 'آیا نویسنده رمان خورشید همچنان می\u200cدمد از پایه\u200cگذاران وقایع\u200cنگاری ادبی شناخته می شود ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'از بین مجموعه تلوزیونی اداره و فصل سوم مجموعه کمدی موقعیت اداره کدام یک زودتر پخش شده است ؟',
#   'answer': 'مجموعه تلوزیونی اداره',
#   'model_answer': 'بلی'},
#  {'question': 'کدام یک از شرکت\u200cهای هواپیمایی که در فرودگاه بین\u200cالمللی سپهبد شهید قاسم سلیمانی فعال هستند در سال 1351 راه\u200cاندازی  شده اند ؟',
#   'answer': 'ایران ایرتور',
#   'model_answer': 'ایران ایرتور'},
#  {'question': 'آیا دو فیلم فردایی بهتر و قهرمانان گریه نمی\u200cکنند را جان وو کارگردانی کرده است ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'آیا دو فیلم آرتی شاو: زمان چیزی است که به\u200cدست آورده\u200cای و بی\u200cخانمانی در آمریکا هر دو در یک سال منتشر شده اند ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'آیا دو فیلم آرتی شاو: زمان چیزی است که به\u200cدست آورده\u200cای و بی\u200cخانمانی در آمریکا برنده جایزه اسکار بهترین فیلم مستند شده اند ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'از بین نیما عالمیان و نوشاد عالمیان کدام یک فعالیت خود را از سال 2000 شروع کرده\u200cاند ؟',
#   'answer': 'نیما عالمیان',
#   'model_answer': 'نیما عالمیان'},
#  {'question': 'آیا نیما عالمیان و نوشاد عالمیان هر دو فعالیت خود را از سال 1998 شروع کرده\u200cاند؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'آیا نیما عالمیان و نوشاد عالمیان هر دو اکنون عضو باشگاه توقینیه فویلارد هستند؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'آیا نیما عالمیان و نوشاد عالمیان هر دو بازیکن تنیس روی میز و ملی\u200cپوش اهل ایران هستند؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'کارگردان مستند تقاطع تحصیلاتش را در چه رشته ای به پایان برده است ؟',
#   'answer': 'مهندسی کشاورزی',
#   'model_answer': 'مهندسی کشاورزی'},
#  {'question': 'آیا کارگردان مستند تقاطع برنده سیمرغ بلورین برای بهترین فیلم مستند شده است ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'کارگردان مستند تقاطع سیمرغ بلورین بهترین فیلم مستند را برای کدام فیلم برنده شده است ؟',
#   'answer': 'فیلم نیمه بلند اتاق صعود',
#   'model_answer': 'اتاق صعود'},
#  {'question': 'کدام یک از فیلم\u200cهای کیم یونگ-کوانگ بیش از 8 جایزه را از آن خود کرده است ؟',
#   'answer': 'پینوکیو',
#   'model_answer': 'بلی'},
#  {'question': 'کدام یک از فیلم\u200cهای کیم یونگ-کوانگ در چین و تایلند و ژاپن پخش شده است؟',
#   'answer': 'پینوکیو',
#   'model_answer': 'پینوکیو'},
#  {'question': 'برشی که روش اکسایش حرارتی تولید یک لایه نازک اکسید بر روی سطح آن می\u200cکند توسط کدام فرایند برش می\u200cخورد ؟',
#   'answer': 'برش ویفر یا ویفر دایسینگ',
#   'model_answer': 'برش ویفر یا ویفر دایسینگ'},
#  {'question': 'کدام یک از فیلم\u200cهایی که لقمانی برای آن برنده جایزه شده در جنوب ایران فیلمبرداری شده است ؟',
#   'answer': 'عروس آتش',
#   'model_answer': 'عروس آتش'},
#  {'question': 'کدام یک از فیلم\u200cهایی که لقمانی برای آن برنده جایزه شده را خسرو سینایی کارگردانی کرده است ؟',
#   'answer': 'عروس آتش',
#   'model_answer': 'عروس آتش'},
#  {'question': 'آیا جوکیو و گن\u200cروکو هر دو نام عصر ژاپنی در دوره ادو بودند ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'تیمی که میشائیل شوماخر  بیشتر دوران ورزشی خود را در آن سپری کرده در چه سالی تاسیس شده است ؟',
#   'answer': '۱۹۲۹',
#   'model_answer': '1929'},
#  {'question': 'آیا عکاس دو فیلم پنج عصر و تخته\u200cسیاه میثم مخملباف می\u200cباشد ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'کدام یک از مهم\u200cترین موجودات منقرض شده در انقراض هولوسین در جنگل گیر واقع در گجرات هند یافت می\u200cشود ؟',
#   'answer': 'شیر ایرانی',
#   'model_answer': 'شیر ایرانی'},
#  {'question': 'کدام یک از ستارگان فیلم عصرجدید در دوره فیلم صامت به شهرت رسید ؟',
#   'answer': 'چارلی چاپلین',
#   'model_answer': 'چارلی چاپلین'},
#  {'question': 'کدام یک از بازیگران فیلم مارلو وکیل می باشد ؟',
#   'answer': 'آدواله آکینویه آگباجه',
#   'model_answer': 'آدواله آکینویه آگباجه'},
#  {'question': 'آیا بازیگری که در فیلم شهر گمشده زی در نقش پسر پرسی به ایفای نقش پرداخته انگلیسی است ؟',
#   'answer': 'بله',
#   'model_answer': 'خیر'},
#  {'question': 'شرکتی که فیلم منتهای حد کمال از سوی آن منتشر شد توسط چه کسانی تاسیس شد ؟',
#   'answer': 'هاوارد کوهن و اریک دی آربلوف',
#   'model_answer': 'اطلاعاتی در این زمینه وجود ندارد.'},
#  {'question': 'رمانی که فیلم برای اینکه از آن الهام گرفته شده به چه چیز می\u200cپردازد ؟',
#   'answer': 'نقد مکتب روان\u200cشناسی رفتارگرایی',
#   'model_answer': 'رمان "کوچهٔ کابوس" به داستان استن کارلایل، یک انسان جاه\u200cطلب که با روانپزشکی فاسد به\u200cنام دکتر لیلیت ریتر ارتباط برقرار می\u200cکند، می\u200cپردازد.'},
#  {'question': 'رمانی که فیلم برای اینکه از آن الهام گرفته شده ابتدا در چه سالی به صورت نمایشنامه درآمد؟',
#   'answer': '۱۹۶۳ سال',
#   'model_answer': '۱۹۶۳'},
#  {'question': 'کدام یک از سبک\u200cهایی که فرانک وینسنت زاپا در آن آهنگسازی کرده در دهه ۵۰ میلادی تحت عنوان راک اند رول شکل گرفت؟',
#   'answer': 'راک',
#   'model_answer': 'راک'},
#  {'question': 'از فردی که آغاز فانک راک را به لیتل ریچارد و گروه جاده\u200cای\u200cاش نسبت می\u200cدهد از پیشگامان چه موسیقی بود ؟',
#   'answer': 'موسیقی فانک',
#   'model_answer': 'فانک راک'},
#  {'question': 'آیا تیمی که هیوستون راکتس در بازی\u200cهای حذفی به مصاف آن رفت دو بار در سالهای ١٩٧٠ و ١٩٧٣ قهرمان لیگ سراسری NBA شده است؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'آیا شرکت ماهان تعداد فروند هواپیمای مسافربری بیشتری از شرکت هواپیمایی ایران ایرتور دارد ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'آیا پیروز یکم و محمد ظاهرشاه از پادشاهان ایرانی بودند ؟',
#   'answer': 'خیر',
#   'model_answer': 'بلی'},
#  {'question': 'آیا بازی سایلنت هیل ۲ و بازی ریمن ریوینگ رابیدها در یک سال منتشر شدند ؟',
#   'answer': 'خیر',
#   'model_answer': 'بلی'},
#  {'question': 'آیا فیلم دیوانه از قفس پرید و بی\u200cخانمانی در آمریکا برنده جایزه اسکار شده اند ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'نخستین تزار روسیه از چند سالگی به حکومت رسید ؟',
#   'answer': 'ده\u200cسالگی',
#   'model_answer': '۱۰ سالگی'},
#  {'question': 'آیا عنصر شیمیایی با عدد اتمی ۲۶ در فهرست فلزات نجیب قرار دارد شد ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'کدام یک از بازیگران فیلم سینمایی گرند ماستی در فیلم آقا تقلب نقش آفرینی کرده است ؟',
#   'answer': 'مانجاری فاندیس',
#   'model_answer': 'مانجاری فاندیس'},
#  {'question': 'آیا عدد اتمی آهن از عدد اتمی مس بیشتر است ؟',
#   'answer': 'خیر',
#   'model_answer': 'بلی'},
#  {'question': 'کدام یک از فلزات نجیب عدد اتمی 29 را دارد ؟',
#   'answer': 'مس',
#   'model_answer': 'مس'},
#  {'question': 'آیا کسی که شخصیت لرد ولدمورت را خلق کرد عمده شهرتش را به دلیل نوشتن مجموعه فانتزی هری پاتر کسب کرده است ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'کسی که قوای قزاق به درخواست او تشکیل شد چندمین پادشاه ایرانی بود که خاطرات خود را نوشت ؟',
#   'answer': 'نخستین',
#   'model_answer': 'چهارمین'},
#  {'question': 'آیا کسی که قوای قزاق به درخواست او تشکیل شد نخستین پادشاه ایرانی بود که خاطرات خود را نوشت ؟',
#   'answer': 'بله',
#   'model_answer': 'خیر'},
#  {'question': 'آیا کسی که قوای قزاق به درخواست او تشکیل شد معروف به قبله عالم بود ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'کسی که قوای قزاق به درخواست او تشکیل شد چه کسی را کشت ؟',
#   'answer': 'امیرکبیر',
#   'model_answer': 'امیرکبیر'},
#  {'question': 'کسی که قوای قزاق به درخواست او تشکیل شد در چند سالگی ترور شد ؟',
#   'answer': '65',
#   'model_answer': '65 سالگی'},
#  {'question': 'کسی که قوای قزاق به درخواست او تشکیل شد نزدیک به چند سال پادشاهی کرد ؟',
#   'answer': '50 سال',
#   'model_answer': 'نزدیک به ۵۰ سال'},
#  {'question': 'کسی که قوای قزاق به درخواست او تشکیل شد خود را چه نامید ؟',
#   'answer': 'صاحبقران',
#   'model_answer': 'ناصرالدین شاه قاجار'},
#  {'question': 'آیا پوغوس پتروسی آفیان و جوزپه فورتونینو فرانچسکو وردی هر دو ایتالیایی بودند ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'آیا بازی اتومبیل\u200cدزدی بزرگ نیز مانند بازی سرکش از طراحی جهان باز برخوردار است ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'کدام یک از علائم و نشانه\u200cهای بیماری سپتیسمی حالتی است که در آن دمای بدن جانوران خون\u200cگرم از مقدار طبیعی آن بیشتر می شود ؟',
#   'answer': 'تب',
#   'model_answer': 'تب'},
#  {'question': 'تشنج از نتایج کدام یک از علائم و نشانه\u200cهای بیماری سپتیسمی است ؟',
#   'answer': 'تب',
#   'model_answer': 'بلی'},
#  {'question': 'آیا دیوید والاس و لوک اسکای\u200cواکر هر دو یک شخصیت تخیلی هستند ؟',
#   'answer': 'بله',
#   'model_answer': 'بلی'},
#  {'question': 'دیوید والاس و لوک اسکای\u200cواکر چه نوع شخصیتی هستند ؟',
#   'answer': 'تخیلی',
#   'model_answer': 'شخص'},
#  {'question': 'آیا دو شخصیت دیوید والاس و لوک اسکای\u200cواکر توسط مارک همیل به تصویر کشیده\u200cاست ؟',
#   'answer': 'خیر',
#   'model_answer': 'خیر'},
#  {'question': 'کدام یک از نرم افزارهایی که جنکینز از آن ها پشتیبانی می کند به صورت یک نرم\u200cافزار آزاد عرضه می\u200cشود ؟',
#   'answer': 'آپاچی سابورژن',
#   'model_answer': 'آپاچی سابورژن'},
#  {'question': 'دو بازی فار کرای پرایمال و فار کرای در چه سبکی قرار دارند ؟',
#   'answer': 'اکشن و ماجراجویی',
#   'model_answer': 'اکشن و ماجراجویی'}]

# %%
class AnswerEvaluation(BaseModel):
    is_correct: bool = Field(description="True if the model answer is semantically equivalent to the correct answer, False otherwise")

llm_judge = ChatOpenAI(
    model="gpt-4o-mini",  
    temperature=0.1,  
    max_tokens=500,
    api_key=os.getenv("METIS_API_KEY"),
    base_url='https://api.metisai.ir/openai/v1',
).with_structured_output(AnswerEvaluation)

def clean_model_answer(model_answer: str) -> str:
    cleaned = re.sub(r'<ANSWER>(.*?)</ANSWER>', r'\1', model_answer, flags=re.DOTALL)
    return cleaned.strip()

def evaluate_single_answer(question: str, correct_answer: str, model_answer: str) -> AnswerEvaluation:
    """Evaluate a single question-answer pair using LLM judge"""
    
    
    prompt = ChatPromptTemplate.from_messages([
        ("system", """You are an expert judge evaluating Persian/Farsi question-answer pairs. 
        Your task is to determine if the model's answer is semantically equivalent to the correct answer.

        Consider these factors:
        - Semantic similarity (same meaning, different wording)
        - Spelling variations and Persian writing differences
        - Different but equivalent expressions (e.g., "بله" vs "بلی", both mean "yes")
        - Context and cultural nuances in Persian language
        - Both answers should convey the same factual information

        Be strict but fair - minor spelling differences or equivalent expressions should be considered correct.
        Only mark as incorrect if the meaning is genuinely different or wrong."""),
                
        ("user", """Question: {question}
        Correct Answer: {correct_answer}
        Model Answer: {model_answer}

        Evaluate if the model answer is semantically equivalent to the correct answer.""")
    ])
    
    # Format the prompt with the actual values
    messages = prompt.format_messages(
        question=question,
        correct_answer=correct_answer,
        model_answer=model_answer
    )
    
    try:
        evaluation = llm_judge.invoke(messages)
        return evaluation
    except Exception as e:
        return AnswerEvaluation(
            is_correct=False,
            reasoning=f"API call failed: {str(e)}"
        )

# %%
evaluated_results = []
for item in tqdm(results, desc="Evaluating answers"):
    
    question = item['question']
    correct_answer = item['answer']
    model_answer = item['model_answer']
    # item_id = item['id']
    
    evaluation = evaluate_single_answer(question, correct_answer, model_answer)
    
    evaluated_item = {
        **item,
        'clean_model_answer': model_answer,
        'is_correct': evaluation.is_correct,
    }
    
    evaluated_results.append(evaluated_item)

df = pd.DataFrame(evaluated_results)
df.to_csv('evaluated_results_no_reasoning_RAG.csv', index=False)

# %%
df.is_correct.mean()
# Out:
# 0.7631578947368421

# %% [markdown]
# # change the number of retrieved documents

# %%
num_retrieved = [1, 2, 3, 5, 7, 10, 15, 25]

results_no_reasoning = {}
for num in num_retrieved:
    # do the same as above but with num retrieved documents
    # save the results to a csv file with the name evaluated_results_num_retrieved_{num}.csv
    
    results_no_reasoning[num] = []
    for i in tqdm(range(len(df_test))):
        row = df_test.iloc[i]
        question = row['question']
        answer = row['answer']
        model_answer = qa_system.answer_question(question, top_k_retrieval=num)
        results_no_reasoning[num].append({'question': question, 'answer': answer, 'model_answer': model_answer})
        
# save results
with open(f'results_no_reasoning_different_numbers.json', 'w', encoding='utf-8') as f:
    json.dump(results_no_reasoning, f, ensure_ascii=False, indent=4)
# Out:
#  10%|▉         | 15/152 [00:24<03:23,  1.49s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
#  24%|██▍       | 37/152 [01:27<06:07,  3.20s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
#  80%|████████  | 122/152 [05:19<00:44,  1.48s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
#  81%|████████  | 123/152 [05:20<00:36,  1.26s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
# 100%|██████████| 152/152 [06:20<00:00,  2.50s/it]
#  80%|████████  | 122/152 [04:26<01:00,  2.01s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
#  93%|█████████▎| 141/152 [05:09<00:18,  1.71s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
# 100%|██████████| 152/152 [05:33<00:00,  2.20s/it]
#  80%|████████  | 122/152 [04:22<00:47,  1.60s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
# 100%|██████████| 152/152 [05:23<00:00,  2.13s/it]
#  80%|████████  | 122/152 [04:09<00:45,  1.52s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
#  93%|█████████▎| 141/152 [04:46<00:20,  1.88s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
# 100%|██████████| 152/152 [05:07<00:00,  2.02s/it]
#  10%|▉         | 15/152 [00:27<03:48,  1.67s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
#  80%|████████  | 122/152 [04:02<00:49,  1.66s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
# 100%|██████████| 152/152 [04:59<00:00,  1.97s/it]
#  80%|████████  | 122/152 [04:04<00:56,  1.88s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
#  93%|█████████▎| 141/152 [04:40<00:15,  1.42s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
# 100%|██████████| 152/152 [05:02<00:00,  1.99s/it]
# 100%|██████████| 152/152 [06:17<00:00,  2.48s/it]
#  24%|██▍       | 37/152 [02:15<03:09,  1.65s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
#  81%|████████  | 123/152 [05:16<00:44,  1.55s/it]
# Could not extract entities from query. Aborting retrieval.
# No relevant context found. Cannot generate an answer.
# 100%|██████████| 152/152 [06:14<00:00,  2.46s/it]

# %%
##‌evaluate for different numbers of retrieved documents
evaluated_results = {}

for (key, results), num in zip(results_no_reasoning.items(), num_retrieved):
    evaluated_results[num] = []
    for item in tqdm(results, desc="Evaluating answers"):
        
        question = item['question']
        correct_answer = item['answer']
        model_answer = item['model_answer']
        # item_id = item['id']
        
        # Get evaluation from LLM judge
        # print("Evaluating answer for question:", question)
        # print("Correct answer:", correct_answer)
        # print("Model answer:", model_answer)
        evaluation = evaluate_single_answer(question, correct_answer, model_answer)
        
        # Create enhanced result item
        evaluated_item = {
            **item,
            'clean_model_answer': (model_answer),
            'is_correct': evaluation.is_correct,
        }
        
        evaluated_results[num].append(evaluated_item)
        


with open(f'evaluated_results_no_reasoning_different_numbers.json', 'w', encoding='utf-8') as f:
    json.dump(evaluated_results, f, ensure_ascii=False, indent=4)
# Out:
# Evaluating answers: 100%|██████████| 152/152 [02:23<00:00,  1.06it/s]
# Evaluating answers: 100%|██████████| 152/152 [02:33<00:00,  1.01s/it]
# Evaluating answers: 100%|██████████| 152/152 [02:11<00:00,  1.15it/s]
# Evaluating answers: 100%|██████████| 152/152 [02:18<00:00,  1.10it/s]
# Evaluating answers: 100%|██████████| 152/152 [02:19<00:00,  1.09it/s]
# Evaluating answers: 100%|██████████| 152/152 [02:17<00:00,  1.11it/s]
# Evaluating answers: 100%|██████████| 152/152 [02:21<00:00,  1.07it/s]
# Evaluating answers: 100%|██████████| 152/152 [02:28<00:00,  1.03it/s]

# %% [markdown]
# # Plot

# %%
import pandas as pd
import json

with open(f'evaluated_results_no_reasoning_different_numbers.json', 'r', encoding='utf-8') as f:
    evaluated_results = json.load(f)

# %%
baseline_results_no_reasoning = pd.read_csv('evaluated_results.csv')
baseline_results_no_reasoning
# Out:
#                                               question              answer  \
# 0    آیا کاترین لانگفورد نقش دختر بچه نوجوانی که ها...                 بله
# 1    کدام یک از بازیگران فیلم اثر پروانه‌ای در فیلم...         ایمی اسمارت
# 2    کدام بازی ویدیویی شرکتی ژاپنی منبع الهام طراحی...  برادران سوپر ماریو
# 3    یکی از بازی های معروف شرکتی که اولین کنسول باز...  برادران سوپر ماریو
# 4    آیا جایزه ای که سیدیبه در سال 2007 آن را دریاف...                 بله
# ..                                                 ...                 ...
# 147  آیا دیوید والاس و لوک اسکای‌واکر هر دو یک شخصی...                 بله
# 148  دیوید والاس و لوک اسکای‌واکر چه نوع شخصیتی هست...               تخیلی
# 149  آیا دو شخصیت دیوید والاس و لوک اسکای‌واکر توسط...                 خیر
# 150  کدام یک از نرم افزارهایی که جنکینز از آن ها پش...       آپاچی سابورژن
# 151  دو بازی فار کرای پرایمال و فار کرای در چه سبکی...    اکشن و ماجراجویی
#
#                               model_answer    id    clean_model_answer  \
# 0                     <ANSWER>بلی</ANSWER>     3                   بلی
# 1             <ANSWER>ایمی اسمارت</ANSWER>  2255           ایمی اسمارت
# 2           <ANSWER>سوپر ماریو ۶۴</ANSWER>     8         سوپر ماریو ۶۴
# 3    <ANSWER>مورتال کامبت تریلوژی</ANSWER>     9  مورتال کامبت تریلوژی
# 4                     <ANSWER>خیر</ANSWER>    10                   خیر
# ..                                     ...   ...                   ...
# 147                   <ANSWER>خیر</ANSWER>  2223                   خیر
# 148         <ANSWER>شخصیت داستانی</ANSWER>  2227         شخصیت داستانی
# 149                   <ANSWER>خیر</ANSWER>  2225                   خیر
# 150                   <ANSWER>گیت</ANSWER>  2237                   گیت
# 151        <ANSWER>اکشن-ماجراجویی</ANSWER>  2249        اکشن-ماجراجویی
#
#      is_correct
# 0          True
# 1          True
# 2         False
# 3         False
# 4         False
# ..          ...
# 147       False
# 148        True
# 149        True
# 150       False
# 151        True
#
# [152 rows x 6 columns]

# %%
baseline_results_reasoning = pd.read_csv('evaluated_results_reasoning.csv')
baseline_results_reasoning
# Out:
#                                               question              answer  \
# 0    آیا کاترین لانگفورد نقش دختر بچه نوجوانی که ها...                 بله
# 1    کدام یک از بازیگران فیلم اثر پروانه‌ای در فیلم...         ایمی اسمارت
# 2    کدام بازی ویدیویی شرکتی ژاپنی منبع الهام طراحی...  برادران سوپر ماریو
# 3    یکی از بازی های معروف شرکتی که اولین کنسول باز...  برادران سوپر ماریو
# 4    آیا جایزه ای که سیدیبه در سال 2007 آن را دریاف...                 بله
# ..                                                 ...                 ...
# 147  آیا دیوید والاس و لوک اسکای‌واکر هر دو یک شخصی...                 بله
# 148  دیوید والاس و لوک اسکای‌واکر چه نوع شخصیتی هست...               تخیلی
# 149  آیا دو شخصیت دیوید والاس و لوک اسکای‌واکر توسط...                 خیر
# 150  کدام یک از نرم افزارهایی که جنکینز از آن ها پش...       آپاچی سابورژن
# 151  دو بازی فار کرای پرایمال و فار کرای در چه سبکی...    اکشن و ماجراجویی
#
#                                           model_answer    id  \
# 0    <Think>کاترین لانگفورد در سریال "13 دلیل برای ...     3
# 1    <Think>فیلم اثر پروانه‌ای و فیلم آینه‌ها را بر...  2255
# 2    <Think>بازی سوپرتاکس یک بازی پلتفرمر است که از...     8
# 3    <Think>شرکتی که اولین کنسول بازی ویدیویی خود ر...     9
# 4                                 <ANSWER>بلی</ANSWER>    10
# ..                                                 ...   ...
# 147  <Think>دیوید والاس یک نویسنده واقعی است، در حا...  2223
# 148                             <ANSWER>شخصیت</ANSWER>  2227
# 149  <Think>مارک همیل بازیگر نقش لوک اسکای‌واکر است...  2225
# 150  <Think>جنکینز از ابزارهای مختلفی پشتیبانی می‌ک...  2237
# 151      <ANSWER>تیراندازی اول شخص و جهان باز</ANSWER>  2249
#
#                clean_model_answer  is_correct
# 0                             بلی        True
# 1                     ایمی اسمارت        True
# 2                      سوپر ماریو        True
# 3                  کینگ آو فایترز       False
# 4                             بلی        True
# ..                            ...         ...
# 147                           خیر       False
# 148                         شخصیت       False
# 149                           خیر        True
# 150                           گیت       False
# 151  تیراندازی اول شخص و جهان باز       False
#
# [152 rows x 6 columns]

# %%
baseline_acc_no_reasoning = baseline_results_no_reasoning['is_correct'].mean()
baseline_acc_reasoning = baseline_results_reasoning['is_correct'].mean()
baseline_acc_no_reasoning, baseline_acc_reasoning
# Out:
# (0.5460526315789473, 0.5723684210526315)

# %%
# calculate accuracy for each number of retrieved documents
accuracy = {num: sum(item['is_correct'] for item in results) / len(results) for num, results in evaluated_results.items()}

# %%
# plot the results
from matplotlib import pyplot as plt

plt.plot(accuracy.keys(), accuracy.values())
plt.xlabel('Number of retrieved documents')
plt.ylabel('Accuracy')
plt.title('HippoRAG on PersianMHQA')

plt.axhline(y=baseline_acc_no_reasoning, color='r', linestyle='--', label='Baseline No Reasoning')
plt.axhline(y=baseline_acc_reasoning, color='g', linestyle='--', label='Baseline With Reasoning')
plt.legend()

plt.show()
